# %% [markdown]
# # Metaphern und andere Formen der uneigentlichen Rede.

# %% [markdown]
# ## Hälfte des Lebens
#
# ### Llama3:70b

# %%
# %%ai llama3big
# {prompt}

# %% [markdown]
# ### GPT4o

# %%
# %%ai gpt4o
# {prompt}

# %% [markdown]
# ### Opus

# %%
# %%ai opus
# {prompt}

# %% [markdown]
# ### Gemini 1.5

# %%
gemini(prompt)

# %% [markdown]
# ## Unsere Toten
#
# ### Llama3:70b

# %%
# %%ai llama3big
# {prompt}

# %% [markdown]
# ### GPT4o

# %%
# %%ai gpt4o
# {prompt}

# %% [markdown]
# ### Opus

# %%
# %%ai opus
# {prompt}
