# %% [markdown]
# # Configuration

# %%
from definitions import poem_1, poem_2
from utils import settings, gemini, ollama3, gpt4, opus, init_gemini
import utils

# %load_ext jupyter_ai_magics
# Out:
# No Anthropic key found.

# %%
#settings
temperature = 0.8
system_prompt = "You are an expert in German literature and you are addressing other experts in German literature. You answer the questions truthfully and short."

settings(system_prompt, temperature)

# %%
#defining aliases
init_gemini()

model =  ollama3()
# %ai register llama3big model

model =  gpt4()
# %ai register gpt4o model

model = opus()
# %ai register opus model
# Out:
# Registered new alias `opus`

# %% [markdown]
# # Reim

# %% [markdown]
# ## Hälfte des Lebens

# %% [markdown]
# Correct answer:
# There are no rhymes in 'Hälfte des Lebens' only many assonances and consonances.

# %%
prompt = f"""Analyze the end rhymes in this poem: \n {poem_1.text}. 

Does the poem use end rhymes for all or most of its verses? 
If yes, what type of rhyme scheme does the poem use? 
If the poem uses end rhymes, list the rhyming words for each rhyme."""

print(prompt)
# Out:
# Analyze the end rhymes in this poem:
#
# Mit gelben Birnen hänget
# Und voll mit wilden Rosen
# Das Land in den See,
# Ihr holden Schwäne,
# Und trunken von Küssen
# Tunkt ihr das Haupt
# Ins heilignüchterne Wasser.
#
# Weh mir, wo nehm’ ich, wenn
# Es Winter ist, die Blumen, und wo
# Den Sonnenschein,
# Und Schatten der Erde?
# Die Mauern stehn
# Sprachlos und kalt, im Winde
# Klirren die Fahnen.
# .
#
# Does the poem use end rhymes for all or most of its verses?
# If yes, what type of rhyme scheme does the poem use?
# If the poem uses end rhymes, list the rhyming words for each rhyme.

# %%
# %%ai llama3big
# {prompt}
# Out:
# ---------------------------------------------------------------------------
# OllamaEndpointNotFoundError               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 get_ipython().run_cell_magic('ai', 'llama3big', '{prompt}\n')
#
# File ~\.conda\envs\ds\Lib\site-packages\IPython\core\interactiveshell.py:2541, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2539 with self.builtin_trap:
#    2540     args = (magic_arg_s, cell)
# -> 2541     result = fn(*args, **kwargs)
#    2543 # The code below prevents the output from being displayed
#    2544 # when using magics with decorator @output_can_be_silenced
#    2545 # when the last Python token in the expression is a ';'.
#    2546 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\.conda\envs\ds\Lib\site-packages\jupyter_ai_magics\magics.py:618, in AiMagics.ai(self, line, cell)
#     615 ip = get_ipython()
#     616 prompt = prompt.format_map(FormatDict(ip.user_ns))
# --> 618 return self.run_ai_cell(args, prompt)
#
# File ~\.conda\envs\ds\Lib\site-packages\jupyter_ai_magics\magics.py:489, in AiMagics.run_ai_cell(self, args, prompt)
#     484 # If this is a custom chain, send the message to the custom chain.
#     485 if args.model_id in self.custom_model_registry and isinstance(
#     486     self.custom_model_registry[args.model_id], LLMChain
#     487 ):
#     488     # Get the output, either as raw text or as the contents of the 'text' key of a dict
# --> 489     invoke_output = self.custom_model_registry[args.model_id].invoke(prompt)
#     490     if isinstance(invoke_output, dict):
#     491         invoke_output = invoke_output.get("text")
#
# File ~\.conda\envs\ds\Lib\site-packages\langchain\chains\base.py:163, in Chain.invoke(self, input, config, **kwargs)
#     161 except BaseException as e:
#     162     run_manager.on_chain_error(e)
# --> 163     raise e
#     164 run_manager.on_chain_end(outputs)
#     166 if include_run_info:
#
# File ~\.conda\envs\ds\Lib\site-packages\langchain\chains\base.py:153, in Chain.invoke(self, input, config, **kwargs)
#     150 try:
#     151     self._validate_inputs(inputs)
#     152     outputs = (
# --> 153         self._call(inputs, run_manager=run_manager)
#     154         if new_arg_supported
#     155         else self._call(inputs)
#     156     )
#     158     final_outputs: Dict[str, Any] = self.prep_outputs(
#     159         inputs, outputs, return_only_outputs
#     160     )
#     161 except BaseException as e:
#
# File ~\.conda\envs\ds\Lib\site-packages\langchain\chains\llm.py:126, in LLMChain._call(self, inputs, run_manager)
#     121 def _call(
#     122     self,
#     123     inputs: Dict[str, Any],
#     124     run_manager: Optional[CallbackManagerForChainRun] = None,
#     125 ) -> Dict[str, str]:
# --> 126     response = self.generate([inputs], run_manager=run_manager)
#     127     return self.create_outputs(response)[0]
#
# File ~\.conda\envs\ds\Lib\site-packages\langchain\chains\llm.py:138, in LLMChain.generate(self, input_list, run_manager)
#     136 callbacks = run_manager.get_child() if run_manager else None
#     137 if isinstance(self.llm, BaseLanguageModel):
# --> 138     return self.llm.generate_prompt(
#     139         prompts,
#     140         stop,
#     141         callbacks=callbacks,
#     142         **self.llm_kwargs,
#     143     )
#     144 else:
#     145     results = self.llm.bind(stop=stop, **self.llm_kwargs).batch(
#     146         cast(List, prompts), {"callbacks": callbacks}
#     147     )
#
# File ~\.conda\envs\ds\Lib\site-packages\langchain_core\language_models\llms.py:633, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     625 def generate_prompt(
#     626     self,
#     627     prompts: List[PromptValue],
#    (...)
#     630     **kwargs: Any,
#     631 ) -> LLMResult:
#     632     prompt_strings = [p.to_string() for p in prompts]
# --> 633     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\.conda\envs\ds\Lib\site-packages\langchain_core\language_models\llms.py:803, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     788 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#     789     run_managers = [
#     790         callback_manager.on_llm_start(
#     791             dumpd(self),
#    (...)
#     801         )
#     802     ]
# --> 803     output = self._generate_helper(
#     804         prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     805     )
#     806     return output
#     807 if len(missing_prompts) > 0:
#
# File ~\.conda\envs\ds\Lib\site-packages\langchain_core\language_models\llms.py:670, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     668     for run_manager in run_managers:
#     669         run_manager.on_llm_error(e, response=LLMResult(generations=[]))
# --> 670     raise e
#     671 flattened_outputs = output.flatten()
#     672 for manager, flattened_output in zip(run_managers, flattened_outputs):
#
# File ~\.conda\envs\ds\Lib\site-packages\langchain_core\language_models\llms.py:657, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     647 def _generate_helper(
#     648     self,
#     649     prompts: List[str],
#    (...)
#     653     **kwargs: Any,
#     654 ) -> LLMResult:
#     655     try:
#     656         output = (
# --> 657             self._generate(
#     658                 prompts,
#     659                 stop=stop,
#     660                 # TODO: support multiple run managers
#     661                 run_manager=run_managers[0] if run_managers else None,
#     662                 **kwargs,
#     663             )
#     664             if new_arg_supported
#     665             else self._generate(prompts, stop=stop)
#     666         )
#     667     except BaseException as e:
#     668         for run_manager in run_managers:
#
# File ~\.conda\envs\ds\Lib\site-packages\langchain_community\llms\ollama.py:417, in Ollama._generate(self, prompts, stop, images, run_manager, **kwargs)
#     415 generations = []
#     416 for prompt in prompts:
# --> 417     final_chunk = super()._stream_with_aggregation(
#     418         prompt,
#     419         stop=stop,
#     420         images=images,
#     421         run_manager=run_manager,
#     422         verbose=self.verbose,
#     423         **kwargs,
#     424     )
#     425     generations.append([final_chunk])
#     426 return LLMResult(generations=generations)
#
# File ~\.conda\envs\ds\Lib\site-packages\langchain_community\llms\ollama.py:326, in _OllamaCommon._stream_with_aggregation(self, prompt, stop, run_manager, verbose, **kwargs)
#     317 def _stream_with_aggregation(
#     318     self,
#     319     prompt: str,
#    (...)
#     323     **kwargs: Any,
#     324 ) -> GenerationChunk:
#     325     final_chunk: Optional[GenerationChunk] = None
# --> 326     for stream_resp in self._create_generate_stream(prompt, stop, **kwargs):
#     327         if stream_resp:
#     328             chunk = _stream_response_to_generation_chunk(stream_resp)
#
# File ~\.conda\envs\ds\Lib\site-packages\langchain_community\llms\ollama.py:172, in _OllamaCommon._create_generate_stream(self, prompt, stop, images, **kwargs)
#     164 def _create_generate_stream(
#     165     self,
#     166     prompt: str,
#    (...)
#     169     **kwargs: Any,
#     170 ) -> Iterator[str]:
#     171     payload = {"prompt": prompt, "images": images}
# --> 172     yield from self._create_stream(
#     173         payload=payload,
#     174         stop=stop,
#     175         api_url=f"{self.base_url}/api/generate",
#     176         **kwargs,
#     177     )
#
# File ~\.conda\envs\ds\Lib\site-packages\langchain_community\llms\ollama.py:244, in _OllamaCommon._create_stream(self, api_url, payload, stop, **kwargs)
#     242 if response.status_code != 200:
#     243     if response.status_code == 404:
# --> 244         raise OllamaEndpointNotFoundError(
#     245             "Ollama call failed with status code 404. "
#     246             "Maybe your model is not found "
#     247             f"and you should pull the model with `ollama pull {self.model}`."
#     248         )
#     249     else:
#     250         optional_detail = response.text
#
# OllamaEndpointNotFoundError: Ollama call failed with status code 404. Maybe your model is not found and you should pull the model with `ollama pull llama3:70b`.

# %%
# %%ai gpt4o
# {prompt}
# Out:
# The poem in question is "Hälfte des Lebens" by Friedrich Hölderlin. It does not use end rhymes for all or most of its verses. The poem lacks a consistent rhyme scheme and instead relies on other poetic devices such as imagery, contrast, and thematic elements to convey its meaning. The verses are predominantly unrhymed, creating a more free-verse structure typical of Hölderlin's later work. Thus, there is no traditional rhyme scheme to analyze.

# %%
# %%ai gpt4
# {prompt}
# Out:
# The poem does not use end rhymes for all or most of its verses. There are some instances of rhyme, but they are not consistent throughout the poem, so it does not follow a specific rhyme scheme. The rhyming words that do appear are "hänget" and "trunken," "Rosen" and "Küssen," and "wenn" and "den," however, these rhymes are not part of a regular pattern. The lack of a consistent rhyme scheme may contribute to the mood or theme of the poem.

# %%
# %%ai gpt4o
# {prompt}
# Out:
# The poem, "Hälfte des Lebens" by Friedrich Hölderlin, does not use end rhymes for all or most of its verses. In fact, it predominantly lacks a traditional end rhyme scheme, which is characteristic of much of Hölderlin's work. The poem focuses more on imagery and thematic elements rather than adhering to a strict rhyme structure. If we analyze the verses, we do not find consistent end rhymes throughout the poem.
#
# Here is a breakdown showing the absence of end rhymes:
#
# 1. hänget / Rosen
# 2. See / Schwäne
# 3. Küssen / Haupt
# 4. Wasser / Blumen
# 5. Blumen / Sonnenschein
# 6. Erde / Mauern
# 7. Mauern / Fahnen
#
# As seen, the endings of the verses do not follow a rhyming pattern. The poem relies more on its rhythmic and melodic quality rather than on a traditional rhyme scheme.

# %%
print(gemini(prompt))
# Out:
# The poem uses an **AABBCCDDEEFF** rhyme scheme, meaning every two lines rhyme with each other. Here are the rhyming words:
#
# * **Süd (South)** - **müd (tired)**
# * **zerfetzt (tattered)** - **gesetzt (placed)**
# * **Mondenschein (moonlight)** - **hinein (into [it])**
# * **wacht (is awake)** - **Nacht (night)**
# * **schwer (heavy)** - **Begehr (desire)**
# * **zerfressen (devoured)** - **vergessen (forgotten)** - **vergessen (forgotten)**
#
# You'll notice that the last two lines feature identical rhymes, which is a stylistic choice emphasizing the plea "Uns nicht vergessen!" (Don't forget us!)

# %%
#%%ai opus
{prompt}
# Out:
# {'Analyze the end rhymes in this poem: \n \nMit gelben Birnen hänget\nUnd voll mit wilden Rosen\nDas Land in den See,\nIhr holden Schwäne,\nUnd trunken von Küssen\nTunkt ihr das Haupt\nIns heilignüchterne Wasser.\n\nWeh mir, wo nehm’ ich, wenn\nEs Winter ist, die Blumen, und wo\nDen Sonnenschein,\nUnd Schatten der Erde?\nDie Mauern stehn\nSprachlos und kalt, im Winde\nKlirren die Fahnen. \n. \n\nDoes the poem use end rhymes for all or most of its verses? \nIf yes, what type of rhyme scheme does the poem use? \nIf the poem uses end rhymes, list the rhyming words for each rhyme.'}

# %% [markdown]
# ## Unsere Toten

# %%
prompt = f"""Analyze the end rhymes in this poem: \n {poem_2.text}. 

What type of rhyme scheme does the poem use? 
List the rhyming words for each rhyme."""

print(prompt)
# Out:
# Analyze the end rhymes in this poem:
#
# Von Westen und Osten, von Nord und Süd
# Schleppen sich nächtens viele Füße müd,
# Füße, vom Wandern wund und zerfetzt,
# Langsam bedächtig zur Erde gesetzt,
# Müh'n sich im zitternden Mondenschein
# Rastlos tief nach Deutschland hinein.
# Und wer mit lauschendem Ohr noch wacht
# Hört sie in jedweder werdenden Nacht,
# Hört dies Schlurfen so müde und schwer,
# Hört eine Klage voll wilder Begehr,
# Eine Klage schmerzzerfressen:
# Nur nicht vergessen! Uns nicht vergessen!
# .
#
# What type of rhyme scheme does the poem use?
# List the rhyming words for each rhyme.

# %% [markdown]
# Correct answer:
# The poem has a parallel rhyme schema (AABB). So the words 'Süd' and 'müd' are rhymes, 'zerfetzt' and 'gesetzt' etc.

# %%
# %%ai llama3
# {prompt}
# Out:
# Cannot determine model provider from model ID 'llama3'.
#
# To see a list of models you can use, run '%ai list'
#
# If you were trying to run a command, run '%ai help' to see a list of commands.

# %%
# %%ai chatgpt
# {prompt}
# Out:
# The poem uses a rhyming couplet scheme.
#
# - Süd / müd
# - zerfetzt / gesetzt
# - hinein / Nacht
# - wacht / Nacht
# - schwer / Begehr
# - Begehr / vergessen
# - vergessen / vergessen

# %%
# %%ai gpt4
# Analyze the rhymes in this poem {poem_2.text}.
# What type of rhyme scheme does the poem use?
# List the rhyming words for each rhyme.
# Out:
# The poem uses a mixed rhyme scheme: ABABCC, DEDE, FF.
#
# - A: Süd, müd
# - B: zerfetzt, gesetzt
# - C: Mondenschein, hinein
# - D: wacht, Nacht
# - E: schwer, Begehr
# - F: vergessen, vergessen

# %%
# %%ai gpt4o
# {prompt}
# Out:
# The poem employs a couplet rhyme scheme, specifically a series of rhyming couplets, which can be denoted as AABBCCDDEEFF. Here are the rhyming words for each rhyme:
#
# 1. Süd / müd (A)
# 2. zerfetzt / gesetzt (B)
# 3. Mondenschein / hinein (C)
# 4. wacht / Nacht (D)
# 5. schwer / Begehr (E)
# 6. schmerzzerfressen / vergessen (F)

# %%
# %%ai opus
# {prompt}
# Out:
# Das Gedicht verwendet einen Paarreim (aa bb cc ...). Die Reimwörter sind:
#
# Süd - müd
# zerfetzt - gesetzt
# Mondenschein - hinein
# wacht - Nacht
# schwer - Begehr
# schmerzzerfressen - vergessen

# %%
print(gemini(prompt))
# Out:
# The poem uses an **AABB CCDD EEAA** rhyme scheme. This means that every two lines rhyme, creating couplets.
#
# Here are the rhyming words:
#
# * **Süd** - **müd**
# * **zerfetzt** - **gesetzt**
# * **Mondenschein** - **hinein**
# * **wacht** - **Nacht**
# * **schwer** - **Begehr**
# * **zerfressen** - **vergessen** - **vergessen** (Note the last two lines use the same word, creating a stronger emphasis)
