# %% [markdown]
# # Configuration

# %%
from definitions import poem_1, poem_2
from utils import settings, gemini, gpt4, opus, init_gemini, printmd
import utils

# %load_ext jupyter_ai_magics

# %%
#settings
temperature = 0.8
system_prompt = "You are an expert in German literature and you are addressing other experts in German literature. You answer the questions truthfully and short."

settings(system_prompt, temperature)

# %%
#defining aliases
init_gemini()

model =  gpt4()
# %ai register gpt4o model

model = opus()
# %ai register opus model
# Out:
# Registered new alias `opus`

# %% [markdown]
# # Reim

# %% [markdown]
# ## Hälfte des Lebens

# %% [markdown]
# Correct answer:
# There are no rhymes in 'Hälfte des Lebens' only many assonances and consonances.

# %%
prompt = f"""Analyze the end rhymes in this poem: \n {poem_1.text}. 

Does the poem use end rhymes for all or most of its verses? 
If yes, what type of rhyme scheme does the poem use? 
If the poem uses end rhymes, list the rhyming words for each rhyme."""

print(prompt)
# Out:
# Analyze the end rhymes in this poem:
#
# Mit gelben Birnen hänget
# Und voll mit wilden Rosen
# Das Land in den See,
# Ihr holden Schwäne,
# Und trunken von Küssen
# Tunkt ihr das Haupt
# Ins heilignüchterne Wasser.
#
# Weh mir, wo nehm’ ich, wenn
# Es Winter ist, die Blumen, und wo
# Den Sonnenschein,
# Und Schatten der Erde?
# Die Mauern stehn
# Sprachlos und kalt, im Winde
# Klirren die Fahnen.
# .
#
# Does the poem use end rhymes for all or most of its verses?
# If yes, what type of rhyme scheme does the poem use?
# If the poem uses end rhymes, list the rhyming words for each rhyme.

# %%
# %%ai gpt4
# {prompt}
# Out:
# The poem does not use end rhymes for all or most of its verses. There are some instances of rhyme, but they are not consistent throughout the poem, so it does not follow a specific rhyme scheme. The rhyming words that do appear are "hänget" and "trunken," "Rosen" and "Küssen," and "wenn" and "den," however, these rhymes are not part of a regular pattern. The lack of a consistent rhyme scheme may contribute to the mood or theme of the poem.

# %%
print(gemini(prompt))
# Out:
# The poem uses end rhymes, but not for all verses. It's a somewhat irregular rhyme scheme, but a pattern can be discerned.  It doesn't strictly adhere to a common scheme like AABB or ABAB, etc.
#
# Here's a breakdown:
#
# * **Rosen / Küssen:** These words share the "-osen" sound, forming a masculine rhyme (rhyme on the final stressed syllable).
# * **See / Weh:**  These words share the "-ee" sound, also a masculine rhyme.
# * **Schatten / Fahnen:** These words share the "-atten" sound, another masculine rhyme.
#
# Notice that other lines, like "hänget," "Schwäne," "Wasser," "Blumen," "Sonnenschein," "Erde," "stehn," "kalt," and "Winde," do *not* rhyme with any other lines.
#
# Therefore, while the poem *does* use end rhymes, it does not do so consistently or with a regular, identifiable rhyme scheme across all lines.  It's more sporadic and serves to connect certain ideas or images thematically rather than impose a strict formal structure.

# %%
# %%ai opus
# {prompt}
# Out:
# No, this poem by Hölderlin ("Hälfte des Lebens") does not employ a systematic end rhyme scheme. It is written in free verse with irregular line lengths. While there are some similar word endings (e.g., "Rosen"/"Küssen"), these are not intentional rhymes but rather coincidental sound parallels. The lack of end rhymes contributes to the poem's modern, less formal structure and emphasizes its content over traditional poetic forms.

# %% [markdown]
# ## Unsere Toten

# %%
prompt = f"""Analyze the end rhymes in this poem: \n {poem_2.text}. 

What type of rhyme scheme does the poem use? 
List the rhyming words for each rhyme."""

print(prompt)
# Out:
# Analyze the end rhymes in this poem:
#
# Von Westen und Osten, von Nord und Süd
# Schleppen sich nächtens viele Füße müd,
# Füße, vom Wandern wund und zerfetzt,
# Langsam bedächtig zur Erde gesetzt,
# Müh'n sich im zitternden Mondenschein
# Rastlos tief nach Deutschland hinein.
# Und wer mit lauschendem Ohr noch wacht
# Hört sie in jedweder werdenden Nacht,
# Hört dies Schlurfen so müde und schwer,
# Hört eine Klage voll wilder Begehr,
# Eine Klage schmerzzerfressen:
# Nur nicht vergessen! Uns nicht vergessen!
# .
#
# What type of rhyme scheme does the poem use?
# List the rhyming words for each rhyme.

# %% [markdown]
# Correct answer:
# The poem has a parallel rhyme schema (AABB). So the words 'Süd' and 'müd' are rhymes, 'zerfetzt' and 'gesetzt' etc.

# %%
# %%ai gpt4
# Analyze the rhymes in this poem {poem_2.text}.
# What type of rhyme scheme does the poem use?
# List the rhyming words for each rhyme.
# Out:
# This poem uses an ABCCB rhyme scheme.
#
# - Rhyme A: Süd, müd
# - Rhyme B: zerfetzt, gesetzt
# - Rhyme C: hinein, Begehr, zerfressen, vergessen
#
# Please note that some rhymes are not perfect (also known as slant rhymes), like 'hinein' and 'Begehr' or 'zerfressen' and 'vergessen'. The rhyming words are based on sound rather than spelling.

# %%
# %%ai opus
# {prompt}
# Out:
# The poem uses paired rhymes (Paarreim) throughout, following an AA BB CC DD EE FF pattern.
#
# The rhyming pairs are:
# - Süd/müd
# - zerfetzt/gesetzt
# - Mondenschein/hinein
# - wacht/Nacht
# - schwer/Begehr
# - vergessen/vergessen
#
# All rhymes are pure rhymes (reine Reime), with the last pair being an identical rhyme (identischer Reim).

# %%
print(gemini(prompt))
# Out:
# The poem uses an AABB CCDD EEFF rhyme scheme. Here's a breakdown of the rhyming words:
#
# * **A:** Süd (South), müd (tired)
# * **B:** Nord (North), zerfetzt (torn)
# * **C:** Mondenschein (moonlight), hinein (into [it])
# * **D:** wacht (is awake), Nacht (night)
# * **E:** schwer (heavy), Begehr (desire)
# * **F:** zerfressen (corroded), vergessen (forgotten)  (This rhyme is repeated twice within the last two lines.)
