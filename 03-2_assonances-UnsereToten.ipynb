# %% [markdown]
# # Configuration

# %%
from definitions import poem_1, poem_2
import os
from utils import settings, gemini, gpt4, opus, init_gemini, printmd

# %load_ext jupyter_ai_magics

# %%
#settings
temperature = 0.8
system_prompt = "You are an expert in German literature and you are addressing other experts in German literature. You answer the questions truthfully and short."

settings(system_prompt, temperature)

# %% [markdown]
# # Unsere Toten

# %%
#defining aliases
init_gemini()

#model =  ollama3()
#%ai register llama3big model

model =  gpt4()
# %ai register gpt4o model

model = opus()
# %ai register opus model
# Out:
# Registered new alias `opus`

# %% [markdown]
# # Assonanzen
# ## Task 1: Student communication: simple identification task: Detect assonances
# ### 1.a: Detection based on different definitions of assonance
# ### 1.b: Detection based on a two-step CoT-prompt: 1) Translate to IPA, 2) then perform assonance detection
# ### 1.c: Same tasks for English¶
#
# ## Expectation:
# - Definitionsabhängigkeit: Je genauer der Laut-und Phonemcharakter erläutert wird, desto besser die Erkennung Assonanzen
# - Schiwerigkeiten, die richtigen Laute im Deutschen zu erkennen.

# %%
assonance = """Assonance is a similarity in sound between two stressed syllables 
that are close together in a text, created by the same vowels but different consonants """

assonance02 = """Assonance is the repetition of identical or similar phonemes in words or syllables that occur close together
in terms of their vowel phonemes (e.g. lean green meat)"""

assonance03 = """Assonance is the repetition of identical or similar phonemes between two stressed syllables that occur close together
in terms of their vowel phonemes (e.g. lean green meat). Note that identical vowels do not always imply same phonems. 
The 'o'-sound in 'often' and 'other' does not produce the same phonem"""

# %%
prompt01 = f"""Here is a definition of assonance: {assonance}. 
Using this definition, give a full description of all assonances in this poem: \n {poem_2.text}. \n
Explain in each case the assonance by repeating the words and by giving the common vowel.
Use the following form in your answer: 'Dem Nordmann schwinden die Sorgen' - the 'o' sound in 'Nordmann' and 'Sorgen' creates assonance."""

prompt02 = f"""Here is a definition of assonance: {assonance02}. 
Using this definition, give a full description of all assonances in this poem: \n {poem_2.text}. \n
Explain in each case the assonance by repeating the words and by giving the common vowel.
Use the following form in your answer: 'Dem Nordmann schwinden die Sorgen' - the 'o' sound in 'Nordmann' and 'Sorgen' creates assonance."""

prompt03 = f"""Here is a definition of assonance: {assonance03}. 
Using this definition, give a full description of all assonances in this poem: \n {poem_2.text}. \n
Explain in each case the assonance by repeating the words and by giving the common vowel.
Use the following form in your answer: 'Dem Nordmann schwinden die Sorgen' - the 'o' sound in 'Nordmann' and 'Sorgen' creates assonance."""

prompt04_ipa = f"""Here is a definition of assonance: {assonance03}. 
Using this definition, give a full description of all assonances in this poem: \n {poem_2.text} \n
Explain in each case the assonance by repeating the words and by giving the common vowel.
Use a two-step reasoning: Firstly, translate the poem to IPA. Secondly, perform the requested analysis of assonances based on the IPA-translation.
Use the following form in the second step of your answer: 'Dem Nordmann schwinden die Sorgen' - the 'o' sound in 'Nordmann' and 'Sorgen' creates assonance."""

prompt_en01 = f"""Here is a definition of assonance: {assonance}. 
Using this definition, give a full description of all assonances in this poem: \n {poem_2.translations[0]}. \n
Explain in each case the assonance by repeating the words and by giving the common vowel.
Use the following form in your answer: 'Dem Nordmann schwinden die Sorgen' - the 'o' sound in 'Nordmann' and 'Sorgen' creates assonance."""


prompt_en02 = f"""Here is a definition of assonance: {assonance02}. 
Using this definition, give a full description of all assonances in this poem: \n {poem_2.translations[0]}. \n
Explain in each case the assonance by repeating the words and by giving the common vowel.
Use the following form in your answer: 'Dem Nordmann schwinden die Sorgen' - the 'o' sound in 'Nordmann' and 'Sorgen' creates assonance."""

prompt_en03 = f"""Here is a definition of assonance: {assonance03}. 
Using this definition, give a full description of all assonances in this poem: \n {poem_2.translations[0]}. \n
Explain in each case the assonance by repeating the words and by giving the common vowel.
Use the following form in your answer: 'Dem Nordmann schwinden die Sorgen' - the 'o' sound in 'Nordmann' and 'Sorgen' creates assonance."""

# %% [markdown]
# ## Task 1.a

# %%
print(prompt01)
# Out:
# Here is a definition of assonance: Assonance is a similarity in sound between two stressed syllables
# that are close together in a text, created by the same vowels but different consonants .
# Using this definition, give a full description of all assonances in this poem:
#
# Von Westen und Osten, von Nord und Süd
# Schleppen sich nächtens viele Füße müd,
# Füße, vom Wandern wund und zerfetzt,
# Langsam bedächtig zur Erde gesetzt,
# Müh'n sich im zitternden Mondenschein
# Rastlos tief nach Deutschland hinein.
# Und wer mit lauschendem Ohr noch wacht
# Hört sie in jedweder werdenden Nacht,
# Hört dies Schlurfen so müde und schwer,
# Hört eine Klage voll wilder Begehr,
# Eine Klage schmerzzerfressen:
# Nur nicht vergessen! Uns nicht vergessen!
# .
#
# Explain in each case the assonance by repeating the words and by giving the common vowel.
# Use the following form in your answer: 'Dem Nordmann schwinden die Sorgen' - the 'o' sound in 'Nordmann' and 'Sorgen' creates assonance.

# %%
# %%ai gpt4o
# {prompt01}
# Out:
# 1. "von Nord und Süd" - the 'o' sound in 'von' and 'Nord' creates assonance.
#
# 2. "Schleppen sich nächtens viele Füße müd" - the 'ü' sound in 'Füße' and 'müd' creates assonance.
#
# 3. "Füße, vom Wandern wund und zerfetzt" - the 'u' sound in 'Wandern' and 'wund' creates assonance.
#
# 4. "Langsam bedächtig zur Erde gesetzt" - the 'e' sound in 'bedächtig' and 'gesetzt' creates assonance.
#
# 5. "Rastlos tief nach Deutschland hinein" - the 'a' sound in 'Rastlos' and 'nach' creates assonance.
#
# 6. "Wer mit lauschendem Ohr noch wacht" - the 'o' sound in 'Ohr' and 'noch' creates assonance.
#
# 7. "Hört dies Schlurfen so müde und schwer" - the 'ö' sound in 'Hört' and 'schwer' creates assonance.
#
# 8. "Hört eine Klage voll wilder Begehr" - the 'e' sound in 'Klage' and 'Begehr' creates assonance.
#
# 9. "Nur nicht vergessen! Uns nicht vergessen!" - the 'e' sound in 'vergessen' and 'vergessen' creates assonance.

# %%
print(prompt02)
# Out:
# Here is a definition of assonance: Assonance is the repetition of identical or similar phonemes in words or syllables that occur close together
# in terms of their vowel phonemes (e.g. lean green meat).
# Using this definition, give a full description of all assonances in this poem:
#
# Von Westen und Osten, von Nord und Süd
# Schleppen sich nächtens viele Füße müd,
# Füße, vom Wandern wund und zerfetzt,
# Langsam bedächtig zur Erde gesetzt,
# Müh'n sich im zitternden Mondenschein
# Rastlos tief nach Deutschland hinein.
# Und wer mit lauschendem Ohr noch wacht
# Hört sie in jedweder werdenden Nacht,
# Hört dies Schlurfen so müde und schwer,
# Hört eine Klage voll wilder Begehr,
# Eine Klage schmerzzerfressen:
# Nur nicht vergessen! Uns nicht vergessen!
# .
#
# Explain in each case the assonance by repeating the words and by giving the common vowel.
# Use the following form in your answer: 'Dem Nordmann schwinden die Sorgen' - the 'o' sound in 'Nordmann' and 'Sorgen' creates assonance.

# %%
# %%ai gpt4o
# {prompt02}
# Out:
# 1. "Von Westen und Osten, von Nord und Süd" - the 'o' sound in 'Von', 'Osten', and 'Nord' creates assonance.
# 2. "Schleppen sich nächtens viele Füße müd" - the 'ü' sound in 'Füße' and 'müd' creates assonance.
# 3. "Füße, vom Wandern wund und zerfetzt" - the 'e' sound in 'Wandern' and 'zerfetzt' creates assonance.
# 4. "Langsam bedächtig zur Erde gesetzt" - the 'e' sound in 'bedächtig', 'Erde', and 'gesetzt' creates assonance.
# 5. "Müh'n sich im zitternden Mondenschein" - the 'i' sound in 'sich' and 'im' creates assonance.
# 6. "Rastlos tief nach Deutschland hinein" - the 'a' sound in 'Rastlos', 'nach', and 'Deutschland' creates assonance.
# 7. "Hört dies Schlurfen so müde und schwer" - the 'ö' sound in 'Hört' and 'schwer' creates assonance.
# 8. "Hört eine Klage voll wilder Begehr" - the 'e' sound in 'Klage' and 'Begehr' creates assonance.
# 9. "Eine Klage schmerzzerfressen" - the 'a' sound in 'Klage' and 'schmerzzerfressen' creates assonance.
# 10. "Nur nicht vergessen! Uns nicht vergessen!" - the 'e' sound in 'vergessen' and 'vergessen' creates assonance.

# %%
print(prompt03)
# Out:
# Here is a definition of assonance: Assonance is the repetition of identical or similar phonemes in words or syllables that occur close together
# in terms of their vowel phonemes (e.g. lean green meat). Note that identical vowels do not always imply same phonems. The 'o'-sound in 'often' and 'other' does not produce the same phonem.
# Using this definition, give a full description of all assonances in this poem:
#
# Von Westen und Osten, von Nord und Süd
# Schleppen sich nächtens viele Füße müd,
# Füße, vom Wandern wund und zerfetzt,
# Langsam bedächtig zur Erde gesetzt,
# Müh'n sich im zitternden Mondenschein
# Rastlos tief nach Deutschland hinein.
# Und wer mit lauschendem Ohr noch wacht
# Hört sie in jedweder werdenden Nacht,
# Hört dies Schlurfen so müde und schwer,
# Hört eine Klage voll wilder Begehr,
# Eine Klage schmerzzerfressen:
# Nur nicht vergessen! Uns nicht vergessen!
# .
#
# Explain in each case the assonance by repeating the words and by giving the common vowel.
# Use the following form in your answer: 'Dem Nordmann schwinden die Sorgen' - the 'o' sound in 'Nordmann' and 'Sorgen' creates assonance.

# %%
# %%ai gpt4o
# {prompt03}
# Out:
# 1. "Von Westen und Osten, von Nord und Süd" - the 'o' sound in 'Osten', 'von', and 'Nord' creates assonance.
#
# 2. "Schleppen sich nächtens viele Füße müd" - the 'ü' sound in 'Füße' and 'müd' creates assonance.
#
# 3. "Füße, vom Wandern wund und zerfetzt" - the 'ä' sound in 'Wandern' and 'zerfetzt' creates assonance.
#
# 4. "Langsam bedächtig zur Erde gesetzt" - the 'e' sound in 'bedächtig', 'Erde', and 'gesetzt' creates assonance.
#
# 5. "Müh'n sich im zitternden Mondenschein" - the 'i' sound in 'Müh'n', 'sich', and 'im' creates assonance; the 'e' sound in 'zitternden' and 'Mondenschein' creates assonance.
#
# 6. "Rastlos tief nach Deutschland hinein" - the 'a' sound in 'Rastlos' and 'nach' creates assonance.
#
# 7. "Und wer mit lauschendem Ohr noch wacht" - the 'o' sound in 'Ohr' and 'noch' creates assonance.
#
# 8. "Hört sie in jedweder werdenden Nacht" - the 'e' sound in 'jedweder' and 'werdenden' creates assonance.
#
# 9. "Hört dies Schlurfen so müde und schwer" - the 'ü' sound in 'Schlurfen' and 'müde' creates assonance; the 'e' sound in 'dies' and 'schwer' creates assonance.
#
# 10. "Hört eine Klage voll wilder Begehr" - the 'e' sound in 'Klage', 'wilder', and 'Begehr' creates assonance.
#
# 11. "Eine Klage schmerzzerfressen" - the 'e' sound in 'Klage' and 'schmerzzerfressen' creates assonance.
#
# 12. "Nur nicht vergessen! Uns nicht vergessen!" - the 'e' sound in 'vergessen' and 'nicht' creates assonance.

# %%
print(prompt_en01)
# Out:
# Here is a definition of assonance: Assonance is the repetition of identical or similar phonemes in words or syllables that occur close together
# in terms of their vowel phonemes (e.g. lean green meat).
# Using this definition, give a full description of all assonances in this poem:
#
# From west and east, from north and south
# Many feet will soon be dragging themselves wearily,
# Feet, sore and torn from walking,
# Slowly set to the earth,
# Toil in the trembling moonlight
# Restlessly deep into Germany.
# And who with listening ear still wakes
# Hears them in every growing night,
# Hears this shuffling so weary and heavy,
# Hears a lament full of wild desire,
# A lamentation full of pain:
# Only do not forget! Do not forget us!
# .
#
# Explain in each case the assonance by repeating the words and by giving the common vowel.
# Use the following form in your answer: 'Dem Nordmann schwinden die Sorgen' - the 'o' sound in 'Nordmann' and 'Sorgen' creates assonance.

# %%
# %%ai gpt4o
# {prompt_en01}
# Out:
# 1. "From west and east, from north and south" - the 'o' sound in 'from' and 'north' creates assonance.
#
# 2. "Many feet will soon be dragging themselves wearily" - the 'ee' sound in 'feet' and 'weary' creates assonance.
#
# 3. "Feet, sore and torn from walking" - the 'o' sound in 'sore' and 'torn' creates assonance.
#
# 4. "Slowly set to the earth" - the 'o' sound in 'slowly' and 'to' creates assonance.
#
# 5. "Toil in the trembling moonlight" - the 'o' sound in 'moonlight' creates assonance with 'toil'.
#
# 6. "Restlessly deep into Germany" - the 'ee' sound in 'deep' and 'Germany' creates assonance.
#
# 7. "And who with listening ear still wakes" - the 'i' sound in 'listening' and 'still' creates assonance.
#
# 8. "Hears them in every growing night" - the 'ea' sound in 'hears' and 'every' creates assonance.
#
# 9. "Hears this shuffling so weary and heavy" - the 'ea' sound in 'weary' and 'heavy' creates assonance.
#
# 10. "Hears a lament full of wild desire" - the 'i' sound in 'wild' and 'desire' creates assonance.
#
# 11. "Only do not forget! Do not forget us!" - the 'o' sound in 'only' and 'not' creates assonance.

# %%
print(prompt_en02)
# Out:
# Here is a definition of assonance: Assonance is the repetition of identical or similar phonemes in words or syllables that occur close together
# in terms of their vowel phonemes (e.g. lean green meat).
# Using this definition, give a full description of all assonances in this poem:
#
# From west and east, from north and south
# Many feet will soon be dragging themselves wearily,
# Feet, sore and torn from walking,
# Slowly set to the earth,
# Toil in the trembling moonlight
# Restlessly deep into Germany.
# And who with listening ear still wakes
# Hears them in every growing night,
# Hears this shuffling so weary and heavy,
# Hears a lament full of wild desire,
# A lamentation full of pain:
# Only do not forget! Do not forget us!
# .
#
# Explain in each case the assonance by repeating the words and by giving the common vowel.
# Use the following form in your answer: 'Dem Nordmann schwinden die Sorgen' - the 'o' sound in 'Nordmann' and 'Sorgen' creates assonance.

# %%
# %%ai gpt4o
# {prompt_en02}
# Out:
# 1. "Feet will soon be dragging themselves wearily" - the 'ee' sound in 'feet', 'be', and 'weary' creates assonance.
#
# 2. "Feet, sore and torn from walking" - the 'o' sound in 'sore' and 'torn' creates assonance.
#
# 3. "Slowly set to the earth" - the 'o' sound in 'slowly' and 'to' creates assonance.
#
# 4. "Toil in the trembling moonlight" - the 'ooi' sound in 'toil' and 'moonlight' creates assonance.
#
# 5. "Restlessly deep into Germany" - the 'ee' sound in 'deep' and 'Germany' creates assonance.
#
# 6. "Hears them in every growing night" - the 'ea' sound in 'hears' and 'every' creates assonance.
#
# 7. "Hears this shuffling so weary and heavy" - the 'ea' sound in 'hears', 'weary', and 'heavy' creates assonance.
#
# 8. "Hears a lament full of wild desire" - the 'ai' sound in 'lament' and 'desire' creates assonance.
#
# 9. "Do not forget! Do not forget us!" - the 'o' sound in 'do' and 'not' creates assonance.

# %%
print(prompt_en03)
# Out:
# Here is a definition of assonance: Assonance is the repetition of identical or similar phonemes in words or syllables that occur close together
# in terms of their vowel phonemes (e.g. lean green meat). Note that identical vowels do not always imply same phonems. The 'o'-sound in 'often' and 'other' does not produce the same phonem.
# Using this definition, give a full description of all assonances in this poem:
#
# From west and east, from north and south
# Many feet will soon be dragging themselves wearily,
# Feet, sore and torn from walking,
# Slowly set to the earth,
# Toil in the trembling moonlight
# Restlessly deep into Germany.
# And who with listening ear still wakes
# Hears them in every growing night,
# Hears this shuffling so weary and heavy,
# Hears a lament full of wild desire,
# A lamentation full of pain:
# Only do not forget! Do not forget us!
# .
#
# Explain in each case the assonance by repeating the words and by giving the common vowel.
# Use the following form in your answer: 'Dem Nordmann schwinden die Sorgen' - the 'o' sound in 'Nordmann' and 'Sorgen' creates assonance.

# %%
# %%ai gpt4o
# {prompt_en03}
# Out:
# 1. "From west and east, from north and south" - the 'o' sound in 'from', 'north', and 'south' creates assonance.
# 2. "Many feet will soon be dragging themselves wearily," - the 'ee' sound in 'feet', 'be', 'wearily' creates assonance.
# 3. "Feet, sore and torn from walking," - the 'o' sound in 'sore' and 'torn' creates assonance.
# 4. "Slowly set to the earth," - the 'o' sound in 'slowly' and 'to' creates assonance.
# 5. "Toil in the trembling moonlight" - the 'o' sound in 'toil' and 'moonlight' creates assonance.
# 6. "Restlessly deep into Germany." - the 'e' sound in 'Restlessly' and 'deep' creates assonance.
# 7. "And who with listening ear still wakes" - the 'e' sound in 'listening' and 'ear' creates assonance.
# 8. "Hears them in every growing night," - the 'e' sound in 'them' and 'every' creates assonance.
# 9. "Hears this shuffling so weary and heavy," - the 'e' sound in 'weary' and 'heavy' creates assonance.
# 10. "Hears a lament full of wild desire," - the 'a' sound in 'lament' and 'desire' creates assonance.
# 11. "A lamentation full of pain:" - the 'a' sound in 'lamentation' and 'pain' creates assonance.
# 12. "Only do not forget! Do not forget us!" - the 'o' sound in 'not' and 'forget' creates assonance.

# %%
print(prompt01)

printmd(gemini(prompt01))
# Out:
# Here is a definition of assonance: Assonance is a similarity in sound between two stressed syllables
# that are close together in a text, created by the same vowels but different consonants .
# Using this definition, give a full description of all assonances in this poem:
#
# Von Westen und Osten, von Nord und Süd
# Schleppen sich nächtens viele Füße müd,
# Füße, vom Wandern wund und zerfetzt,
# Langsam bedächtig zur Erde gesetzt,
# Müh'n sich im zitternden Mondenschein
# Rastlos tief nach Deutschland hinein.
# Und wer mit lauschendem Ohr noch wacht
# Hört sie in jedweder werdenden Nacht,
# Hört dies Schlurfen so müde und schwer,
# Hört eine Klage voll wilder Begehr,
# Eine Klage schmerzzerfressen:
# Nur nicht vergessen! Uns nicht vergessen!
# .
#
# Explain in each case the assonance by repeating the words and by giving the common vowel.
# Use the following form in your answer: 'Dem Nordmann schwinden die Sorgen' - the 'o' sound in 'Nordmann' and 'Sorgen' creates assonance.
# Here are the assonances in the poem, following the requested format:
#
# * **Von Westen und Osten** - the 'o' sound in 'Von' and 'Osten' creates assonance.
# * **Von Nord und Süd** - the 'u' sound in 'Nord' and 'Süd' creates assonance. (Note: while the spelling differs, the vowel sound is the same in German.)
# * **Schleppen sich nächtens viele Füße müd** - the long 'ü' sound in 'Füße' and 'müd' creates assonance.
# * **Füße, vom Wandern wund und zerfetzt** - the 'u' sound in 'wund' and 'und' creates assonance.  (Note: while the spelling differs, the vowel sound is the same in German.)
# * **Langsam bedächtig zur Erde gesetzt** -  the 'e' sound in 'Erde' and 'gesetzt' creates assonance.
# * **Müh'n sich im zitternden Mondenschein** - the 'i' sound in 'sich' and 'im' creates assonance.
# * **Rastlos tief nach Deutschland hinein** - the long 'ei' sound in 'Deutschland' and 'hinein' creates assonance.
# * **Und wer mit lauschendem Ohr noch wacht** - the 'o' sound in 'Ohr' and 'noch' creates assonance.
# * **Hört sie in jedweder werdenden Nacht** - the 'e' sound in 'jedweder' and 'werdenden' creates assonance.
# * **Hört dies Schlurfen so müde und schwer** - the 'u' sound in 'Schlurfen' and 'und' creates assonance. (Note: while the spelling differs, the vowel sound is the same in German.)
# * **Hört eine Klage voll wilder Begehr** - the 'ei' sound in 'eine' and 'wilder' creates assonance.  (Though the spelling differs slightly, the sound is the same in this context in German). The 'e' sound in 'wilder' and 'Begehr' also creates assonance.
# * **Nur nicht vergessen! Uns nicht vergessen!** - the 'e' sound in 'nicht' and 'vergessen' creates assonance (occurs twice).
#
# It is important to note that this analysis relies on the sounds of the words in spoken German, not just the written letters.

# %%
printmd(gemini({prompt02}))
# Out:
# Here's a breakdown of the assonance in the poem, using the requested format:
#
# * **"Von Westen und Osten"** - The 'o' sound in 'Von' and 'Osten' creates assonance.  Note: While "Westen" also contains an "o", it's a different sound (more like the "o" in "off") and therefore doesn't participate in this assonance.
# * **"Von Nord und Süd"** - The 'u' sound in 'Nord' and 'Süd' creates assonance. (The German 'u' with an umlaut (ü) is pronounced similarly to the long 'u' as in 'shoe'.)
# * **"Schleppen sich nächtens viele Füße müd"** -  The 'ie' sound (long 'e') in 'viele' and 'Füße' creates assonance.
# * **"Füße, vom Wandern wund und zerfetzt"** - The 'u' sound in 'Füße', 'wund', and 'und' creates assonance.
# * **"Langsam bedächtig zur Erde gesetzt"** - The 'e' sound (short 'e' like in 'bed') in 'Erde' and 'gesetzt' creates assonance.
# * **"Müh'n sich im zitternden Mondenschein"** - The 'i' sound in 'sich', 'im', and 'zittern' creates assonance.  Note: The 'i' in "im" is short and closed, while the 'i' in "zittern" and "sich" is long and open. They are close enough to be considered assonance, although not a perfect match.
# * **"Rastlos tief nach Deutschland hinein"** - The 'ei' sound (long 'i') in 'Deutschland' and 'hinein' creates assonance.
# * **"Und wer mit lauschendem Ohr noch wacht"** - The 'o' sound in 'Ohr' and 'noch' creates assonance.
# * **"Hört sie in jedweder werdenden Nacht"** - The 'e' sound (short 'e' like in 'bed') in 'jedweder' and 'werdenden' creates assonance.
# * **"Hört dies Schlurfen so müde und schwer"** - The 'u' sound in 'Schlurfen' and 'und' creates assonance.
# * **"Hört eine Klage voll wilder Begehr"** -  The 'ei' sound in 'eine' and 'Begehr' creates assonance. Note that this sound is realized as 'ai' in 'eine'.
# * **"Eine Klage schmerzzerfressen"** - The 'e' sound (short 'e' like in 'bed') in 'schmerz' and 'zerfressen' creates assonance.
# * **"Nur nicht vergessen! Uns nicht vergessen!"** - The 'e' sound (short 'e' like in 'bed') in 'vergessen' (both instances) creates assonance.
#
#
# It's important to note that the perception of assonance can sometimes be subjective, especially across languages.  These examples represent a thorough analysis based on the provided definition and standard German pronunciation.

# %%
printmd(gemini(prompt03))
# Out:
# Here are the instances of assonance in the poem, following the requested format:
#
# * **"Von Westen und Osten"** - the short 'o' sound (as in "cot") in "Von" and "Osten" creates assonance.  Note: While "Westen" also has an 'o', it's a different sound, a long 'o' as in "boat," so it doesn't participate in this assonance.
# * **"Von Nord und Süd"** - the short 'u' sound (similar to the 'oo' in "good") in "und" and "Süd" creates assonance.
# * **"Schleppen sich nächtens viele Füße müd"** -  The long 'ü' sound (similar to the 'ee' in "see" but rounded) in "Füße" and "müd" creates assonance.
# * **"Füße, vom Wandern wund und zerfetzt"** - The short 'u' sound (as in "good") in "wund" and "und" creates assonance.
# * **"Langsam bedächtig zur Erde gesetzt"** - The 'e' sound (as in "bed") in "Erde" and "gesetzt" creates assonance.
# * **"Müh'n sich im zitternden Mondenschein"** -  The long 'i' sound (similar to "ee" in "see") in "sich" and "im" creates assonance.
# * **"Rastlos tief nach Deutschland hinein"**  - The long 'ei/ai' diphthong (as in "eye") in  "Deutschland" and "hinein" creates assonance.
# * **"Und wer mit lauschendem Ohr noch wacht"** -  The 'o' sound (as in "hot") in "noch" and "wacht" creates assonance.
# * **"Hört sie in jedweder werdenden Nacht"** - The 'e' sound (as in "bed") in "jedweder" and "werdenden" creates assonance.
# * **"Hört dies Schlurfen so müde und schwer"**  -  The long 'ü' sound (similar to "ee" in "see" but rounded) in "müde" and "Schlurfen" creates assonance.
# * **"Hört eine Klage voll wilder Begehr"** - The 'e' sound (as in "bed") in "Begehr" and "wer" (from the previous line) creates assonance, though spanning lines. It also creates assonance with "werdenden" and "jedweder" from two lines prior.
# * **"Eine Klage schmerzzerfressen"** - The short 'e' sound (as in "bed") in "schmerzzerfressen" and "gesetzt" (from a previous line) creates assonance, though spanning lines.
# * **"Nur nicht vergessen! Uns nicht vergessen!"** - The long 'e' sound (as in "say") in "vergessen" (both instances) creates assonance. Note: While identical, this 'e' sound is *not* the same as the 'e' in "gesetzt," "Begehr," "jedweder," or "werdenden" noted above.
#
#
# It is important to note that in German, vowel pronunciation can be affected by regional dialects and variations. This analysis relies on standard German pronunciation.

# %%
printmd(gemini(prompt_en01))
# Out:
# * **"From west and east"** - the short 'e' sound in 'west' and 'east' creates assonance.
# * **"Many feet will soon be dragging themselves wearily"** -  the long 'e' sound in 'feet' and 'wearily' creates assonance.
# * **"Feet, sore and torn"** - the 'or' sound in 'sore' and 'torn' creates assonance. (Note: While the vowel combination is different, the sound produced is the same, fitting the definition.)
# * **"Slowly set to the earth"** - the short 'e' sound in 'set' and 'earth' creates assonance.
# * **"Toil in the trembling moonlight"** - the 'oi' sound in 'toil' and 'moonlight' creates assonance.
# * **"Restlessly deep into Germany"** - the long 'e' sound in 'Restlessly' and 'deep' creates assonance.
# * **"And who with listening ear still wakes"** - the long 'e' sound in 'ear'  and 'wakes' creates assonance.
# * **"Hears them in every growing night"** - the long 'o' sound in 'growing' and 'night' creates assonance.
# * **"Hears this shuffling so weary and heavy"** - the short 'e' sound in 'weary' and 'heavy' creates assonance.
# * **"Hears a lament full of wild desire"** - the long 'i' sound in 'wild' and 'desire' creates assonance.
# * **"A lamentation full of pain"** - the long 'a' sound in "lamentation" and "pain" creates assonance.
#
#
# It is important to note that different dialects and accents may affect the perceived vowel sounds, and thus whether certain pairings constitute assonance might be debatable.  This analysis uses a standard American English pronunciation.

# %%
printmd(gemini(prompt_en02))
# Out:
# * **"From west and east"** - the short 'e' sound in 'west' and 'east' creates assonance.
# * **"Many feet will soon be dragging themselves wearily"** -  the long 'e' sound in 'feet', 'be', and 'wearily' creates assonance.
# * **"Feet, sore and torn from walking"** - the 'or' sound in 'sore' and 'torn' creates assonance.  (Note: This is technically described as an assonantal consonant cluster since both the vowel and consonant sound are repeated. Pure assonance involves only the vowel sound.)
# * **"Slowly set to the earth"** - the short 'e' sound in 'set' and 'earth' creates assonance.
# * **"Toil in the trembling moonlight"** - the 'oi' sound in 'toil' and 'moonlight' creates assonance.
# * **"Restlessly deep into Germany"** - the long 'e' sound in  'restlessly', 'deep', and 'Germany' creates assonance.
# * **"And who with listening ear still wakes"** - the short 'i' sound in 'with', 'listening', and 'still' creates assonance.
# * **"Hears them in every growing night"** - the long 'e' sound in 'hears' and 'ear' creates assonance.  The long 'i' sound in 'nigh't and 'li'stening (from previous line, demonstrating assonance across lines) also resonates.
# * **"Hears this shuffling so weary and heavy"** -  the short 'e' sound in 'heavy' and 'weary' creates assonance.
# * **"Hears a lament full of wild desire"** - The long 'i' sound in 'wild' and 'desire' creates assonance.
# * **"A lamentation full of pain"** - the long 'a' sound in "lamentation" and "pain" creates assonance.
# * **"Only do not forget! Do not forget us!"** - the short 'o' sound in 'not' and 'forget' creates assonance. The "uh" sound in "us" and "forget" also creates assonance.

# %%
printmd(gemini(prompt_en03))
# Out:
# * **"From west and east"** - the short 'e' sound in 'west' and 'east' creates assonance.
# * **"Many feet will soon be dragging themselves wearily"** -  the long 'e' sound in 'feet', 'be', and 'wearily' creates assonance.
# * **"Feet, sore and torn from walking"** - the 'or' sound in 'sore' and 'torn' creates assonance. (Note: While the spellings differ, the vowel sounds are similar enough to be considered assonance.)
# * **"Slowly set to the earth"** -  the short 'e' sound in 'set' and 'earth' creates assonance.
# * **"Toil in the trembling moonlight"** - the 'oi' sound in 'toil' and 'moonlight' creates assonance.
# * **"Restlessly deep into Germany"** -  the long 'e' sound in 'restlessly' and 'deep' creates assonance.
# * **"And who with listening ear still wakes"** - the short 'i' sound in 'with', 'listening', and 'still' creates assonance.
# * **"Hears them in every growing night"** -  the long 'e' sound in 'hears' and 'ear' and the long 'i' in 'night' creates assonance.
# * **"Hears this shuffling so weary and heavy"** - the short 'e' sound in 'heavy' and 'weary' creates assonance.
# * **"Hears a lament full of wild desire"** - the 'i' sound in 'wild' and 'desire' creates assonance.
# * **"A lamentation full of pain"** - the long 'a' sound in 'lamentation' and 'pain' creates assonance.
# * **"Only do not forget! Do not forget us!"** - the short 'o' sound in 'not' and 'forget' creates assonance.

# %%
# %%ai opus
# {prompt01}
# Out:
# Certainly! Let's identify and explain the assonances in the poem provided, focusing on the repetition of vowel sounds:
#
# 1. "With yellow pears hangs" - the 'e' sound in "yellow" and "pears" creates assonance.
# 2. "And full of wild roses" - the 'o' sound in "of" and "roses" creates assonance.
# 3. "O lovely swans" - the 'o' sound in "O" and "lovely" creates assonance.
# 4. "And drunk with kisses" - the 'i' sound in "with" and "kisses" creates assonance.
# 5. "Into the sacred-sober water" - the 'o' sound in "sober" and "water" creates assonance.
# 6. "Alas, where shall I find" - the 'a' sound in "Alas" and "shall" creates assonance.
# 7. "When winter comes, flowers, and where" - the 'o' sound in "comes" and "flowers" creates assonance.
# 8. "And the shadows of Earth" - the 'a' sound in "shadows" and "Earth" creates assonance.
# 9. "The walls stand" - the 'a' sound in "walls" and "stand" creates assonance.
# 10. "Weathervanes clatter" - the 'a' sound in "weathervanes" and "clatter" creates assonance.
#
# These repetitions of vowel sounds contribute to the musical quality of the poem.

# %%
# %%ai opus
# {prompt02}
# Out:
# Here are all assonances in the poem:
#
# 'Westen' and 'Osten' - the 'e' sound creates assonance
# 'Füße' and 'müd' - the 'ü' sound creates assonance
# 'müh'n' and 'tief' - the 'i' sound creates assonance
# 'wacht' and 'Nacht' - the 'a' sound creates assonance
# 'Klage' and 'vergessen' - the 'e' sound creates assonance
#
# There's also a notable repetition of assonance through the recurring words:
# 'vergessen' and 'vergessen' - the 'e' sound is repeated
# 'Klage' and 'Klage' - the 'a' and 'e' sounds are repeated

# %%
# %%ai opus
# {prompt03}
# Out:
# Here are all assonances in the poem:
#
# "Westen" and "gesetzt" - the 'e' sound creates assonance
# "Füße" and "müd" - the 'ü' sound creates assonance
# "wund" and "Füße" - the 'u'/'ü' sound creates assonance
# "müh'n" and "tief" - the 'ie' sound creates assonance
# "Ohr" and "wacht" - the 'o'/'a' sound creates assonance
# "Hört" and "schwer" - the 'ö'/'e' sound creates assonance
# "Klage" and "schmerzzerfressen" - the 'a'/'e' sound creates assonance
# "vergessen" and "vergessen" - the 'e' sound creates assonance (repeated word)

# %%
# %%ai opus
# {prompt_en01}
# Out:
# Here are all assonances in the poem, following the definition:
#
# "south" and "soon" - the 'ou' sound creates assonance
# "feet" and "wearily" - the 'ee' sound creates assonance
# "torn" and "walking" - the 'o' sound creates assonance
# "toil" and "moonlight" - the 'oi/i' sound creates assonance
# "deep" and "weary" - the 'ee' sound creates assonance
# "hears" and "weary" - the 'ea' sound creates assonance
# "wild" and "desire" - the 'i' sound creates assonance
# "pain" and "lamentation" - the 'ai' sound creates assonance

# %%
# %%ai opus
# {prompt_en02}
# Out:
# Here are all assonances in the poem:
#
# "feet" and "wearily" - the 'ee' sound creates assonance
# "torn" and "north" - the 'o' sound creates assonance
# "south" and "toil" - the 'ou/oi' sound creates assonance
# "trembling" and "deep" - the 'ee' sound creates assonance
# "listening" and "still" - the 'i' sound creates assonance
# "weary" and "heavy" - the 'ee' sound creates assonance
# "wild" and "desire" - the 'ai' sound creates assonance
# "pain" and "lamentation" - the 'ai' sound creates assonance
# "forget" and "heavy" - the 'e' sound creates assonance

# %%
# %%ai opus
# {prompt_en03}
# Out:
# Here are all assonances in the poem:
#
# "feet" and "wearily" - the 'ee' sound creates assonance
# "torn" and "walking" - the 'o' sound creates assonance
# "toil" and "moonlight" - the 'oo' sound creates assonance
# "wakes" and "lamentation" - the 'a' sound creates assonance
# "heavy" and "desire" - the 'e' sound creates assonance
# "forget" and "forget" - the 'e' sound creates assonance (repetition)
#
# Note: Due to potential variations in pronunciation and the fact that this might be a translation from German, some of these assonances might be debatable.

# %% [markdown]
# # Task 2: Epert communication: interpretation based on assonances

# %%
prompt_expert = f"""Perform the following task in two steps. 
Step 1: {prompt04_ipa}
Step 2: Based on step 1, give an interpretation of the poem that takes into account the connections and contrast between the semantic fields that 
are grouped by the different assonances.
"""

# %%
# %%ai gpt4o
# {prompt_expert}
# Out:
# Step 1:
# IPA Translation:
# 1. Von Westen und Osten, von Nord und Süd
# [vɔn ˈvɛstn̩ ʊnt ˈɔstn̩, vɔn nɔʁt ʊnt zyːt]
# 2. Schleppen sich nächtens viele Füße müd,
# ˈʃlɛpn̩ zɪç ˈnɛçtn̩s ˈfiːlə ˈfyːsə myːt]
# 3. Füße, vom Wandern wund und zerfetzt,
# [ˈfyːsə, fɔm ˈvandɐn vʊnt ʊnt tsɛʁˈfɛtst]
# 4. Langsam bedächtig zur Erde gesetzt,
# [ˈlaŋzaːm bəˈdɛçtɪç tsuːɐ̯ ˈeːʁdə gəˈzɛtst]
# 5. Müh'n sich im zitternden Mondenschein
# [myːn̩ zɪç ʔɪm ˈtsɪtɐndn̩ ˈmoːdn̩ʃaɪn]
# 6. Rastlos tief nach Deutschland hinein.
# [ˈʁastloːs tiːf naːx ˈdɔʏtʃlant hɪˈnaɪn]
# 7. Und wer mit lauschendem Ohr noch wacht
# [ʊnt veːɐ̯ mɪt ˈlaʊʃndəm oːɐ̯ nɔx ˈvaxt]
# 8. Hört sie in jedweder werdenden Nacht,
# [høːɐ̯t ziː ʔɪn ˈjeːdˌveːdɐ ˈveːɐ̯dən də ˈnaxt]
# 9. Hört dies Schlurfen so müde und schwer,
# [høːɐ̯t diːs ˈʃlʊʁfn̩ zoː ˈmyːdə ʊnt ʃveːɐ̯]
# 10. Hört eine Klage voll wilder Begehr,
# [høːɐ̯t ˈʔaɪ̯nə ˈklaːɡə fɔl ˈvɪldɐ bəˈɡeːɐ̯]
# 11. Eine Klage schmerzzerfressen:
# [ˈʔaɪ̯nə ˈklaːɡə ˈʃmɛʁtst͡sɛʁˌfʁɛsn̩]
# 12. Nur nicht vergessen! Uns nicht vergessen!
# [nuːɐ̯ nɪçt fɛɐ̯ˈɡɛsn̩ ʔʊns nɪçt fɛɐ̯ˈɡɛsn̩]
#
# Assonances Analysis:
# - Line 1: 'vɔstn̩' and 'nɔʁt' - the 'o' sound creates assonance.
# - Line 2: 'ˈfiːlə' and 'ˈfyːsə' - the 'iː/yː' sound creates assonance.
# - Line 3: 'ˈfyːsə' and 'ˈvʊnt' - the 'ʊ' sound creates assonance.
# - Line 5: 'myːn̩' and 'ˈfyːsə' (from line 2) - the 'yː' sound creates assonance.
# - Line 8: 'ˈjeːdˌveːdɐ' and 'ˈveːɐ̯dən' - the 'eː' sound creates assonance.
# - Line 11: 'ˈʔaɪ̯nə' and 'ˈklaːɡə' - the 'aː' sound creates assonance.
#
# Step 2:
# The poem's assonances create clusters of sound that highlight the themes of movement and longing. The 'o' sound in 'vɔstn̩' and 'nɔʁt' may emphasize the vast geographical and emotional distance. The repetition of the 'yː' sound in 'ˈfiːlə', 'ˈfyːsə', and 'myːn̩' underscores weariness and continuity of the movement, hinting at a relentless journey. The 'eː' sound in 'ˈjeːdˌveːdɐ' and 'ˈveːɐ̯dən' connects the inevitability of night and the listening, drawing attention to the timeless nature of the unheard cries. These assonances collectively echo a melancholic plea for remembrance and acknowledgment, weaving a rich tapestry of longing and hope amidst struggle.

# %%
printmd(gemini(prompt_expert))
# Out:
# **Step 1: IPA Translation and Assonance Analysis**
#
# Here's the poem translated into IPA, using a standard German pronunciation:
#
# [fɔn ˈvɛstn̩ ʊnt ˈɔstn̩, fɔn nɔʁt ʊnt zyːt]
# [ˈʃlɛpn̩ zɪç ˈnɛçtn̩s ˈfiːlə ˈfyːsə myːt]
# [ˈfyːsə, fɔm ˈvandɐn vʊnt ʊnt tsɛɐ̯ˈfɛtst]
# [ˈlaŋzam bəˈdɛçtɪç tsʊɐ̯ ˈeːɐ̯də gəˈzɛtst]
# [ˈmyːn zɪç ɪm ˈtsɪtɐndən ˈmoːnʃaɪn]
# [ˈʁastloːs tiːf naːx ˈdɔʏtʃlant haɪˈnaɪn]
# [ʊnt veːɐ̯ mɪt ˈlaʊʃəndəm ˈoːɐ̯ nɔx vaxt]
# [høːɐ̯t ziː ɪn ˈjeːdvɛdɐ ˈveːɐ̯dəndən naxt]
# [høːɐ̯t diːs ˈʃlʊʁfn̩ zoː ˈmyːdə ʊnt ʃveːɐ̯]
# [høːɐ̯t ˈaɪnə ˈklaːɡə fɔl ˈvɪldɐ bəˈɡeːɐ̯]
# [ˈaɪnə ˈklaːɡə ˈʃmɛʁtsˌtsɛɐ̯fʁɛsn̩]
# [nuːɐ̯ nɪçt fɛɐ̯ˈɡɛsn̩! ʊns nɪçt fɛɐ̯ˈɡɛsn̩!]
#
#
# Now, let's analyze the assonances:
#
# * **[ɔ]**:  `[fɔn ˈvɛstn̩ ʊnt ˈɔstn̩]` - the 'o' sound in 'Von' and 'Osten' creates assonance.
# * **[ɔ]**: `[fɔn nɔʁt ʊnt zyːt]`- the 'o' sound in 'von' and 'Nord' creates assonance.
# * **[yː]**: `[ˈfyːsə myːt]` - the 'ü' sound in 'Füße' and 'müd' creates assonance.
# * **[yː]**: `[ˈfyːsə, fɔm ˈvandɐn vʊnt ʊnt tsɛɐ̯ˈfɛtst]` - the 'ü' sound in 'Füße' and 'wund' creates assonance.
# * **[eː]**: `[tsʊɐ̯ ˈeːɐ̯də gəˈzɛtst]` - the 'e' sound in 'Erde' and 'gesetzt' creates assonance.
# * **[ɪ]**: `[ˈmyːn zɪç ɪm ˈtsɪtɐndən ˈmoːnʃaɪn]` - the 'i' sound in 'sich' and 'im' creates assonance.
# * **[ɪ]**: `[zɪç ɪm ˈtsɪtɐndən]` - the 'i' sound in 'sich', 'im', and 'zitternden' creates assonance.
# * **[aɪ̯]**: `[haɪˈnaɪn]` - the 'ei' sound in 'hinein' creates internal assonance.
# * **[oː]**: `[mɪt ˈlaʊʃəndəm ˈoːɐ̯ nɔx vaxt]` - the 'o' sound in 'Ohr' and 'noch' creates assonance.
# * **[øː]**: `[høːɐ̯t ziː ɪn ˈjeːdvɛdɐ ˈveːɐ̯dəndən naxt]` - the 'ö' sound in 'Hört' and 'jeder' and 'werdenden' creates assonance.
# * **[yː]**: `[ˈʃlʊʁfn̩ zoː ˈmyːdə ʊnt ʃveːɐ̯]`- the 'ü' sound in 'müde' creates assonance with previous instances of 'ü'.
# * **[eː]**: `[bəˈɡeːɐ̯]` - the 'e' sound in 'Begehr' creates assonance with previous instances of 'e'.
# * **[ɛ]**: `[fɛɐ̯ˈɡɛsn̩! ʊns nɪçt fɛɐ̯ˈɡɛsn̩!]` - the 'e' sound in 'vergessen' creates internal assonance and assonance with the repeated phrase.
#
#
# **Step 2: Interpretation**
#
# The poem describes the weary march of many feet into Germany, presumably refugees or displaced persons. The assonances contribute to the overall melancholic and urgent tone.
#
# * **[yː] (ü) sound**: Connects the physical suffering ("Füße," "müd," "wund") of the travelers with their movement.  This reinforces the arduousness of their journey.
# * **[ɔ] and [oː] (o and oh sounds)**: These sounds appear primarily in words relating to direction and perception ("Von," "Osten," "Nord," "Ohr," "noch"). This might suggest a sense of disorientation and a desperate need to be heard.
# * **[eː] (e sound)**: Links the destination ("Erde," "gesetzt," "Begehr") and the desperate plea at the end ("vergessen"). This emphasizes the profound desire of these travelers to find a place and not be forgotten.
# * **[aɪ̯] (ei sound in "hinein")**:  The internal assonance here highlights the inward movement, the penetration into Germany, almost as if seeking refuge within.
#
# The contrasting sounds, particularly the sharper [ɪ] sounds (zitternden, im, sich) against the broader [ɔ] and [oː] sounds and the [yː] sounds, create a sonic texture that mirrors the emotional turmoil and uncertainty experienced by those described in the poem. The repetition of "vergessen" with its internal assonance and connection to the earlier [eː] sounds emphasizes the central theme of remembrance and the fear of being forgotten, which is paramount for these displaced individuals.

# %%
# %%ai opus
# {prompt_expert}
# Out:
# Step 1:
# First, IPA translation (simplified):
# fɔn vɛstən ʊnt ɔstən, fɔn nɔrt ʊnt zyːt
# ʃlɛpən zɪç nɛçtəns fiːlə fyːsə myːd
# fyːsə, fɔm vandərn vʊnt ʊnt tsɛrfɛtst
# laŋzaːm bədɛçtɪç tsʊr ɛrdə gəzɛtst
# myːn zɪç ɪm tsɪtərndən moːndənʃaɪn
# rastloːs tiːf naːx dɔʏtʃlant hɪnaɪn
# ʊnt veːr mɪt laʊʃəndəm oːr nɔx vaxt
# høːrt ziː ɪn jeːdveːdɐ veːrdəndən naxt
# høːrt diːs ʃlʊrfən zoː myːdə ʊnt ʃveːr
# høːrt aɪnə klaːgə fɔl vɪldɐ bəgeːr
# aɪnə klaːgə ʃmɛrtstserfrɛsən
# nʊr nɪçt fɛrgɛsən! ʊns nɪçt fɛrgɛsən!
#
# Main assonances:
# - The [yː] sound in "Füße" and "müd" creates assonance
# - The [eː] sound in "wer" and "werdenden" creates assonance
# - The [ɛ] sound in "zerfetzt", "gesetzt", "vergessen" creates assonance
# - The [aː] sound in "Klage" and "Mondenschein" creates assonance
# - The [iː] sound in "tief" and "sie" creates assonance
#
# Step 2:
# The assonances create meaningful connections between key semantic fields:
# 1. The [yː] sound connects physical exhaustion ("müd") with the body part ("Füße"), emphasizing the physical toll
# 2. The [eː] sound links consciousness/awareness ("wer") with becoming/transformation ("werdenden")
# 3. The [ɛ] sound ties destruction ("zerfetzt") with settling ("gesetzt") and forgetting ("vergessen"), creating a progression from violence to potential oblivion
# 4. The [aː] sound connects natural light ("Mondenschein") with human suffering ("Klage"), contrasting nature's indifference with human pain
# 5. The [iː] sound links depth ("tief") with identity ("sie"), suggesting profound existential concerns
#
# These sound patterns reinforce the poem's central theme of displaced people struggling against both physical hardship and the threat of being forgotten.

# %% [markdown]
# # Task 3: Abstraction-Transfer
# ## 3.a Counterfactual Assonances: The notion of "eusonance": Detecting eusonances

# %%
eusonance = """Eusonance occurs when the vowel sounds of the stressed syllables in two consecutive words in the same line are a German i-sound and a German e-sound. 
The order between the i sound and the e sound does not matter.
Monosyllabic words always count as words with a stressed syllable
(e.g. "Ich" and "esse" in "Ich esse Kuchen")."""

# %%
prompt_eusonance = f"""Here is a definition of Eusonance: {eusonance}. 
Using this definition, give a full description of all eusonances in this poem: \n {poem_2.text} \n
Explain in each case the eusonance by repeating the words and by giving the common vowel.
Use a two-step reasoning: Firstly, translate the poem to IPA. Secondly, perform the requested analysis of eusonances based on the IPA-translation.
Use the following form in the second step of your answer: 'Dem Nichts schwindet die Sorge' - the 'i' sound and the 'e' sound in 'Dem' and 'Nichts' creates eusonance."""

# %% [markdown]
# # gold standard eusonance
# Z. 2 sich nächtens
# Z. 7 in jedweden
# Z. 12 nicht vergessen

# %%
# %%ai gpt4o
# {prompt_eusonance}
# Out:
# Certainly. Let's begin with the IPA transcription of the poem:
#
# 1. Von Westen und Osten, von Nord und Süd
#    /fɔn ˈvɛstən ʊnt ˈɔstən fɔn nɔrt ʊnt zyːt/
#
# 2. Schleppen sich nächtens viele Füße müd,
#    /ˈʃlɛpən zɪç ˈnɛçtəns ˈfiːlə ˈfyːsə myːt/
#
# 3. Füße, vom Wandern wund und zerfetzt,
#    /ˈfyːsə fɔm ˈvandɐn vʊnt ʊnt tsɛrˈfɛtst/
#
# 4. Langsam bedächtig zur Erde gesetzt,
#    /ˈlaŋzaːm bəˈdɛçtɪç tsuːr ˈeːrdə gəˈzɛtst/
#
# 5. Müh'n sich im zitternden Mondenschein
#    /myːn zɪç ɪm ˈtsɪtɐndən ˈmoːdənaɪn/
#
# 6. Rastlos tief nach Deutschland hinein.
#    /ˈʀastloːs tiːf naːx ˈdɔʏ̯tʃlant hɪˈnaɪn/
#
# 7. Und wer mit lauschendem Ohr noch wacht
#    /ʊnt veːɐ̯ mɪt ˈlaʊ̯ʃəndəm oːɐ̯ nɔx vaxt/
#
# 8. Hört sie in jedweder werdenden Nacht,
#    /høːɐ̯t ziː ɪn ˈjeːdveːdɐ veːɐ̯dəndən naxt/
#
# 9. Hört dies Schlurfen so müde und schwer,
#    /høːɐ̯t diːs ˈʃlʊrfn̩ zoː ˈmyːdə ʊnt ʃveːɐ̯/
#
# 10. Hört eine Klage voll wilder Begehr,
#     /høːɐ̯t ˈaɪ̯nə ˈklaːgə fɔl ˈvɪldɐ bəˈɡeːɐ̯/
#
# 11. Eine Klage schmerzzerfressen:
#     /ˈaɪ̯nə ˈklaːgə ˈʃmɛʁtsˌtsɛʁˈfrɛsn̩/
#
# 12. Nur nicht vergessen! Uns nicht vergessen!
#     /nuːɐ̯ nɪçt fɛɐ̯ˈɡɛsn̩ ʊns nɪçt fɛɐ̯ˈɡɛsn̩/
#
# Now, let's analyze the eusonances based on this transcription:
#
# 1. Line 2: "sich nächtens viele" - the 'i' sound in "sich" and the 'e' sound in "viele" creates eusonance.
#
# 2. Line 8: "sie in jedweder" - the 'i' sound in "sie" and the 'e' sound in "jedweder" creates eusonance.
#
# 3. Line 9: "dies Schlurfen so müde" - the 'i' sound in "dies" and the 'e' sound in "müde" creates eusonance.
#
# These are the instances of eusonance found in the poem.

# %%
printmd(gemini(prompt_eusonance))
# Out:
# Here's the poem translated into IPA, using a standard German pronunciation:
#
# fɔn ˈvɛstn̩ ʊnt ˈɔstn̩, fɔn nɔʁt ʊnt zyːt
# ˈʃlɛpn̩ zɪç ˈnɛçtn̩s ˈfiːlə ˈfyːsə myːt,
# ˈfyːsə, fɔm ˈvandɐn vʊnt ʊnt tsɛɐ̯ˈfɛtst,
# ˈlaŋzam bəˈdɛçtɪç tsʊɐ̯ ˈeːɐ̯də gəˈzɛtst,
# ˈmyːn zɪç ɪm ˈtsɪtɐndən ˈmoːnʃaɪn
# ˈʁastloːs tiːf naχ ˈdɔʏtʃlant hiˈnaɪn.
# ʊnt veːɐ̯ mɪt ˈlaʊʃəndəm ˈoːɐ̯ nɔx vaxt
# ˈhøːɐ̯t ziː ɪn ˈjeːdvɛːdɐ ˈveːɐ̯dəndən naxt,
# ˈhøːɐ̯t diːs ˈʃlʊʁfn̩ zoː ˈmyːdə ʊnt ʃveːɐ̯,
# ˈhøːɐ̯t ˈaɪnə ˈklaːɡə fɔl ˈvɪldɐ bəˈɡeːɐ̯,
# ˈaɪnə ˈklaːɡə ˈʃmɛʁtsɛɐ̯ˌfrɛsn̩:
# nuːɐ̯ nɪçt fɛɐ̯ˈɡɛsn̩! ʊns nɪçt fɛɐ̯ˈɡɛsn̩!
#
#
# Now, let's analyze the eusonances based on the IPA transcription and the provided definition:
#
# * **ˈfyːsə fɔm** - The 'yː' sound in 'ˈfyːsə' and the 'ɔ' sound in 'fɔm' *do not* create eusonance.  The 'ɔ' is not a German 'e' sound.
# * **ˈmyːn zɪç** - The 'yː' sound in 'ˈmyːn' and the 'ɪ' sound in 'zɪç' *do not* create eusonance, as both vowels represent variations of the German i-sound.
# * **ziː ɪn** -  The 'iː' sound in 'ziː' and the 'ɪ' sound in 'ɪn' *do not* create eusonance, as both vowels represent variations of the German i-sound.
# * **ˈjeːdvɛːdɐ ˈveːɐ̯dəndən** - The 'eː' sound in 'ˈjeːdvɛːdɐ' and the 'eː' sound in 'ˈveːɐ̯dəndən' *do not* create eusonance, as both vowels represent the German e-sound, and the definition requires both 'i' and 'e' sounds.
#
#
# Therefore, there are no instances of eusonance in the poem according to the provided definition.  It is important to note that the definition is highly specific and relies on distinct German "i" and "e" sounds *in stressed syllables*.  Many near misses occur (like 'ˈmyːn zɪç'), but don't quite fulfill all the criteria.

# %%
# %%ai opus
# {prompt_eusonance}
# Out:
# Let me analyze this step by step:
#
# Step 1: Key IPA sections where potential eusonances occur:
# Line 1: [fɔn vɛstən ʊnt ɔstən fɔn nɔrt ʊnt zyːt]
# Line 2: [ʃlɛpən zɪç nɛçtəns fiːlə fyːsə myːt]
# Line 3: [fyːsə fɔm vandɐn vʊnt ʊnt tsɛrfɛtst]
# Line 4: [laŋzaːm bədɛçtɪç tsʊr eːrdə gəzɛtst]
# Line 5: [myːn zɪç ɪm tsɪtɐndən moːndənʃaɪn]
# Line 6: [rastloːs tiːf naːx dɔʏtʃlant hɪnaɪn]
# Line 7: [ʊnt veːr mɪt laʊʃəndəm oːr nɔx vaxt]
# Line 8: [høːrt ziː ɪn jeːdveːdɐ veːrdəndən naxt]
# Line 9: [høːrt diːs ʃlʊrfən zoː myːdə ʊnt ʃveːr]
# Line 10: [høːrt aɪnə klaːgə fɔl vɪldɐ bəgeːr]
# Line 11: [aɪnə klaːgə ʃmɛrtstsɛrfrɛsən]
# Line 12: [nuːr nɪçt fɛrgɛsən ʊns nɪçt fɛrgɛsən]
#
# Step 2: Eusonances found:
# - "sich nächstens" - the 'i' sound and 'e' sound in "sich" and "nächtens" creates eusonance (line 2)
# - "tief hinein" - the 'i' sound appears in both stressed syllables (line 6)
# - "dies schwer" - the 'i' sound and 'e' sound in "dies" and "schwer" creates eusonance (line 9)
# - "nicht vergessen" - appears twice in line 12, both times creating eusonance with the 'i' sound in "nicht" and the 'e' sound in "vergessen"

# %% [markdown]
# ## 3b: Inference of implicit rule and rule application
#
# implicit rule: find the two main assonance vowels and identify the central semantic field that connects both groups and the central semantic field constituing a central opposition.

# %%
prompt_transfer = f"""

Given the following definition: {assonance03}, 

infer the implicit rule of the following interpretation. Give an explicit formulation of that rule and apply it to the poem with the title "Unsere Toten": 
{poem_2.text}.

Here is the poem: Waldgespräch (1815)
Es ist schon spät, es wird schon kalt,
Was reit’st du einsam durch den Wald?
Der Wald ist lang, du bist allein,
Du schöne Braut! Ich führ’ dich heim!

„Groß ist der Männer Trug und List,
Vor Schmerz mein Herz gebrochen ist,
Wohl irrt das Waldhorn her und hin,
O flieh! Du weißt nicht, wer ich bin.“

So reich geschmückt ist Roß und Weib,
So wunderschön der junge Leib,
Jetzt kenn’ ich dich – Gott steh’ mir bei!
Du bist die Hexe Lorelei.

„Du kennst mich wohl – von hohem Stein
Schaut still mein Schloß tief in den Rhein.
Es ist schon spät, es wird schon kalt,
Kommst nimmermehr aus diesem Wald!“


In this poem, the two central assonances are the "a"-Laut in words like "Wald" and "kalt" on the one hand and the "ei"-Laut
in words like "Lorelei", "Rhein", "Weib", "reiten", "heim". Both groups are connected by the semantic of "Wald" and "Rhein" is
natural environments (forest as type of nature, the Rhein as an instance of a river), both being also symbols of 
the contemporary construction of national German identity in Romanticism. Lorelei as a personification of attraction and fatality is 
in this poem finally transferred to the imagination of the forest, which is, at the beginning of the poem, introduced as a harmless locus of
romantic loneliness. So, one of the word groups that are grouped by assonance (here: "ei") affects the meaning of the other group (here "a").

"""

# %%
printmd(gemini(prompt_transfer))
# Out:
# The implicit rule being used in this analysis of assonance can be formulated as follows:
#
# **Rule:**  If two distinct groups of words sharing assonance exist within a poem, and one group has a clear semantic connection to a central theme or motif, then the assonance links the semantic field of that group to the other group, potentially altering or enriching its meaning.
#
# More formally:
#
# Let A and B be two sets of words in a poem such that:
#
# 1. The words in A share assonance (assonance_A).
# 2. The words in B share a different assonance (assonance_B).
# 3. The words in A share a clear semantic connection to a theme or motif T.
#
# Then, the assonance implicitly links T to the semantic field of B, influencing the interpretation of B in the context of the poem.
#
#
# **Application to "Unsere Toten":**
#
#
# In "Unsere Toten," several assonance groups can be identified.  Let's examine two prominent ones:
#
# * **Group A ("ü" sound):**  Füße, müd, Süd, wund, Müh'n
# * **Group B ("ei" sound):**  hinein, Schein, hinein, Begehr
#
# **Theme/Motif (T) associated with Group A ("ü" sound):**  Physical exhaustion and suffering. The words "Füße," "müd," "wund" directly relate to the hardship of the journey.  "Müh'n" reinforces this sense of struggle. "Süd" (south) while a direction, is contextually part of the arduous journey from all directions.
#
# **Semantic field of Group B ("ei" sound):**  "hinein" indicates direction and penetration, "Schein" (shine) refers to the moonlight, and "Begehr" (desire) represents a strong yearning.
#
# **Applying the rule:**  The assonance linking the "ü" sounds (fatigue, suffering) to the "ei" sounds connects the theme of arduous journey and suffering (T) to the ideas of penetration, moonlight, and desire.  This suggests that the yearning and inward movement ("hinein") are fueled by the hardship of the journey, and the moonlight ("Schein") witnesses this struggle and longing.  The "Begehr" is not just any desire, but one born from exhaustion and the difficult journey.
#
#
# Therefore, the assonance doesn't merely create a pleasant sound effect, but actively shapes the meaning, implying that the desire expressed in the poem is directly linked to the hardship endured by the "Toten."

# %%
# %%ai gpt4o
# {prompt_transfer}
# Out:
# The implicit rule inferred from the interpretation seems to be that assonances can group words together by phonetic similarity, connecting them semantically or thematically within the poem. One group can influence or affect the meaning or interpretation of another group, especially if they are linked by a common thematic or symbolic context.
#
# Applying this rule to "Unsere Toten":
#
# Assonances in "Unsere Toten" include:
# - The "ü"-Laut in "müd," "Süd," "füße," "müh'n," "hört," "geh'r," "wird," and "Wald."
# - The "e"-Laut in "von," "Osten," "zerfetzt," "gesetzt," "erinnern," and "vergessen."
#
# The "ü"-Laut, often associated with weariness and movement ("müd," "füße," "müh'n"), ties together the theme of tireless persistence and the physical journey. The "e"-Laut, seen in words related to remembering and forgetting, suggests a thematic underpinning of memory and loss. The interplay between these assonances underscores the dual themes of relentless movement towards something (Germany) and the haunting plea not to be forgotten. The physical journey (linked by "ü") affects the emotional plea (linked by "e"), creating a complex interplay of action and remembrance.

# %%
# %%ai opus
# {prompt_transfer}
# Out:
# The implicit rule in this interpretation is: When analyzing assonance in German Romantic poetry, we should examine how different groups of assonant words create semantic networks that can interact with and transform each other's meanings through their thematic associations.
#
# This rule emphasizes that:
# 1. Assonant word groups should be analyzed for their semantic relationships
# 2. These semantic relationships can form larger thematic networks
# 3. Different assonant groups can influence each other's meaning through their symbolic interactions
#
# Applying this rule to "Unsere Toten":
#
# The main assonant groups are:
# 1. "ü/üh" sounds: (Füße, müd, müh'n)
# 2. "ei" sounds: (ein, hinein)
#
# These assonant groups create a semantic network around:
# - Physical exhaustion and pain (müd, Füße)
# - Movement and direction (hinein)
#
# The interaction between these sound patterns reinforces the poem's central theme of the dead soldiers' eternal march back to Germany, where the "ü" sounds emphasize their weariness and the "ei" sounds their determined direction, creating a haunting effect of endless, painful movement homeward.
