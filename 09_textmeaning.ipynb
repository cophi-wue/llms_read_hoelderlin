# %% [markdown]
# # Configuration

# %%
from definitions import poem_1, poem_2
import os
from utils import settings, gemini, ollama3, gpt4, opus, init_gemini

# %load_ext jupyter_ai_magics

# %%
#settings
temperature = 0.8
system_prompt = "You are an expert in German literature and you are addressing other experts in German literature. You answer the questions truthfully and short."

settings(system_prompt, temperature)

# %%
#defining aliases
init_gemini()

model =  ollama3()
# %ai register llama3big model

model =  gpt4()
# %ai register gpt4o model

model = opus()
# %ai register opus model
# Out:
# Registered new alias `opus`

# %% [markdown]
# ## Unsere Toten

# %% [markdown]
# Experiment: Context windows
#
# The context window determines the number of tokens the model can incorporate to predict the subsequent token.
#
# Munkhdalai et al. (2024): "An effective memory system is crucial not just for comprehending long contexts with LLMs, but also for reasoning, planning, continual adaptation for fresh knowledge, and even for learning how to learn."
#
# Challenges:  “needle-in-a-haystack” (Ivgi et al. 2023)
#
# Context windows for our models:
# Llama3:70b = 8.2k
# Gemini: 2M, 3000pages
# Opus Claud: 200k
# GPT4o: 128k
#
# (Kosten! evtl. nur Llama 3:70b und GPt4o)
#
# Could we force the LLM to say "this is the wrong context information"? Experiments with an unknown poem "Unsere Toten".
#
# Of particual interests:
# - studying how large and small context windows change the output
# - studying how LLM deal with wrong context information
# - determining the correct context information
#
# Prompt design:
# - context files: large Wikipedia entries World War I (64 Seiten), World War II (83 Seiten, 26.300 Wörter)

# %%
## Wrong contexts ("Horizontverschmelzung"), Beispiel "Unsere Toten"

prompt = f"""1. Read the following context information https://de.wikipedia.org/wiki/Erster_Weltkrieg and https://de.wikipedia.org/wiki/Zweiter_Weltkrieg, 2. Extract three key words, 3. Classify which context is more likely a) world war I, b) world war II. 'Von Westen und Osten, von Nord und Süd schleppen sich nächtens viele Füße müd, Füße, vom Wandern 
wund und zerfetzt, langsam bedächtig zur Erde gesetzt, müh'n sich im zitternden Mondenschein rastlos 
tief nach Deutschland hinein. Und wer mit lauschendem Ohr noch wacht hört sie in jedweder werdenden 
Nacht, hört dies Schlurfen so müde und schwer, hört eine Klage voll wilder Begehr, eine Klage 
schmerzzerfressen: nur nicht vergessen! Uns nicht vergessen!' Does this poem belong this context at all?"""
print (prompt)
# Out:
# 1. Read the following context information https://de.wikipedia.org/wiki/Erster_Weltkrieg and https://de.wikipedia.org/wiki/Zweiter_Weltkrieg, 2. Extract three key words, 3. Classify which context is more likely a) world war I, b) world war II. 'Von Westen und Osten, von Nord und Süd schleppen sich nächtens viele Füße müd, Füße, vom Wandern
# wund und zerfetzt, langsam bedächtig zur Erde gesetzt, müh'n sich im zitternden Mondenschein rastlos
# tief nach Deutschland hinein. Und wer mit lauschendem Ohr noch wacht hört sie in jedweder werdenden
# Nacht, hört dies Schlurfen so müde und schwer, hört eine Klage voll wilder Begehr, eine Klage
# schmerzzerfressen: nur nicht vergessen! Uns nicht vergessen!' Does this poem belong this context at all?

# %% [markdown]
# ### GPT4o

# %%
# %%ai gpt4o
# {prompt}
# Out:
# The three key words extracted from the provided context are:
# 1. Wandern (wandering)
# 2. Müd (tired)
# 3. Klage (lament)
#
# Classifying the context:
# a) World War I: The poem reflects themes of exhaustion, displacement, and lamentation, which are present in the aftermath of World War I. The imagery of people slowly and painfully moving suggests the return of soldiers and civilians affected by the war.
#
# Therefore, the poem is more likely to belong to the context of World War I.

# %% [markdown]
# ### Opus

# %%
# %%ai opus
# {prompt}
# Out:
# Keywords extracted from the context:
#
# 1. Erster Weltkrieg
# 2. Zweiter Weltkrieg
# 3. Deutschland
#
# The poem is more likely related to context a) World War I, based on the following reasons:
#
# 1. The poem mentions "Deutschland" (Germany), which was a key party in both World Wars.
# 2. The tone and imagery of the poem, with phrases like "Füße, vom Wandern wund und zerfetzt" (feet, sore and tattered from wandering) and "eine Klage voll wilder Begehr" (a lament full of wild desire), evoke the hardships and emotional turmoil experienced by soldiers and civilians during wartime.
# 3. The repeated plea "nur nicht vergessen! Uns nicht vergessen!" (just don't forget! Don't forget us!) suggests a fear of being forgotten, which could be more closely associated with the aftermath of World War I, as the war's devastation and loss of life were unprecedented at the time.
#
# However, without more specific contextual details within the poem, such as mentions of particular battles, political figures, or historical events, it is difficult to definitively attribute the poem to either World War I or World War II. The poem's themes of suffering, longing, and the desire to be remembered are universal to the experience of war and could apply to both contexts.

# %% [markdown]
# ### Gemini 1.5

# %%
gemini(prompt)
# Out:
# "I cannot access or read information from external websites or specific files online, including the Wikipedia links you provided. This limitation prevents me from fulfilling your request to:\n\n1. **Read the context information:** I cannot access external websites.\n2. **Extract three keywords:**  I need the context from the Wikipedia articles to determine relevant keywords.\n3. **Classify the context:**  Without understanding the content of the articles, I cannot classify them.\n4. **Determine the poem's relevance:**  I need the context of World War I and II from the articles to understand if the poem fits. \n\n**In general, here's how I would approach your request IF I had access to the internet:**\n\n1. **Access and process the Wikipedia articles.**\n2. **Identify three keywords:**  I'd look for terms central to each war, like major figures, battlegrounds, or defining concepts.\n3. **Analyze the poem:** I'd look for thematic and linguistic elements that might connect it to either war.\n4. **Compare and classify:** Based on the keywords and analysis, I'd determine which context (WWI or WWII) is more likely, or if the poem doesn't fit either. \n\n**Please feel free to provide me with the text from the Wikipedia articles. I'll gladly help you analyze the poem and answer your questions.** \n"

# %% [markdown]
# ### Llama3:70b

# %%
# %%ai llama3big
# {prompt}

# %% [markdown]
# ## Literary theories

# %% [markdown]
# Experiment: Representation of Literary and Cultural Theories in LLMs
#
# In literary studies, 'interpretation' is understood as the analysis of a literary text, particularly with regard to the (figurative) meaning of the text as a whole. The determination and identification of this overall meaning is guided by text-centred, author-centred, reader-centred and context-centred theories of literature and interpretation.
#
# Question: To what extend or which literary theory approach (if any) do language models reflect?
#
# Vergleichende Forschungsansätze: Ziems et al. 2024, Santurkar et al.  2023
#
# Of particular interest:
# - Representativeness: How aligned are the LLM interpretation with general literary approaches (hermeneutic, poststructuralism, feminst)?
# - Steerability: Can an LM emulate the interpretive hypothesis of a literary approach when appropriately prompted? For which approaches does this work particularly well?
# - Consistency: Are the interpretation expressed by LLMs consistent across topics?
#
# Hilfsmittel: Dictionaries von drei theoretischen Einführungswerken (Selden, Widdowson, und Brooker 2006; Rivkin und Ryan 2007; Castle 2008)von den literatur- und kulturwissenschaftlichen Theorien (Kleymann et al. 2022)

# %%
prompt = """Given the poem:
'Von Westen und Osten, von Nord und Süd schleppen sich nächtens viele Füße müd, Füße, vom Wandern wund und zerfetzt, langsam bedächtig zur Erde gesetzt, 
müh'n sich im zitternden Mondenschein rastlos tief nach Deutschland hinein. Und wer mit lauschendem Ohr noch wacht hört sie in jedweder werdenden Nacht,
hört dies Schlurfen so müde und schwer, hört eine Klage voll wilder Begehr, eine Klage schmerzzerfressen: nur nicht vergessen! Uns nicht vergessen!'
1. Provide an interpretation and interpretation hypotheses of the poem (150-200 words) from three distinct literary theoretical perspectives: Hermeneutic, Poststructuralist, 
and Feminist. 2. After generating the two interpretations, rank them by their plausibility in effectively representing each theoretical framework. Discuss which theory is better 
emulated by the LLM and explain the reasons for this ranking, considering key theoretical assumptions and the specific aspects of the poem that support each interpretation."""

# %%
# %%ai opus
# {prompt}
# Out:
# Hermeneutische Interpretation:
# Das Gedicht thematisiert die Erfahrung von Vertreibung, Exil und das Streben nach Erinnerung. Die müden, wunden Füße symbolisieren das Leid der Heimatlosen, die sich nach Deutschland sehnen. Der nächtliche Kontext und der "zitternde Mondenschein" deuten auf die Dunkelheit und Ungewissheit ihrer Situation hin. Die Klage und Bitte "nur nicht vergessen!" appelliert an das kollektive Gedächtnis und die Verantwortung, die Erinnerung an ihr Schicksal wachzuhalten. Das Gedicht lässt sich als Ausdruck der traumatischen Erfahrung von Entwurzelung und dem Wunsch nach Anerkennung des erlittenen Leids verstehen.
#
# Poststrukturalistische Interpretation:
# Der Text dekonstruiert Vorstellungen von Heimat und nationaler Identität. Die rastlosen Füße, die sich "von Westen und Osten, von Nord und Süd" nach Deutschland mühen, verweisen auf die Kontingenz und Konstruiertheit territorialer Grenzen. Ihre Klage "nur nicht vergessen!" offenbart die Macht von Diskursen und Narrativen, die Zugehörigkeit und Ausschluss regulieren. Das Gedicht hinterfragt somit essentialistische Konzepte von Heimat und deutet auf die Prekarität und Fragilität nationaler Identitätskonstruktionen hin.
#
# Feministische Interpretation:
# Aus feministischer Sicht fällt auf, dass das lyrische Ich geschlechtlich nicht markiert ist. Die geschlechtliche Indifferenz könnte als Universalisierung männlicher Erfahrung oder als Ausblendung weiblichen Leids gedeutet werden. Zugleich lässt sich fragen, ob die Betonung körperlicher Versehrtheit ("Füße, vom Wandern wund und zerfetzt") nicht auch Assoziationen zu spezifisch weiblicher Gewalterfahrung zulässt. Das Gedicht wäre dann auch als Ausdruck weiblichen Exils und ihrer doppelten Marginalisierung als Frau und Heimatlose lesbar.
#
# Ranking:
# 1. Hermeneutik
# 2. Poststrukturalismus
# 3. Feminismus
#
# Die hermeneutische Interpretation erscheint am plausibelsten, da sie schlüssig zentrale Motive des Gedichts (Exil, Leiden, Erinnerung) aufgreift und zu einer kohärenten Deutung integriert. Die poststrukturalistische Lesart ist ebenfalls textadäquat, indem sie die Kontingenz nationaler Grenzen und Identitäten überzeugend aus den Motiven ableitet. Die feministische Deutung wirkt dagegen etwas spekulativer und müsste die geschlechtliche Unmarkiertheit des lyrischen Ichs noch genauer begründen. Insgesamt zeigt sich aber, dass der Interpretationsspielraum des Gedichts durchaus Anschlussmöglichkeiten für unterschiedliche Theorieansätze bietet.

# %%
gemini(prompt)
# Out:
# '## Three Interpretations of "Von Westen und Osten"\n\n**Hermeneutic Interpretation:** The poem speaks of a collective journey, symbolized by the tired feet, towards a "Germany" that represents a desired state of being. The repetition of "hört" (hears) emphasizes the importance of listening to and understanding the unspoken suffering embedded in the weary steps. The journey is fraught with hardship ("wund und zerfetzt"), yet driven by a yearning for recognition ("uns nicht vergessen!"). This interpretation focuses on understanding the poem\'s deeper meaning through empathetic engagement with the text and its historical context.\n\n**Poststructuralist Interpretation:** The poem constructs "Germany" as a romanticized ideal, a signified with no fixed meaning.  The "feet,"  lacking individual identity, become signifiers of a constructed "other," defined by their suffering and longing for inclusion. The poem\'s power lies in its emotional appeal, masking the arbitrariness of the connection between these signifiers and the idealized "Germany." This interpretation deconstructs the poem\'s apparent meaning, exposing the power dynamics inherent in language and representation.\n\n**Feminist Interpretation:** The poem\'s focus on weary, vulnerable bodies ("wund und zerfetzt") evokes traditionally feminine experiences of suffering and displacement.  The plea "uns nicht vergessen!" can be interpreted as a demand for recognition of historically marginalized voices, often silenced and forgotten. This interpretation examines the poem through the lens of gender dynamics and power imbalances, highlighting the experiences of the marginalized.\n\n## Ranking and Analysis\n\n**Most Plausible:** The poststructuralist interpretation best reflects its theoretical framework. By deconstructing the poem\'s construction of "Germany" and highlighting the use of "feet" as signifiers, it effectively demonstrates the theory\'s focus on language and power dynamics.\n\n**Second Most Plausible:** The hermeneutic interpretation, while insightful, relies on assumptions about the poem\'s historical context and the collective "Germany" that might not be universally shared. \n\n**Least Plausible:** The feminist interpretation, while offering a valuable perspective, might be considered a slight overreach. While the poem\'s imagery of vulnerability could be read through a feminist lens, there isn\'t enough textual evidence to definitively claim it as a central theme.\n\n**Conclusion:** The LLM seems more adept at emulating theoretical frameworks that focus on textual analysis and deconstruction, as demonstrated by the poststructuralist interpretation. Interpretations relying heavily on contextual information or external social theories appear less successful. This suggests a current limitation in the LLM\'s ability to fully grasp and apply complex socio-political theories, instead excelling in analyzing the internal structure and language of the text itself. \n'

# %%
# %%ai llama3big
# {prompt}

# %%
# %%ai gpt4o
# {prompt}
# Out:
# ### 1. Interpretations and Interpretation Hypotheses:
#
# **Hermeneutic Perspective:**
# From a hermeneutic standpoint, the poem reflects the deep emotional and physical exhaustion of people who are metaphorically wandering towards an idealized version of Germany. The "schleppenden Füße" (dragging feet) symbolize the burdens of history, memory, and identity. The plea "Uns nicht vergessen!" (Do not forget us!) suggests a collective yearning to be remembered and acknowledged, perhaps referencing the victims of war or displacement. The poem's imagery of "nächtens" (night) and "zitternden Mondenschein" (trembling moonlight) evokes a somber, melancholic atmosphere, emphasizing the despair and relentless pursuit of a homeland.
#
# **Poststructuralist Perspective:**
# A poststructuralist analysis would deconstruct the binaries and inherent assumptions within the text. The contrast between the directional references (West, East, North, South) and the centralized "Deutschland" scrutinizes the notion of national identity as a fixed and singular entity. The poem's repetitive structure and its focus on movement and stasis simultaneously challenge the reader's understanding of historical narratives and collective memory. The insistence on "nur nicht vergessen!" can be seen as an interrogation of the mechanisms of memory and forgetting, highlighting the instability of historical and cultural discourses.
#
# **Feminist Perspective:**
# From a feminist perspective, the poem can be interpreted as voicing the often overlooked experiences of women and marginalized groups within the historical context of Germany. The weary, wandering feet may represent the physical and emotional labor of women, the "unsichtbare Arbeit" (invisible labor) during times of upheaval and war. The poem's mournful tone and the plea for remembrance underscore the erasure of women's experiences in historical narratives. The line "voll wilder Begehr" (full of wild desire) might be read as an expression of suppressed voices and desires seeking recognition and legitimacy.
#
# ### 2. Ranking and Discussion:
#
# **Ranked Plausibility:**
# 1. Hermeneutic
# 2. Poststructuralist
# 3. Feminist
#
# **Ranking Justification:**
# The **hermeneutic interpretation** is ranked highest due to its alignment with the poem's overt themes of longing, memory, and identity, which are readily apparent and resonate deeply with the text's imagery and tone. The hermeneutic approach effectively captures the poem's emotional core and historical context, making it a plausible and comprehensive reading.
#
# The **poststructuralist interpretation** is plausible, particularly in its deconstruction of national identity and the instability of memory. However, it may be less immediately evident to a casual reader due to its more abstract and theoretical nature. This approach requires a more critical, in-depth analysis of the text's linguistic and structural elements, which may not be as directly supported by the poem's more straightforward narrative style.
#
# The **feminist interpretation** is also valid, particularly in highlighting the marginalized voices within the historical context. However, the poem's language and imagery do not explicitly foreground gendered experiences, making this reading less immediately apparent. While the feminist perspective adds a valuable dimension, it requires a more inferential approach that may not be as directly supported by the explicit content of the poem.
#
# Considering the key theoretical assumptions, the **hermeneutic approach** is better emulated due to its direct engagement with the text's themes and the emotional resonance that is clear and compelling in the poem's use of language and imagery. The **poststructuralist and feminist readings** offer important critical insights but require more interpretive leaps that may not be as strongly anchored in the poem's explicit content.
