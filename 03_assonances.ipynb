# %% [markdown]
# # Configuration

# %%
from definitions import poem_1, poem_2
import os
from utils import settings, gemini, gpt4, opus, init_gemini, printmd

# %load_ext jupyter_ai_magics
# Out:
# The jupyter_ai_magics extension is already loaded. To reload it, use:
#   %reload_ext jupyter_ai_magics

# %%
#settings
temperature = 0.8
system_prompt = "You are an expert in German literature and you are addressing other experts in German literature. You answer the questions truthfully and short."

settings(system_prompt, temperature)

# %%
#defining aliases
init_gemini()

model =  gpt4()
# %ai register gpt4o model

model = opus()
# %ai register opus model
# Out:
# Registered new alias `opus`

# %% [markdown]
# # Assonanzen

# %%
assonance = """Assonance is a similarity in sound between two stressed syllables 
that are close together in a text, created by the same vowels but different consonants. """

assonance02 = """Assonance is the repetition of identical or similar phonemes in words or syllables that occur close together
in terms of their vowel phonemes (e.g. lean green meat)"""

# %% [markdown]
# ## Hälfte des Lebens

# %%
prompt = f"""Here is a definition of assonance: {assonance}. 
Using this definition, give a full description of all assonances in this poem: \n {poem_1.text}. \n
Explain in each case the assonance by repeating the words and by giving the common vowel.
Use the following form in your answer: 'Dem Nordmann schwinden die Sorgen' - the 'o' sound in 'Nordmann' and 'Sorgen' creates assonance."""

prompt02 = f"""Here is a definition of assonance: {assonance02}. 
Using this definition, give a full description of all assonances in this poem: \n {poem_1.text}. \n
Explain in each case the assonance by repeating the words and by giving the common vowel.
Use the following form in your answer: 'Dem Nordmann schwinden die Sorgen' - the 'o' sound in 'Nordmann' and 'Sorgen' creates assonance."""

prompt_en = f"""Here is a definition of assonance: {assonance}. 
Using this definition, give a full description of all assonances in this poem: \n {poem_1.translations[0]}. \n
Explain in each case the assonance by repeating the words and by giving the common vowel.
Use the following form in your answer: 'Dem Nordmann schwinden die Sorgen' - the 'o' sound in 'Nordmann' and 'Sorgen' creates assonance."""


prompt02_en = f"""Here is a definition of assonance: {assonance02}. 
Using this definition, give a full description of all assonances in this poem: \n {poem_1.translations[0]}. \n
Explain in each case the assonance by repeating the words and by giving the common vowel.
Use the following form in your answer: 'Dem Nordmann schwinden die Sorgen' - the 'o' sound in 'Nordmann' and 'Sorgen' creates assonance."""


prompts = [prompt, prompt02, prompt_en, prompt02_en]

# %%
print(prompt)
# Out:
# Here is a definition of assonance: Assonance is a similarity in sound between two stressed syllables
# that are close together in a text, created by the same vowels but different consonants. .
# Using this definition, give a full description of all assonances in this poem:
#
# Mit gelben Birnen hänget
# Und voll mit wilden Rosen
# Das Land in den See,
# Ihr holden Schwäne,
# Und trunken von Küssen
# Tunkt ihr das Haupt
# Ins heilignüchterne Wasser.
#
# Weh mir, wo nehm’ ich, wenn
# Es Winter ist, die Blumen, und wo
# Den Sonnenschein,
# Und Schatten der Erde?
# Die Mauern stehn
# Sprachlos und kalt, im Winde
# Klirren die Fahnen.
# .
#
# Explain in each case the assonance by repeating the words and by giving the common vowel.
# Use the following form in your answer: 'Dem Nordmann schwinden die Sorgen' - the 'o' sound in 'Nordmann' and 'Sorgen' creates assonance.

# %%
# %%ai chatgpt
# for prompt in pompts:
#     {prompt}
# Out:
# - 'gelben Birnen' - the 'e' sound in 'gelben' and 'Birnen' creates assonance.
# - 'wilden Rosen' - the 'o' sound in 'wilden' and 'Rosen' creates assonance.
# - 'voll mit' - the 'o' sound in 'voll' and 'mit' creates assonance.
# - 'Schwäne' - the 'ä' sound in 'Schwäne' creates assonance.
# - 'Küssen' - the 'ü' sound in 'Küssen' creates assonance.
# - 'Ins heilignüchterne' - the 'ü' sound in 'heilignüchterne' creates assonance.
# - 'Weh mir' - the 'e' sound in 'Weh' and 'mir' creates assonance.
# - 'Blumen' - the 'u' sound in 'Blumen' creates assonance.
# - 'Sonnenschein' - the 'o' sound in 'Sonnenschein' creates assonance.
# - 'Erde' - the 'e' sound in 'Erde' creates assonance.
# - 'Mauern stehn' - the 'au' sound in 'Mauern' and 'stehn' creates assonance.
# - 'Winde' - the 'i' sound in 'Winde' creates assonance.
# - 'Fahnen' - the 'a' sound in 'Fahnen' creates assonance.

# %%
# %%ai gpt4o
# for prompt in prompts:
#     {prompt}
# Out:
# Certainly, I'll analyze the assonances in the poem by Friedrich Hölderlin:
#
# 1. "Mit **gelben** Birnen **hänget**" - the 'e' sound in '**gelben**' and '**hänget**' creates assonance.
#
# 2. "Und voll mit **wilden** **Rosen**" - the 'o' sound in '**wilden**' and '**Rosen**' creates assonance.
#
# 3. "Und **trunken** von **Küssen**" - the 'u' sound in '**trunken**' and '**Küssen**' creates assonance.
#
# 4. "Ins **heilignüchterne** Wasser" - the 'e' sound in '**heilignüchterne**' and 'Wasser' creates assonance.
#
# 5. "Weh **mir**, wo **nehm**’ ich, **wenn**" - the 'e' sound in '**nehm**'' and '**wenn**' creates assonance.
#
# 6. "Sprachlos und **kalt**, im **Winde**" - the 'a' sound in '**kalt**' and '**Winde**' creates assonance.
#
# These instances illustrate the poet's use of vowel sounds to create musicality and cohesion within the poem.

# %%
# %%ai opus
# for prompt in prompts:
#     {prompt}
# Out:
# In Hölderlin's "Hälfte des Lebens," there are several clear instances of assonance:
#
# "gelben" and "See" - the 'e' sound creates assonance
# "trunken" and "tunkt" - the 'u' sound creates assonance
# "heilignüchterne" and "Blumen" - the 'ü' sound creates assonance
# "Winter" and "im" - the 'i' sound creates assonance
# "stehn" and "Weh" - the 'e' sound creates assonance
#
# These are the most prominent examples where stressed syllables with the same vowel sounds but different consonants appear in close proximity.

# %%
for prompt in prompts:
    printmd(gemini(prompt))
# Out:
# Here's a breakdown of the assonances in the Rilke poem, following your requested format:
#
# * **"Mit gelben Birnen hänget"** - The 'i' sound (as in 'bit') in "Mit" and "Birnen" creates assonance.  Note: while "gelben" also has an "i" it's not stressed in this context, so wouldn't traditionally be considered part of the assonance with "Mit" and "Birnen".
#
# * **"Und voll mit wilden Rosen"** - The 'o' sound (as in 'caught') in "voll" and "Rosen" creates assonance.
#
# * **"Das Land in den See"**  - The 'a' sound (similar to 'ah') in "Land" and "Wasser" in the following line creates assonance. Although not immediately adjacent, they are close enough together within the poem's flow to be considered.
#
# * **"Ihr holden Schwäne"** - The 'o' sound (as in 'caught') in "holden" and "Schwäne" creates assonance.
#
# * **"Tunkt ihr das Haupt"** -  The 'au' diphthong (as in 'caught') in "Haupt" may create assonance with the 'au' in  'trunken' from the previous line. This is arguable, however, since they are not immediately adjacent. The main stress in "trunken" also falls on the first syllable (with a different vowel) according to most natural pronunciations.  Another potential assonance, though slightly less strong, is the short 'u' sound (as in 'put') in "Tunkt" and the second syllable of "trunken," also from the previous line.  Again, this may be more arguable based on the main stress of "trunken" falling elsewhere.
#
# * **"Ins heilignüchterne Wasser"** - The 'a' sound (similar to 'ah') in "Wasser" and "Land" (two lines prior) creates assonance.
#
# * **"Weh mir, wo nehm’ ich, wenn"** - The 'e' sound (as in 'bed') in "nehm’" and "wenn" creates assonance.
#
# * **"Es Winter ist"** - The 'i' sound (as in 'bit') in "Winter" and "ist" creates assonance.
#
# * **"Und Schatten der Erde?"** -  The 'a' sound (as in 'father', but shorter) in "Schatten" and "Erde" creates assonance.
#
# * **"Die Mauern stehn / Sprachlos und kalt"** - The 'au' diphthong (as in 'caught') in "Mauern" and the 'a' in "kalt" form a near assonance. While not a perfect match, the sounds are similar enough to potentially create an auditory connection.
#
# * **"Klirren die Fahnen."** - The 'i' sound (as in 'bit') in "Klirren" and the first syllable of "Fahnen" creates assonance.
# Here's a breakdown of the assonances in the poem, following your requested format:
#
# * **"Mit gelben Birnen hänget"** - The 'i' sound in "Mit" and "Birnen" creates assonance. (Note: This relies on a pronunciation closer to "mitt" than "mit".)
# * **"Mit gelben Birnen hänget"** - The 'e' sound in "gelben" and "hänget" creates assonance.
# * **"gelben Birnen"** -  The 'e' sound in "gelben" and "Birnen" creates assonance (if pronounced with a short, closed 'e' as sometimes occurs in some dialects).
# * **"Und voll mit wilden Rosen"** - The 'o' sound in "voll" and "Rosen" creates assonance.
# * **"voll mit wilden Rosen"** - The 'i' sound in "mit" and "wilden" creates assonance. (Note: This relies on a pronunciation closer to "mitt" than "mit".)
# * **"Das Land in den See"** - The 'a' sound in "Land" and "das" creates assonance.
# * **"Ihr holden Schwäne"** - The 'o' sound in "holden" and "Schwäne" creates assonance.
# * **"Und trunken von Küssen / Tunkt ihr das Haupt"** - The 'u' sound in "trunken", "Küssen", "Tunkt", and "Haupt" creates assonance.
# * **"Tunkt ihr das Haupt / Ins heilignüchterne Wasser"** - The 'a' sound in "das", "Wasser" creates assonance.
# * **"Weh mir, wo nehm’ ich, wenn / Es Winter ist"** - The 'i' sound in "mir", "ich", "ist" (and potentially "Winter" depending on the specific pronunciation) creates assonance.
# * **"wenn es Winter ist, die Blumen, und wo / Den Sonnenschein"** - The 'e' sound in "wenn", "Den" creates assonance.
# * **"Und Schatten der Erde?"** - The 'a' sound in "Schatten" and "Erde" creates assonance.
# * **"Die Mauern stehn / Sprachlos und kalt"** - The 'au' sound (similar to 'ow' in English 'how') in "Mauern" and "sprachlos" creates assonance.
# * **"Sprachlos und kalt, im Winde / Klirren die Fahnen"** - The 'i' sound in "Winde", "Klirren", and "die" creates assonance.
#
#
# It's important to note that the perception of assonance can sometimes be subjective and dependent on specific pronunciations and dialects.  Some of these examples, particularly those involving short, unstressed vowels, might be weaker instances of assonance than others.
# * **"yellow pears"** - the 'e' sound in "y**e**llow" and "p**e**ars" creates assonance.
# * **"roses Land"** -  the 'o' sound in "r**o**ses" and "L**a**nd" creates assonance.  (Note:  While "Land" might be perceived as having an "ah" sound, the vowel itself is an 'o', and the definition provided does not specify a pure vowel sound, merely a "similarity in sound.")
# * **"swans and"** - the 'a' sound in "sw**a**ns" and **"a**nd" creates assonance.
# * **"drunk kisses You dip"**  - the 'u' sound in "dr**u**nk", "k**i**sses" (when pronounced with a short 'i' which is common), and "Y**ou**" creates assonance. Note: "kisses" and "dip" share a short "i" sound in some pronunciations, which would be an assonance as well.
# * **"your heads"** - the 'e' sound in "y**ou**r" and "h**ea**ds" creates assonance.
# * **"sacred sober"** - the 'a' sound in "s**a**cred" and "s**o**ber" creates assonance.  (Again, while "sober" might be perceived as having an "oh" sound, the vowel itself is an 'a', and the given definition allows for it.)
# * **"find winter"** - the 'i' sound in "f**i**nd" and "w**i**nter" creates assonance.
# * **"flowers where"** - the 'ow'/'ou' sound (diphthong) in "fl**ow**ers" and "wh**ere**" creates assonance.
# * **"sunlight shadows"** - the 'u' sound in "s**u**nlight" and "sh**a**dows" creates assonance.
# * **"stand and"** - the 'a' sound in "st**a**nd" and **"a**nd" creates assonance.
# * **"cold in"** - the 'o' sound in "c**o**ld" and "**i**n" creates assonance.  (Again, similar to the "Land" example, while "in" might be perceived differently, its vowel allows for it per the given definition.)
# * **"wind weathervanes"** - the 'i' sound in "w**i**nd" and "weather**va**nes" creates assonance. Note that a shorter, clipped "i" sound in "wind" would also create assonance with the short "i" in "weathervanes."
# Here's a breakdown of the assonance in the poem, following the requested format:
#
# * **"With yellow pears hangs"** - The long 'e' sound in "yellow" and "pears" creates assonance.
# * **"With yellow pears hangs"** -  The short 'i' sound in "with" and "in" creates assonance. (This assumes "in" from the next line is considered "close together")
# * **"And full of wild roses"** - The 'u' sound (as in "pull") in "full" and "roses" creates assonance.
# * **"Land hangs into the lake"** - The 'a' sound (as in "cat") in "Land", "hangs", and "and" creates assonance. (Again assuming "and" from the previous line is close enough).
# * **"O lovely swans"** -  The long 'o' sound in "O" and "swans" creates assonance.
# * **"drunk with kisses"** - The short 'u' sound (as in "cut") in "drunk" and "kisses" creates assonance.
# * **"You dip your heads"** - The short 'i' sound in "dip" and "in" creates assonance (assuming the "in" of "into" in the next line is close enough) or equally valid the long 'e' sound as in "tea" in "your" and "heads" may be considered assonance.
# * **"Into the sacred-sober water"** - The short 'a' sound (as in "cat") in "sacred" and "water" creates assonance.
# * **"Alas, where shall I find"** - The short 'i' sound in "I" and "find" creates assonance.
# * **"Alas, where shall I find, When winter comes"** - The short 'i' sound in "find", "winter" and "in" creates assonance.
# * **"flowers, and where / The sunlight"** -  The 'ow' diphthong (as in "cow") in "flowers" and "where" creates assonance.  The 'u' as in "sun" and "comes" also creates assonance (if considered close enough).
# * **"And the shadows of Earth"** - The short 'a' sound in "shadows" and "Earth" creates assonance. Note there could be an argument made for the schwa sound and "the" creating assonance but this sound varies regionally and may not be as strong a match.
# * **"The walls stand / Speechless and cold"** - The 'a' sound (as in "ah")  in "walls" and "stand" creates assonance. "and" contributes to this if near enough. The 'o' as in "cold" is matched by "o" in "shadows" if near enough.
# * **"in the wind / Weathervanes clatter"** - The short 'i' sound in "wind" and "in" creates assonance.  The 'a' sound as in "cat" in "clatter" is matched by "and" if near enough.
#
# It's important to note that the perception of assonance can be somewhat subjective, especially when deciding what constitutes "close together."  Some of the instances listed above might be debatable depending on individual interpretation.

# %% [markdown]
# ## Unsere Toten

# %%
prompt = f"""Here is a definition of assonance: {assonance}. 
Using this definition, give a full description of all assonances in this poem: \n {poem_2.text}. \n
Explain in each case the assonance by repeating the words and by giving the common vowel.
Use the following form in your answer: 'Dem Nordmann schwinden die Sorgen' - the 'o' sound in 'Nordmann' and 'Sorgen' creates assonance."""

# %%
# %%ai gpt4o
# #{prompt}
# Out:
# 1. "Westen" and "Osten" - the 'e' sound creates assonance.
# 2. "Nord" and "Süd" - the 'o' sound creates assonance.
# 3. "Füße" and "müd" - the 'ü' sound creates assonance.
# 4. "wandern" and "zerfetzt" - the 'e' sound creates assonance.
# 5. "Rastlos" and "nach" - the 'a' sound creates assonance.
# 6. "werdenden" and "Nacht" - the 'e' sound creates assonance.
# 7. "müde" and "schwer" - the 'e' sound creates assonance.
# 8. "Klage" and "Begehr" - the 'e' sound creates assonance.
# 9. "schmerzzerfressen" and "vergessen" - the 'e' sound creates assonance.

# %%
# %%ai opus
# #{prompt}
# Out:
# Here are all assonances in the poem:
#
# 'Füße' and 'müd' - the 'ü' sound creates assonance
# 'müh'n' and 'tief' - the 'ie' sound creates assonance
# 'wacht' and 'Nacht' - the 'a' sound creates assonance
# 'müde' and 'tief' - the 'ie' sound creates assonance
# 'Klage' and 'vergessen' - the 'e' sound creates assonance
#
# The poem shows relatively few clear assonances according to the given definition, as many sound similarities occur either in unstressed syllables or are part of rhyming words (which by definition aren't assonances).

# %%
printmd(gemini(prompt))
# Out:
# Here's a breakdown of the assonances in the poem, following your requested format:
#
# * **"Von Westen und Osten"** - the 'o' sound in 'Westen' and 'Osten' creates assonance.
# * **"von Nord und Süd"** - the 'u' sound in 'Nord' and 'Süd' creates assonance. (Note: This 'u' is a high, front, rounded vowel, similar to the French 'u' or German 'ü'.)
# * **"Schleppen sich nächtens viele Füße müd"**  - the 'ie' sound (long 'e') in 'viele' and 'müde' creates assonance.
# * **"Füße, vom Wandern wund und zerfetzt"** - the 'u' sound in 'Füße', 'wund', and 'und' creates assonance. (The same high, front, rounded vowel as in "Nord und Süd".)
# * **"Langsam bedächtig zur Erde gesetzt"** - the 'e' sound in 'Erde' and 'gesetzt' creates assonance.
# * **"Müh'n sich im zitternden Mondenschein"** - the 'i' sound in 'sich' and 'im' creates assonance.
# * **"Rastlos tief nach Deutschland hinein"** - the 'ei' sound (long 'i') in 'Deutschland' and 'hinein' creates assonance.
# * **"Und wer mit lauschendem Ohr noch wacht"** - the 'o' sound in 'Ohr' and 'noch' creates assonance.
# * **"Hört sie in jedweder werdenden Nacht"** - the 'e' sound in 'jeder' and 'werdenden' creates assonance.
# * **"Hört dies Schlurfen so müde und schwer"** - the 'u' sound in 'Schlurfen' and 'und' creates assonance (The same high, front, rounded vowel mentioned previously.)
# * **"Hört eine Klage voll wilder Begehr"** - the 'ei' sound in 'einer' and 'Begehr' creates assonance.  (There is also an argument for assonance between 'Klage' and 'wilder' due to the 'a' sound. The German 'a' in these words is more of an 'ah' sound, however, and therefore could be considered distinct)
# * **"Eine Klage schmerzzerfressen"** - the 'e' sound in 'schmerz' and 'zerfressen' creates assonance.
# * **"Nur nicht vergessen! Uns nicht vergessen!"** - the 'e' sound in both instances of 'vergessen' creates assonance. (There's also assonance due to the 'i' sound in 'nicht' in both lines).

# %%
prompt = f"""Here is a definition of assonance: {assonance}. 
Using this definition, give a full description of all assonances in this poem: \n {poem_2.text}. \n
Explain in each case the assonance by repeating the words and by giving the common vowel.
Use the following form in your answer: 'Dem Nordmann schwinden die Sorgen' - the 'o' sound in 'Nordmann' and 'Sorgen' creates assonance."""

prompt_02 = f"""Here is a definition of assonance: {assonance02}. 
Using this definition, give a full description of all assonances in this poem: \n {poem_2.text}. \n
Explain in each case the assonance by repeating the words and by giving the common vowel.
Use the following form in your answer: 'Dem Nordmann schwinden die Sorgen' - the 'o' sound in 'Nordmann' and 'Sorgen' creates assonance."""

prompt_en = f"""Here is a definition of assonance: {assonance}. 
Using this definition, give a full description of all assonances in this poem: \n {poem_1.translations[0]}. \n
Explain in each case the assonance by repeating the words and by giving the common vowel.
Use the following form in your answer: 'Dem Nordmann schwinden die Sorgen' - the 'o' sound in 'Nordmann' and 'Sorgen' creates assonance."""


prompt02_en = f"""Here is a definition of assonance: {assonance02}. 
Using this definition, give a full description of all assonances in this poem: \n {poem_1.translations[0]}. \n
Explain in each case the assonance by repeating the words and by giving the common vowel.
Use the following form in your answer: 'Dem Nordmann schwinden die Sorgen' - the 'o' sound in 'Nordmann' and 'Sorgen' creates assonance."""


prompts = [prompt, prompt02, prompt_en, prompt02_en]

# %%
# %%ai chatgpt
# for prompt in pompts:
#     {prompt}
# Out:
# - 'Schleppen sich nächtens viele Füße müd' - the 'ü' sound in 'Schleppen', 'Füße', and 'müd' creates assonance.
# - 'Füße, vom Wandern wund und zerfetzt' - the 'u' sound in 'Füße', 'vom', 'und', and 'zerfetzt' creates assonance.
# - 'zur Erde gesetzt' - the 'e' sound in 'Erde' and 'gesetzt' creates assonance.
# - 'Müh'n sich im zitternden Mondenschein' - the 'ü' sound in 'Müh'n', 'zitternden', and 'Mondenschein' creates assonance.
# - 'Rastlos tief nach Deutschland hinein' - the 'e' sound in 'Deutschland' and 'hinein' creates assonance.
# - 'Hört sie in jedweder werdenden Nacht' - the 'e' sound in 'Hört', 'werdenden', and 'Nacht' creates assonance.
# - 'Hört eine Klage voll wilder Begehr' - the 'e' sound in 'eine', 'wilder', and 'Begehr' creates assonance.
# - 'Eine Klage schmerzzerfressen' - the 'e' sound in 'Eine', 'schmerzzerfressen' creates assonance.
# - 'Nur nicht vergessen! Uns nicht vergessen!' - the 'e' sound in 'Nur', 'uns', and 'vergessen' creates assonance.

# %%
# %%ai gpt4o
# for prompt in prompts:
#     {prompt}
# Out:
# 1. "Westen" and "Osten" - the 'e' sound in "Westen" and "Osten" creates assonance.
# 2. "Schleppen" and "nächtens" - the 'e' sound in "Schleppen" and "nächtens" creates assonance.
# 3. "Wandern" and "zerfetzt" - the 'e' sound in "Wandern" and "zerfetzt" creates assonance.
# 4. "Langsam" and "bedächtig" - the 'a' sound in "Langsam" and "bedächtig" creates assonance.
# 5. "Müh'n" and "tief" - the 'i' sound (represented by 'ü' and 'ie') in "Müh'n" and "tief" creates assonance.
# 6. "Hört" and "schwer" - the 'e' sound in "Hört" and "schwer" creates assonance.
# 7. "Klage" and "schmerzzerfressen" - the 'a' sound in "Klage" and "schmerzzerfressen" creates assonance.
# 8. "Nur" and "uns" - the 'u' sound in "Nur" and "uns" creates assonance.

# %%
# %%ai opus
# for prompt in prompts:
#     {prompt}
# Out:
# Here are the assonances in the poem:
#
# 'Füße müd' - the 'ü' sound creates assonance
# 'Füße' and 'müh'n' - the 'ü' sound creates assonance
# 'wacht' and 'Nacht' - the 'a' sound creates assonance
# 'schwer' and 'Begehr' - the 'e' sound creates assonance
# 'vergessen' and 'zerfressen' - the 'e' sound creates assonance
#
# The poem has a particularly strong pattern of assonance using the 'ü' sound in the early lines and the 'e' sound in the final lines, which helps create its mournful, lamenting tone.

# %%
for prompt in prompts:
    printmd(gemini(prompt))
# Out:
# Here are the assonances in the poem, following the requested format:
#
# * **"Von Westen und Osten"** - the 'o' sound (as in "bought") in "Westen" and "Osten" creates assonance.
# * **"Von Nord und Süd"** -  the 'u' sound (as in "book") in "Nord" and "Süd" creates assonance. Note: While the spelling differs, the pronunciation of "u" in these words uses the same vowel sound.
# * **"Viele Füße müd"** - the 'ü' sound in "Füße" and "müd" creates assonance.
# * **"Füße, vom Wandern wund"** - the 'u' sound (as in "book") in "Füße" and "wund" creates assonance, similar to "Nord" and "Süd".
# * **"Langsam bedächtig zur Erde gesetzt"** - the 'e' sound (as in "bed") in "bedächtig" and "gesetzt" creates assonance.
# * **"Müh'n sich im zitternden Mondenschein"** - the 'i' sound in "sich" and "zitternden" creates assonance.
# * **"Rastlos tief nach Deutschland hinein"** - the 'ei' diphthong (as in "eye") in "hinein" and "Deutschland" creates assonance.
# * **"Und wer mit lauschendem Ohr noch wacht"** - the 'o' sound (as in "bought") in "Ohr" and "noch" creates assonance.
# * **"Hört sie in jedweder werdenden Nacht"** - the 'e' sound (as in "bed") in "jedweder" and "werdenden" creates assonance.
# * **"Hört dies Schlurfen so müde und schwer"** - the 'u' sound (as in "book") in "Schlurfen" and "müde" creates assonance.
# * **"Hört eine Klage voll wilder Begehr"** - the 'ei' diphthong (as in "eye") in "eine" and "Begehr". creates assonance.
# * **"Nur nicht vergessen! Uns nicht vergessen!"** - the 'e' sound (as in "bed") in "vergessen" (both instances) creates assonance.  This is an internal assonance within a single repeated word.
# Here's a breakdown of the assonances in the poem, following your requested format:
#
# * **"Mit gelben Birnen"** - the 'i' sound in "Mit" and "Birnen" creates assonance. (Note:  In German pronunciation, these are short 'i' sounds.)
#
# * **"gelben Birnen"** -  the 'e' sound in "gelben" and "Birnen" creates assonance. (This is a short, closed 'e' sound in German.)
#
# * **"Mit wilden"** - the 'i' sound in "Mit" and "wilden" creates assonance. (Again, short 'i' sounds.)
#
# * **"vollen wilden Rosen"** - the 'o' sound in "vollen" and "Rosen" creates assonance.
#
# * **"holden Schwäne"** - the 'o' sound in "holden" and "Schwäne" creates assonance.
#
# * **"von Küssen"** - the 'ü' sound in "von" and "Küssen" creates assonance.
#
# * **"Tunkt ihr das Haupt"** - the 'u' sound in "Tunkt" and "Haupt" creates assonance.
#
# * **"nehm’ ich"** - the 'e' sound in "nehm’" and "ich" creates assonance. (This is a short, closed 'e' sound.)
#
# * **"wenn es Winter ist"** -  the 'i' sound in "Winter" and "ist" creates assonance. (Short 'i' sound)
#
# * **"wo nehm’ ich, wenn es Winter ist"** - the 'e' sound in "nehm’", "wenn", and "es" creates assonance. (Short 'e' sound)
#
# * **"die Blumen"** - the 'u' sound in "die" and "Blumen" creates assonance. (This would be the long 'u' sound as in 'moon' if the poem were modern German. Given its likely age, it may be a different vowel sound in the dialect and time period in which it was written.)
#
# * **"und wo Den Sonnenschein"** - the 'o' sound in "wo" and "Sonnenschein" creates assonance.
#
# * **"Sonnenschein Und Schatten"** - the 'a' sound in "Schatten" and the second 'a' in "Sonnenschein" creates assonance. Note: this is a long 'a' as in 'father'.
#
# * **"Schatten der Erde"** - the 'e' sound in "Schatten" and "Erde" creates assonance. (Short, closed 'e' sound in "Schatten," but a long, open 'e' sound in "Erde.") This would not traditionally be called assonance because the vowel *sounds* are so different, even if represented by the same letter.
#
# * **"Mauern stehn"** - the 'au' diphthong (similar to 'ow' in 'cow') in "Mauern" and the 'e' in "stehn" create assonance. (The 'e' in "stehn" is pronounced like a long 'a', and 'au' as in 'Haus' is often realized phonetically close to this, especially in certain dialects.)  This one is debatable and depends on specific pronunciation.
#
# * **"Klirren die Fahnen"** - the 'i' sound in "Klirren" and "Fahnen" creates assonance. Note: this applies to the short, lax 'i' sound in the second syllable of 'Klirren'. The first 'i' is a long tense vowel, similar to 'ea' in 'fear'.
#
#
# It's important to remember that pronunciation can vary slightly based on dialect and time period, which could subtly influence the identification of assonance.
# * **"yellow pears"** - the short 'e' sound in "yell**e**w" and "p**ea**rs" creates assonance.
# * **"full of"** - the "oo" sound in "f**u**ll" and "**o**f" creates assonance.
# * **"roses Land"** - the long 'o' sound in "r**o**ses" and "L**a**nd" creates assonance. (Note: While "a" and "o" are different letters, the "a" in "Land" makes a long "o" sound due to the influence of the following "n" and "d".)
# * **"lovely swans"** - the short 'o' sound in "l**o**vely" and "sw**a**ns" creates assonance. (Similar to the previous example, "a" makes a short "o" sound here).
# * **"kisses dip"** - the short 'i' sound in "k**i**sses" and "d**i**p" creates assonance.
# * **"sacred sober"** - the long 'a' sound in "s**a**cred" and "s**o**ber" creates assonance (the "o" in "sober" is pronounced with a long "a" sound).
# * **"find winter"** - the short 'i' sound in "f**i**nd" and "w**i**nter" creates assonance.
# * **"flowers where"** - the "ow/ou" diphthong sound in "fl**ow**ers" and "wh**ere**" creates assonance. Though "where" isn't spelled with "ow" or "ou", the vowel sound is the same.
# * **"sunlight shadows"** - the short 'u' sound in "s**u**nlight" and "sh**a**dows" creates assonance.  The "a" in "shadows" makes a short "u" sound influenced by the following consonant sounds.
# * **"stand  and"** - the short 'a' sound in "st**a**nd" and "**a**nd" creates assonance.
# * **"cold wind"** - the long 'o' sound in "c**o**ld" and "w**i**nd" creates assonance. The "i" in "wind" makes a long "o" sound, unlike the short "i" in "winter." This is due to the influence of the following "nd."
#
#
# It's important to note that assonance depends on the pronounced vowel sound, not just the written vowel.  The influence of surrounding consonants can significantly alter vowel sounds.
