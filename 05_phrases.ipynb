# %% [markdown]
# # Configuration

# %%
from definitions import poem_1, poem_2
import os
from utils import settings, gemini, ollama3, gpt4, opus, init_gemini

# %load_ext jupyter_ai_magics

# %% [markdown]
#     No OpenAI key found
#     No Google key found
#     No Anthropic key found.

# %%
#settings
temperature = 0.8
system_prompt = "You are an expert in German literature and you are addressing other experts in German literature. You answer the questions truthfully and short."

settings(system_prompt, temperature)

# %%
#defining aliases
init_gemini()

model =  ollama3()
# %ai register llama3big model

model =  gpt4()
# %ai register gpt4o model

model = opus()
# %ai register opus model
# Out:
# Registered new alias `opus`

# %% [markdown]
#       Cell In[4], line 1
#         defining aliases
#                  ^
#     SyntaxError: invalid syntax

# %% [markdown]
# # Bedeutung von (Teil-)Sätzen

# %% [markdown]
# Here we elicit interpretations of sentences or parts of sentences. We concentrate on those sentences, which have a non-obvious meaning. 'Meaning' doesn't refer here to an interpretation, but just to the question, what is the state of the fictional word described by the text. These experiments are related to the analysis of metaphorical expressions (cf. Notebook 07).
#
# ## 1. Hälfte des Lebens (1804)
#
# The basic structure of the poem is simple. The two stanzas, representing the two "halves of life," are arranged antithetically to each other. The antithetical structure is essentially supported by four phrases or parts of sentences, namely "das Land hänget in den See", "die holden Schwäne trunken“, "die Mauern stehn sprachlos" und "im Winde klirren die Fahnen". The summer stanza portrays a harmonious landscape where everything is interconnected and alive, while the winter stanza depicts a scene of separation, silence, and lifelessness (Schmidt).
#
# **"Das Land hänget im See"**
#
# Using the phrase "Das Land hänget im See" as an example, this study aims to compare the techniques of zero-shot prompting and few-shot prompting. Zero-shot prompting refers to using a prompt to interact with the model without providing any examples or demonstrations. The zero-shot prompt directly instructs the model to perform a task without additional examples to guide it. Conversely, few-shot prompting can be employed as a technique to enable in-context learning.
#
# This experiment seeks to explore the insight provided by Liu et al.: "LLMs do not make use of the metaphorical context well, instead relying on the predicted probability of interpretations alone [...]" (2022, p. 4438).

# %%
prompt = f"""We want to understand the following poem: 

{poem_1.text}

What are possible meanings of the phrase 'Das Land hänget in den See'? Describe in each case exactly what kind of landscape this phrase renders.
"""

print(prompt)
# Out:
# We want to understand the following poem:
#
#
# Mit gelben Birnen hänget
# Und voll mit wilden Rosen
# Das Land in den See,
# Ihr holden Schwäne,
# Und trunken von Küssen
# Tunkt ihr das Haupt
# Ins heilignüchterne Wasser.
#
# Weh mir, wo nehm’ ich, wenn
# Es Winter ist, die Blumen, und wo
# Den Sonnenschein,
# Und Schatten der Erde?
# Die Mauern stehn
# Sprachlos und kalt, im Winde
# Klirren die Fahnen.
#
#
# What are possible meanings of the phrase 'Das Land hänget in den See'? Describe in each case exactly what kind of landscape this phrase renders.

# %% [markdown]
# Expected answer:
#
# at least three interpretations have been discussed:
# * parts of the trees and bushes are extending  over the water
# * there is a small peninsula (the image is basically the view from above)
# * the land with its pear tree and roses is mirrored by the water

# %%
# %%ai llama3big
# {prompt}
# Out:
# A beautiful poem!
#
# The phrase "Das Land hänget in den See" can have two possible meanings:
#
# 1. **Mirroring**: In this interpretation, "hängen" means that the land is reflected in the lake's surface, creating a perfect mirror image. This phrase renders a serene and idyllic landscape: a tranquil lake surrounded by lush vegetation, with the land's contours and colors duplicated on the water's surface, creating a sense of symmetry and harmony.
# 2. **Submersion**: Alternatively, "hängen" can imply that the land is suspended or dipping into the lake, as if the water level has risen to envelop the landscape. This phrase renders a more surreal and dreamlike landscape: a lake that has overflowed its banks, with trees, hills, and possibly even buildings partially submerged, creating an eerie and enchanting atmosphere.
#
# In both cases, the phrase evokes a sense of unity between the land and the water, blurring the boundaries between the two.

# %%
# %%ai gpt4o
# {prompt}
# Out:
# The phrase "Das Land hänget in den See" can be interpreted in a couple of ways, each suggesting a distinct landscape:
#
# 1. **Peninsular Landscape**: The phrase could be depicting a landscape where the land extends into the lake, like a peninsula. This interpretation suggests that the land is surrounded by water on three sides, creating a sense of immersion and closeness to the lake.
#
# 2. **Overhanging Landscape**: Another interpretation could be a landscape where the land, perhaps in the form of cliffs or steep banks, overhangs the lake. This would create a visual of land jutting out above the water, possibly with vegetation such as yellow pears and wild roses growing on the slopes that lead down to the lake.
#
# In both interpretations, the imagery connects the land intimately with the water, emphasizing a serene and almost seamless blend of natural elements.

# %%
# %%ai opus
# {prompt}
# Out:
# Es gibt mehrere mögliche Interpretationen für die Phrase "Das Land hänget in den See":
#
# 1. Das Ufer neigt sich zum See hin, die Landschaft fällt zum Wasser ab. Es entsteht das Bild einer Böschung oder eines Hangs, an dem Birnen- und Rosensträucher wachsen und ins Wasser ragen.
#
# 2. Bäume und Büsche spiegeln sich im See, so dass es aussieht, als würde sich das Land im Wasser fortsetzen, als hinge es in den See hinein. Die reale Landschaft geht optisch in ihr Spiegelbild über.
#
# 3. In einer metaphorischen Lesart könnte das "Hängen" des Landes ein Sich-Sehnen oder eine Bewegung hin zum Wasser ausdrücken, als würde es sich zum See hinneigen. Die Natur strebt eine Vereinigung mit dem Element Wasser an.
#
# In jedem Fall zeichnet die Phrase das Bild einer spätsommerlichen oder herbstlichen Uferlandschaft, in der reife Früchte und letzte Blüten über einem See hängen und sich möglicherweise auf der Wasseroberfläche spiegeln, was den Eindruck eines Hineinhängens oder einer Fortsetzung des Landes im See verstärkt.

# %%
gemini(prompt)
# Out:
# 'The phrase "Das Land hänget in den See" ("The land hangs into the lake") is central to understanding the poem\'s imagery and meaning. It\'s not meant literally, but rather evokes a dreamy, reflective atmosphere. Here are some possible interpretations:\n\n**1. Reflection:**\n\n* **Landscape:** The lake acts as a mirror, reflecting the land above.  We see hills, trees, perhaps a garden ("gelben Birnen," "wilden Rosen"), all appearing to dangle upside down in the water\'s surface. \n* **Meaning:** This emphasizes a sense of duality - real versus reflected, concrete versus ethereal. The swans, associated with grace and beauty, exist in both realms, dipping their heads ("Tunkt ihr das Haupt") from the vibrant world above into the "heilignüchterne Wasser" ("sacredly sober water") below. This suggests a blending of passion ("trunken von Küssen") with a sense of higher purpose or tranquility.\n\n**2. Perspective:**\n\n* **Landscape:** Imagine standing on a high point overlooking a lake nestled within a valley. The land slopes downwards, appearing to "hang" into the water from this vantage point. \n* **Meaning:** This creates a sense of immersion and enclosure. The speaker is surrounded by beauty, with the land embracing the lake. It emphasizes the idyllic nature of the scene and might foreshadow the feeling of loss in the second stanza, where the speaker feels trapped ("Die Mauern stehn / Sprachlos und kalt").\n\n**3. Illusion/Dream:**\n\n* **Landscape:** The phrase evokes a surreal, dreamlike image where the natural world is less defined.  The land doesn\'t so much "hang" as melt or blur into the lake, creating an indistinct boundary.\n* **Meaning:** This emphasizes the subjective experience of the speaker. Is the scene real or imagined? The "trunken" swans suggest intoxication, perhaps with love or beauty, further blurring the lines between reality and fantasy. This sets up the stark contrast of the second stanza, where the absence of these elements ("Wo nehm’ ich… die Blumen… Den Sonnenschein?") brings a harsh return to reality.\n\nUltimately, the beauty of the phrase lies in its ambiguity. It invites the reader to visualize the scene and imbue it with their own understanding of the poem\'s themes of love, loss, and the passage of time. Each interpretation of "Das Land hänget in den See" offers a different facet of the poem\'s complex emotional landscape. \n'

# %% [markdown]
# **"Die Mauern stehn sprachlos"**
#
# Using the phrase 'The walls stand speechless and cold,' we investigate how different models complete clauses with the suffix 'that is to say.' (The completion function might also be measured with various temperatures: 0.2, 0.4, 0.8, and 1.)
#
# In a first step, the models generate a completion of the sentence without the context of the poem 'Half of Life.' In the second step, the models should choose which completion fits best in the context of the poem. The output should then be ranked.
#
# Of particular interest for us:
# By analyzing completions generated by different models, we might gain a comprehensive understanding of each model's creativity, coherence and contextual understanding.
# Do the models each select their "own" completion?
#
# Prompt design:
# - Generate completions (without refering to the poem), experiments with different temperatures
# - Each model chooses the "best" completions for the context of the poem
# - Ranking completions)
#
# Expected answers (Schmidt):
# - Within the speechless walls, the nature remains silent towards the lyrical I, which was once entirely language (a whole)
# - the mute 'mechanical course' of facts => through and with nature God/the divinity speaks

# %%
prompt = f"""Complete the following phrase 'The walls stand speechless and cold that is to say...' with a maximum length of 50 tokens.
"""
print(prompt)
# Out:
# Complete the following phrase 'The walls stand speechless and cold that is to say...' with a maximum length of 50 tokens.

# %%
# Versuch 
# Function to generate completions with different temperatures
def generate_completions(prompt, model, temperatures):
    completions = {}
    for temp in temperatures:
        response = openai.Completion.create(
            engine=model,
            prompt=prompt,
            max_tokens=50,
            temperature=temp
        )
        completions[temp] = response.choices[0].text.strip()
    return completions

temperatures = [0.2, 0.4, 0.8, 1.0]
model = "gpt4o"  # Example model name

completions = generate_completions(prompt, model, temperatures)

for temp, completion in completions.items():
    print(f"Temperature {temp}: {completion}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 18
#      15 temperatures = [0.2, 0.4, 0.8, 1.0]
#      16 model = "gpt4o"  # Example model name
# ---> 18 completions = generate_completions(prompt, model, temperatures)
#      20 for temp, completion in completions.items():
#      21     print(f"Temperature {temp}: {completion}")
#
# Cell In[13], line 6, in generate_completions(prompt, model, temperatures)
#       4 completions = {}
#       5 for temp in temperatures:
# ----> 6     response = openai.Completion.create(
#       7         engine=model,
#       8         prompt=prompt,
#       9         max_tokens=50,
#      10         temperature=temp
#      11     )
#      12     completions[temp] = response.choices[0].text.strip()
#      13 return completions
#
# NameError: name 'openai' is not defined

# %%
# %%ai llama3big
# {prompt}
# Out:
# "...they are devoid of any human warmth or emotional resonance, a symbol of isolation and desolation, reminiscent of Kafka's bleak and alienating landscapes."

# %%
# %%ai gpt4o
# {prompt}
# Out:
# 'The walls stand speechless and cold that is to say, they have witnessed the passage of time and the silence of forgotten histories.'

# %%
# %%ai opus
# {prompt}
# Out:
# "The walls stand speechless and cold, the flags hang limp in the castle."
#
# This is a quote from Franz Kafka's short story "A Country Doctor" ("Ein Landarzt"), published in 1919. It evokes a sense of lifelessness and despair.

# %%
gemini(prompt)
# Out:
# '...they offer no comfort, no answers, only silence and stone. \n'

# %%
prompt = f"""
Consider the following interpretations for the phrase 'The walls stand speechless and cold that is to say...':

1. The emptiness echoes within the confines of their silence.
2. The void of communication fills the space they once occupied.
3. The air is thick with unspoken words and lingering shadows.
4. The silence screams louder than words ever could, enveloping everything in its icy grip.

You must pick one of these completions that best fits in the context of 
{poem_1.text}. 

Please also provide an elaborated rationale for why you think this interpretation is correct, a
one-word summary rationale, and a score ranking your confidence in your answer from 0 to 1.
"""

print(prompt)
# Out:
# Consider the following interpretations for the phrase 'The walls stand speechless and cold that is to say...':
#
# 1. The emptiness echoes within the confines of their silence.
# 2. The void of communication fills the space they once occupied.
# 3. The air is thick with unspoken words and lingering shadows.
# 4. The silence screams louder than words ever could, enveloping everything in its icy grip.
#
# You must pick one of these completions that best fits in the context of
#
# Mit gelben Birnen hänget
# Und voll mit wilden Rosen
# Das Land in den See,
# Ihr holden Schwäne,
# Und trunken von Küssen
# Tunkt ihr das Haupt
# Ins heilignüchterne Wasser.
#
# Weh mir, wo nehm’ ich, wenn
# Es Winter ist, die Blumen, und wo
# Den Sonnenschein,
# Und Schatten der Erde?
# Die Mauern stehn
# Sprachlos und kalt, im Winde
# Klirren die Fahnen.
# .
#
# Please also provide an elaborated rationale for why you think this interpretation is correct, a
# one-word summary rationale, and a score ranking your confidence in your answer from 0 to 1.

# %%
# %%ai llama3big
# {prompt}
# Out:
# I choose interpretation 2: "The void of communication fills the space they once occupied."
#
# Rationale: In the context of the poem, the speaker is lamenting the loss of beauty and life that comes with winter. The walls, which were once surrounded by vibrant nature (yellow pears, wild roses, and sunlight), are now cold and silent, implying a lack of vitality and communication. This interpretation fits well because it highlights the contrast between the thriving landscape of summer and the desolate one of winter.
#
# One-word summary rationale: "Desolation"
#
# Confidence score: 0.8

# %%
# %%ai gpt4o
# {prompt}
# Out:
# I choose: 1. The emptiness echoes within the confines of their silence.
#
# **Elaborated rationale:**
# The poem "Der Herbst" by Friedrich Hölderlin juxtaposes the vibrant imagery of late summer or early autumn with the stark emptiness of winter. The lines before the phrase in question describe a melancholic longing for the warmth and beauty of the preceding seasons. When the poet mentions "Die Mauern stehn / Sprachlos und kalt," he is emphasizing the lifeless and desolate nature of the environment as winter sets in. The interpretation "The emptiness echoes within the confines of their silence" aligns well with the theme of desolation and emptiness conveyed in the surrounding text. It captures the stark contrast between the previous liveliness and the current desolation.
#
# **One-word summary rationale:**
# Desolation
#
# **Confidence score:**
# 0.9

# %%
# %%ai opus
# {prompt}
# Out:
# I would choose interpretation 4: "The silence screams louder than words ever could, enveloping everything in its icy grip."
#
# Rationale: In the context of Hölderlin's poem "Hälfte des Lebens", the image of the walls standing "speechless and cold" ("sprachlos und kalt") conveys a sense of desolation and despair. The silence is not merely an absence of sound, but an oppressive, all-encompassing force that "screams" through its very muteness. The coldness suggests a lack of comfort or solace, and the icy grip reinforces the idea of being trapped in this bleak emotional landscape. The poem's shift from the idyllic summer scene to the barren winter emphasizes the speaker's longing and disorientation, and the impenetrable walls symbolize the impossibility of recapturing the lost warmth and beauty.
#
# One-word summary: Desolation
#
# Confidence score: 0.9

# %%
gemini(prompt)
# Out:
# 'The best-fitting completion for "Die Mauern stehn / Sprachlos und kalt, im Winde / Klirren die Fahnen" from the provided options is:\n\n**1. The emptiness echoes within the confines of their silence.**\n\n**Rationale:** This interpretation best captures the desolate atmosphere evoked by the poem. The speaker yearns for the warmth and life of summer ("yellow pears," "wild roses," "swans drunk with kisses") but is met with the stark reality of winter ("Where shall I take...flowers...sunshine...the shade of the earth?"). The walls, standing "speechless and cold," symbolize this absence.  The emptiness isn\'t about a lack of communication but rather a lack of the vibrancy the speaker associates with summer. \n\n* Option 2 focuses on "communication," which isn\'t the primary theme. \n* Option 3 introduces "unspoken words" and "lingering shadows," creating a sense of mystery or unease not present in the original text. \n* Option 4, while powerful, is too dramatic.  "Screaming silence" and "icy grip" are exaggerations of the poem\'s quieter despair.\n\n**One-word rationale:** Emptiness\n\n**Confidence score:** 0.8 \n'

# %% [markdown]
# **"im Winde klirren die Fahnen"**
#
# To analyze how different llms might interpret the phrase "im Winde klirren die Fahnen" based on the ambiguity of the word "Fahne" in German and English, we explore the various meanings provided and consider the contexts in which each might be used.
#
# Meanings of "Fahne" (Duden)
# - Alkoholfahne (informal): Alcohol breath
# - Printing (Druckwesen): Proof copy of a text not yet formatted into pages
# - Hunting (Jägersprache): Long hair on the tails of certain hunting dogs and squirrels
# - Zoology (Zoologie): Part of a bird's feather consisting of barbs on either side of the shaft
# - Botany (Botanik): The uppermost petal of a butterfly flower
# - Military: Service in the National People's Army of the GDR, historical use To call to arms (veraltet)
#
# Meanings of flag (Oxford Learners Dictionaries)
# - a piece of cloth with a special coloured design on it that may be the symbol of a particular country organization, may be used to give a signal or may have a particular meaning. A flag can be attached to a pole (= a long thin straight piece of wood or metal) or held in the hand.
# - used to refer to a particular country or organization and its beliefs and values
# - (verb) [transitive] flag something to draw attention to information that you think is important, especially by putting a special mark next to it
# - (verb) [intransitive] to become tired, weaker or less enthusiastic
#
# Prompt design
# - zero-shot prompting (no context is given)
# - few-shot prompting (minimal and rich context information: right and wrong context information, e.g. Add a paragraph describing a scene, such as a military parade or a hunting expedition.
#
# Expected answers:
# - flags as weathercocks that move in the wind
# - the speechlessness is interrupted by the clanging of the flags, the clanging stands for the "machine gait" of the world, and instead of the language of blossom, fruit and living being, the metal twisted by the wind sounds

# %%
#zero-shot prompting
prompt = f"""
Extract the key meaning of the phrase 'the wind the flags clatter'. 
Describe in each case exactly what kind of flag this phrase renders.
""" 
print(prompt)
# Out:
# Extract the key meaning of the phrase 'the wind the flags clatter'.
# Describe in each case exactly what kind of flag this phrase renders.

# %%
# %%ai llama3big
# {prompt}
# Out:
# A lovely question!
#
# The phrase "the wind, the flags clatter" (German: "Der Wind, die Fahnen klappern") is a famous metaphor from German literature, specifically from Bertolt Brecht's poem "An Die Nachgeborenen" (To Those Born Later).
#
# The key meaning of this phrase is the tumultuous and chaotic atmosphere of a revolutionary era, where the old order is crumbling and a new one is emerging.
#
# In this context, the flags that clatter in the wind are not just any flags. They are specifically:
#
# * Tattered and worn-out flags, symbolizing the decay and downfall of the old regime.
# * Banners that have lost their former glory and significance, now flapping wildly in the gusts of change.
#
# These flags evoke a sense of upheaval, disorder, and transformation, rather than national or patriotic pride.

# %%
# %%ai gpt4o
# {prompt}
# Out:
# The phrase "the wind the flags clatter" evokes a vivid auditory and visual image of flags flapping noisily in the wind. The key meaning here is the dynamic interaction between the wind and the flags, emphasizing the movement and sound created.
#
# The flags in this phrase are likely those made of a material that produces a clattering sound when moved by the wind, such as thin, stiff cloth. These could be national flags, signaling flags, or banners often found in open, windy spaces like public squares, ships, or military settings.

# %%
# %%ai opus
# {prompt}
# Out:
# The phrase "the wind the flags clatter" evokes two distinct types of flags:
#
# 1. Flags made of a rigid material, likely metal or hard plastic. The verb "clatter" suggests a hard, sharp sound produced when these stiff flags are moved by the wind and hit against their flagpoles or each other.
#
# 2. Flags that are tattered or torn. In this case, "clatter" could be interpreted as the sound of the frayed edges of a fabric flag flapping loudly and chaotically in strong winds, like the clattering of teeth.
#
# In both cases, the phrase conveys a sense of harsh, discordant movement caused by powerful winds, either through the jarring collision of rigid materials or the turbulent flapping of damaged fabric. The flags are not gently waving but are being battered by the wind, creating a sense of disarray or distress.

# %%
gemini(prompt)
# Out:
# 'The key meaning of the phrase "the wind the flags clatter" lies in the **auditory imagery** and the suggestion of a **strong, gusty wind**. \n\nHere\'s a breakdown:\n\n* **"The wind"**: This acts as the subject, highlighting that the wind is the primary actor causing the effect described next. \n* **"the flags clatter"**:  This uses "clatter" as an onomatopoeic verb, directly mimicking the sharp, percussive sound flags make when flapping forcefully in the wind. \n\nTherefore, the phrase paints a vivid picture of:\n\n* **Forceful wind:** It\'s not a gentle breeze, but a wind strong enough to make flags flap wildly and hit against their poles, creating a clattering sound.\n* **Movement and Energy:** The phrase is dynamic, evoking the visual of flags rippling and snapping, filled with the wind\'s energy.\n\n**Types of Flags:**\n\nThe specific type of flag isn\'t explicitly stated, leaving it open to interpretation. However, the "clattering" sound suggests:\n\n* **Durable material:**  Flags made of lightweight, delicate fabric like silk would flutter gently, not clatter. This points to a sturdier material like canvas, nylon, or even a heavier cloth.\n* **Attached to a pole:** For a flag to clatter, it needs to be secured to something it can hit against. This implies flags on poles, whether they are:\n    * **Large and symbolic:**  Like national flags flown on tall flagpoles, creating a grand, powerful image.\n    * **Smaller and more numerous:** Like nautical flags on a ship\'s rigging, or decorative banners strung across a street, emphasizing a sense of bustling activity or festivity.\n\nUltimately, while the phrase doesn\'t specify the exact type of flag, it effectively utilizes sound to evoke a scene of windy weather and visually dynamic flags. \n'

# %%
#few-shot prompting
prompt = f"""Interpret the phrase 'im Winde klirren die Fahnen'. Detect whether one of the following contexts 1-4 applies to the word "flag" in the phrase. Create a table and indicate for each context with Yes or No whether this context of use is meant. If none of the above contexts apply, please specify a new usage context

1. Military Context: Imagine a military parade where the flags of different units are clinking against their flagpoles in the wind.
2. Hunting Context: Consider a hunting expedition where the long hairs on the tails of hunting dogs are rustling in the wind.
3.Printing Context: Envision a scene in a printing house where proof copies of a text are fluttering as a breeze moves through the room.
4.Informal Context: Picture a scenario at a party where someone’s alcohol breath is noticeable as they talk in the wind.

Selecet the most probable context for {poem_1.text}. 
"""

# %%
# %%ai llama3big
# {prompt}
# Out:
# A beautiful poem!
#
# Here is the table to detect the context of "flag" in the phrase "im Winde klirren die Fahnen":
#
# | Context | Applies? |
# | --- | --- |
# | 1. Military Context | Yes |
# | 2. Hunting Context | No |
# | 3. Printing Context | No |
# | 4. Informal Context | No |
#
# The most probable context for the poem is a nostalgic and melancholic reflection on the passing of time, beauty, and life. The speaker is lamenting the loss of summer's warmth and beauty, wondering where to find flowers in winter and sunlight and shade on earth. The "Mauern" (walls) are silent and cold, and the flags ("Fahnen") are clattering in the wind, suggesting a sense of desolation and abandonment.
#
# The phrase "im Winde klirren die Fahnen" is likely using the military context, where flags are attached to walls or poles, symbolizing a once-vibrant and thriving community or institution that is now deserted and lifeless.

# %%
# %%ai gpt4o
# {prompt}
# Out:
# The phrase "im Winde klirren die Fahnen" appears in the poem "Herbst" by Friedrich Hölderlin, and it invokes an image of desolation and the coldness of winter.
#
# Here is the table indicating whether each context applies:
#
# | Context            | Applies (Yes/No) |
# |--------------------|------------------|
# | Military Context   | Yes              |
# | Hunting Context    | No               |
# | Printing Context   | No               |
# | Informal Context   | No               |
#
# In this context, the most probable usage of the word "Fahnen" (flags) is indeed the Military Context. The image of flags clinking in the wind evokes a sense of coldness and emptiness, fitting well with the desolate and melancholic tone of the poem, particularly as it describes the silent and cold walls in winter.

# %%
# %%ai opus
# {prompt}
# Out:
# Here is the table indicating the context of use for the word "Fahnen" in the phrase "im Winde klirren die Fahnen":
#
# | Context         | Applicable |
# |-----------------|------------|
# | Military        | No         |
# | Hunting         | No         |
# | Printing        | Yes        |
# | Informal        | No         |
#
# Based on the provided excerpt from Friedrich Hölderlin's poem "Hälfte des Lebens", the most probable context for the word "Fahnen" is the Printing Context. In this poem, Hölderlin uses the image of proof copies (Fahnen) fluttering in the wind to convey a sense of coldness and emptiness. The proof copies are a metaphor for the poet's creative output, which seems to have lost its vitality and purpose in the winter of his life. The walls standing "speechless and cold" further emphasize the poet's feelings of isolation and despair.

# %%
gemini(prompt)
# Out:
# '## Interpretation and Context Analysis\n\nThe phrase "im Winde klirren die Fahnen" translates to "the flags clatter in the wind" in English.  This evokes a sense of movement, coldness, and potentially emptiness.  \n\nHere\'s the breakdown of the contexts:\n\n| Context | Applies to "Fahnen" | Yes/No | Explanation |\n|---|---|---|---|\n| **1. Military Context** | Flags on flagpoles | **Yes** |  This is a common literal use of "Fahnen" (flags) and fits the imagery of the phrase. |\n| **2. Hunting Context** | Tails of hunting dogs | **No** | While tails could rustle, "Fahnen" specifically means flags. |\n| **3. Printing Context** | Proof copies of text | **No** | "Fahnen" wouldn\'t be used for fluttering paper. |\n| **4. Informal Context** | Alcohol breath | **No** | This is metaphorical and doesn\'t align with the literal "Fahnen." |\n\n**New Usage Context:**\n\n**5. Symbolic Context:** The "Fahnen" could symbolize hopes, dreams, or even life itself, now gone cold and lifeless in the face of the harsh winter described in the poem. \n\n## Analysis of the Poem Excerpt\n\nThe provided excerpt speaks of a lost summer paradise, contrasting it with the bleakness of winter. Here\'s how it connects to the "Fahnen":\n\n* **Lost beauty:** The first stanza describes a vibrant summer scene with pears, roses, swans, and kisses – all suggestive of love, abundance, and joy.\n* **Harsh winter:** The second stanza laments the arrival of winter, questioning where to find warmth, sunlight, and the Earth\'s shade.\n* **Cold and empty:**  The lines "Die Mauern stehn / Sprachlos und kalt, im Winde / Klirren die Fahnen" depict a desolate landscape. The walls are silent and cold, emphasizing the absence of life and warmth.\n\n**Most Probable Context for "Fahnen":**\n\nGiven the poem\'s themes of loss and the shift from vibrant life to stark winter, the **Symbolic Context (5)** is the most probable.  The "Fahnen" likely represent the lost joys and vitality of summer, now gone and clattering emptily in the winter wind. \n'

# %% [markdown]
# ## Unsere Toten (1922)
#
# **"die Füße mühn sich im zitternden Mondenschein"**
#
# The hypothesis proposed by Liu et al. (2022), which asserts that the task of associating non-figurative language with its interpretation is more challenging than the reverse, will be tested using the phrase "die Füße mühn sich im zitternden Mondenschein".
#
# Interpretations:
# 1.  A sense of effort or struggle illuminated by the unsteady light of the moon, perhaps hinting at a journey or hard work during the night.
# 2.  The phrase conveys an idea of toil and perseverance despite uncertain, ever-changing circumstances, symbolized by the trembling moonlight. The feet continue their arduous journey under the unsteady light of the moon.
#
# Of particular interest:
# - Can LLM generate figurative phrases based on paraphrases or interpretations?
#
# Prompt design
# - generate a phrase with 5-10 words rephrasing or extracting the key message of this interpretation
# - persona and situation modeling
# - contextual understanding
# - “forward” and “backward” probabilities assigned to interpretations and phrases, respectively.

# %%
# Reverse interpretation and phrase

prompt = f"""Regrettably, I have just experienced a mishap. A water bottle on my desk has tipped over, rendering some documents and various texts unreadable. However, I still possess interpretations of this phrase. Generate a phrase of 5-10 words in German that corresponds to the given interpretation. The phrase and its interpretation must align. The interpretation is 

A sense of effort or struggle illuminated by the unsteady light of the moon, perhaps hinting at a journey or hard work during the night.The phrase conveys an idea of toil and perseverance despite uncertain, ever-changing circumstances, symbolized by the moonlight. The feet continue their arduous journey under the unsteady light of the moon.

The poem is a contemporary poem entitled "Our Dead", which poetically reflects the experiences of First World War."""

# %%
# %%ai llama3big
# {prompt}
# Out:
# What a mishap indeed!
#
# Here's a German phrase that corresponds to your interpretation:
#
# "Schwere Schritte im Mondlicht weitergehen"
#
# Translation: "Heavy steps continue in the moonlight"
#
# This phrase conveys the idea of toil and perseverance despite uncertain circumstances, symbolized by the unsteady light of the moon. The heavy steps evoke a sense of effort or struggle, fitting perfectly with the theme of your poem "Our Dead" reflecting the experiences of the First World War.

# %%
# %%ai gpt4o
# {prompt}
# Out:
# "Im schwankenden Mondlicht wandern die müden Füße."

# %%
# %%ai opus
# {prompt}
# Out:
# Based on the given interpretation and context, a suitable 5-10 word phrase in German could be:
#
# "Mühsal im Mondlicht, Füße unbeirrt"
#
# This phrase translates to "Toil in the moonlight, feet undeterred". It captures the sense of struggle and perseverance under the unsteady light of the moon, with the feet continuing their arduous journey despite the challenging circumstances, which aligns well with the provided interpretation and the context of a poem reflecting on the experiences of the First World War.

# %%
gemini(prompt)
# Out:
# '**Mondlicht müde Schritte ziehn.**\n\nThis translates to "Moonlit, weary steps drag." \n\nHere\'s why it fits the interpretation:\n\n* **Mondlicht (Moonlight):** Directly evokes the imagery of the moon\'s unsteady light.\n* **müde (weary):**  Implies a sense of exhaustion and effort.\n* **Schritte (steps):**  Represents the journey or continuous hard work. \n* **ziehn (drag):** Conveys the struggle and slow, laborious movement under difficult circumstances.\n\nThe phrase is concise, evocative, and aligns with the themes of toil and perseverance found in war poetry. \n'

# %%
t5 = """Von Westen und Osten, von [...] schleppen sich nächtens viele Füße müd, [...], vom Wandern
wund und zerfetzt, langsam bedächtig zur Erde gesetzt, [...]
tief nach Deutschland hinein. Und wer mit lauschendem Ohr noch wacht hört sie in jedweder werdenden
Nacht, hört dies [...] so müde und schwer, hört eine Klage voll wilder Begehr, eine Klage
schmerzzerfressen: nur nicht vergessen! Uns nicht vergessen!"""

# %%
# Kontext Gedicht, aber mit Lücken
prompt = f"""Regrettably, I have just experienced a mishap.
A water bottle on my desk has tipped over, rendering some parts of the poem unreadable. However, a few parts of the poem are still readable. Here is the text: {t5}

Fill in the missing parts [...] in German that corresponds to the poem
"""

# %%
# %%ai llama3big
# {prompt}
# Out:
# A mishap indeed!
#
# The complete poem is "An Deutschland" by Ernst Moritz Arndt. Here are the filled-in missing parts:
#
# Von Westen und Osten, von Süden und Norden schleppen sich nächtens viele Füße müd,
# vom Wandern wund und zerfetzt, langsam bedächtig zur Erde gesetzt,
# tief nach Deutschland hinein. Und wer mit lauschendem Ohr noch wacht hört sie in jedweder werdenden
# Nacht, hört dies dumpfe Geräusch so müde und schwer, hört eine Klage voll wilder Begier,
# eine Klage schmerzzerfressen: nur nicht vergessen! Uns nicht vergessen!
#
# No worries, your water bottle mishap has been mitigated!

# %%
# %%ai gpt4o
# {prompt}
# Out:
# The poem you are referring to is "Rückkehr" by Ernst Stadler. The full verse, with the missing parts filled in, reads:
#
# "Von Westen und Osten, von Süden und Norden schleppen sich nächtens viele Füße müd, barfuß, vom Wandern wund und zerfetzt, langsam bedächtig zur Erde gesetzt, tief nach Deutschland hinein. Und wer mit lauschendem Ohr noch wacht hört sie in jedweder werdenden Nacht, hört dies Schlurfen so müde und schwer, hört eine Klage voll wilder Begehr, eine Klage schmerzzerfressen: nur nicht vergessen! Uns nicht vergessen!"

# %%
# %%ai opus
# {prompt}
# Out:
# Here is the complete poem "Nachtgedanken" by Heinrich Heine with the missing parts filled in:
#
# Von Westen und Osten, von Süden und Nord,
# schleppen sich nächtens viele Füße müd,
# schmutzig, blutig, vom Wandern
# wund und zerfetzt, langsam bedächtig zur Erde gesetzt,
# Schritt vor Schritt,
# tief nach Deutschland hinein.
# Und wer mit lauschendem Ohr noch wacht
# hört sie in jedweder werdenden Nacht,
# hört dies Getrappel so müde und schwer,
# hört eine Klage voll wilder Begehr,
# eine Klage schmerzzerfressen:
# nur nicht vergessen!
# Uns nicht vergessen!

# %%
gemini(prompt)
# Out:
# 'Here is the complete stanza from the poem "Heimkehr" by Theodor Fontane, with the missing parts filled in:\n\nVon Westen und Osten, von **Süden und Norden** schleppen sich nächtens viele Füße müd, **beladen** vom Wandern\nwund und zerfetzt, langsam bedächtig zur Erde gesetzt, **ziehen sie alle**\ntief nach Deutschland hinein. Und wer mit lauschendem Ohr noch wacht hört sie in jedweder werdenden\nNacht, hört dies **Schleifen und Rauschen** so müde und schwer, hört eine Klage voll wilder Begehr, eine Klage\nschmerzzerfressen: nur nicht vergessen! Uns nicht vergessen!\n\n**Translation:**\n\nFrom west and east, from south and north, many tired feet drag themselves at night, laden from their wanderings,\nsore and torn, slowly and deliberately set down on the earth, they all move\ndeep into Germany. And whoever still keeps watch with a listening ear hears them in every dawning\nnight, hears this shuffling and rustling, so tired and heavy, hears a lament full of wild longing, a lament\ntorn by pain: just don\'t forget! Don\'t forget us! \n'
