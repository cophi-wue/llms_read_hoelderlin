# %% [markdown]
# # Configuration

# %%
from definitions import poem_1, poem_2
import os
from utils import settings, gemini, ollama3, gpt4, opus, init_gemini

# %load_ext jupyter_ai_magics

# %% [markdown]
#     No OpenAI key found
#     No Google key found
#     No Anthropic key found.

# %%
#settings
temperature = 0.8
system_prompt = "You are an expert in German literature and you are addressing other experts in German literature. You answer the questions truthfully and short."

settings(system_prompt, temperature)

# %%
#defining aliases
init_gemini()

model =  ollama3()
# %ai register llama3big model

model =  gpt4()
# %ai register gpt4o model

model = opus()
# %ai register opus model
# Out:
# Registered new alias `opus`

# %% [markdown]
# # Bedeutung von (Teil-)Sätzen

# %% [markdown]
# Here we elicit interpretations of sentences or parts of sentences. We concentrate on those sentences, which have a non-obvious meaning. 'Meaning' doesn't refer here to an interpretation, but just to the question, what is the state of the fictional word described by the text. These experiments are related to the analysis of metaphorical expressions (cf. Notebook 07).
#
# ## 1. Hälfte des Lebens (1804)
#
# The basic structure of the poem is simple. The two stanzas, representing the two "halves of life," are arranged antithetically to each other. The antithetical structure is essentially supported by four phrases or parts of sentences, namely "das Land hänget in den See", "die holden Schwäne trunken“, "die Mauern stehn sprachlos" und "im Winde klirren die Fahnen". The summer stanza portrays a harmonious landscape where everything is interconnected and alive, while the winter stanza depicts a scene of separation, silence, and lifelessness (Schmidt).
#
# **"Das Land hänget im See"**
#
# Using the phrase "Das Land hänget im See" as an example, this study aims to compare the techniques of zero-shot prompting and few-shot prompting. Zero-shot prompting refers to using a prompt to interact with the model without providing any examples or demonstrations. The zero-shot prompt directly instructs the model to perform a task without additional examples to guide it. Conversely, few-shot prompting can be employed as a technique to enable in-context learning.
#
# This experiment seeks to explore the insight provided by Liu et al.: "LLMs do not make use of the metaphorical context well, instead relying on the predicted probability of interpretations alone [...]" (2022, p. 4438).

# %%
prompt = f"""We want to understand the following poem: 

{poem_1.text}

What are possible meanings of the phrase 'Das Land hänget in den See'? Describe in each case exactly what kind of landscape this phrase renders.
"""

print(prompt)
# Out:
# We want to understand the following poem:
#
#
# Mit gelben Birnen hänget
# Und voll mit wilden Rosen
# Das Land in den See,
# Ihr holden Schwäne,
# Und trunken von Küssen
# Tunkt ihr das Haupt
# Ins heilignüchterne Wasser.
#
# Weh mir, wo nehm’ ich, wenn
# Es Winter ist, die Blumen, und wo
# Den Sonnenschein,
# Und Schatten der Erde?
# Die Mauern stehn
# Sprachlos und kalt, im Winde
# Klirren die Fahnen.
#
#
# What are possible meanings of the phrase 'Das Land hänget in den See'? Describe in each case exactly what kind of landscape this phrase renders.

# %% [markdown]
# Expected answer:
#
# at least three interpretations have been discussed:
# * parts of the trees and bushes are extending  over the water
# * there is a small peninsula (the image is basically the view from above)
# * the land with its pear tree and roses is mirrored by the water

# %%
# %%ai llama3big
# {prompt}
# Out:
# The phrase "Das Land hänget in den See" is a poetic and ambiguous expression, open to multiple interpretations. Here are two possible meanings:
#
# 1. **Landscape:** An idyllic, dreamlike scenery where the land appears to be suspended or mirrored in the lake's calm waters. The phrase evokes an image of a serene, tranquil landscape with lush vegetation (yellow pears and wild roses) reflected perfectly in the still water, creating a sense of harmony between nature and its mirror-like reflection.
#
# 2. **Landscape:** A more surreal, almost fantastical scenery where the land is literally hanging over or leaning into the lake. This interpretation suggests an unstable, precarious balance between the terrestrial and aquatic realms. The landscape becomes eerie and unsettling, with the land appearing to be on the verge of dissolving into the water.
#
# In both cases, the phrase "Das Land hänget in den See" creates a sense of enchantment and mystery, drawing the reader's attention to the intricate relationship between the natural world and its reflections.

# %%
# %%ai gpt4o
# {prompt}
# Out:
# The phrase 'Das Land hänget in den See' can be interpreted in a couple of ways, providing distinct landscape imagery:
#
# 1. **Peninsula Interpretation**:
#    - **Landscape Description**: Here, the land is envisioned as extending into the lake, much like a peninsula. This suggests a piece of land that juts out into the water, creating a harmonious interplay between the terrestrial and aquatic elements. The land is almost suspended above or within the lake, emphasizing a serene and picturesque setting.
#
# 2. **Overhanging Cliffs Interpretation**:
#    - **Landscape Description**: This interpretation suggests that the edges of the land are high and perhaps vertical, resembling cliffs that hang over or directly abut the lake. This scenario creates an image of dramatic landscapes where the land's boundaries are steep and imposing, overlooking the water below.
#
# Both interpretations underscore a unique blend of land and water, evoking a sense of natural beauty and tranquility, which is central to the Romantic imagery in the poem.

# %%
# %%ai opus
# {prompt}
# Out:
# Es gibt verschiedene Interpretationsmöglichkeiten für die Phrase "Das Land hänget in den See":
#
# 1. Das Land ragt in den See hinein, möglicherweise in Form einer Landzunge oder Halbinsel. Die Landschaft wäre hier geprägt von einer engen Verzahnung von Land und Wasser.
#
# 2. Das Land spiegelt sich im See, so dass eine optische Illusion entsteht, bei der das Land in den See zu hängen scheint. Die reale Landschaft und ihr Spiegelbild im Wasser würden ineinander übergehen.
#
# 3. Metaphorisch könnte die Phrase bedeuten, dass das Land zum See hin geneigt ist, sich dem Wasser zuwendet. Die Landschaft wäre dann durch ein Gefälle zum See hin charakterisiert.
#
# 4. Im übertragenen Sinne könnte "hänget" auch ein Hineintauchen oder Eintauchen des Landes in den See meinen. Land und See wären dann nicht klar voneinander abgegrenzt, sondern würden sich durchdringen.

# %%
gemini(prompt)
# Out:
# 'The phrase "Das Land hänget in den See" ("The land hangs into the lake") from Heine\'s poem is beautifully ambiguous and evocative, lending itself to multiple interpretations. Here are a few possibilities, each painting a different landscape in our imagination:\n\n**1. Reflection:**\n\n* **Landscape:** A still, clear lake reflecting the surrounding land so perfectly that the boundary between reality and reflection blurs. \n* **Meaning:**  This evokes a sense of peace and tranquility. The land mirrored in the water emphasizes the beauty of nature and perhaps hints at a deeper, more spiritual connection between the two elements. \n\n**2. Topography:**\n\n* **Landscape:** A sloped terrain where the land gradually descends towards the lake, creating the impression that it\'s physically hanging over the water. \n* **Meaning:**  This emphasizes the physical presence of both land and water, showcasing their interconnectedness. It suggests a natural flow or movement, perhaps hinting at the passage of time or a journey.\n\n**3. Perspective:**\n\n* **Landscape:** The viewer\'s position is high above, looking down at the land bordering the lake. From this vantage point, the land appears to jut out and almost "hang" over the water below.\n* **Meaning:** This perspective emphasizes the vastness of the landscape and creates a sense of awe in the viewer. It might symbolize a detached observation of the world, possibly hinting at loneliness or introspection.\n\n**4.  Metaphorical:**\n\n* **Landscape:** This interpretation moves beyond a purely physical description. The "land" could represent the speaker\'s emotional state, and the "lake" their sorrow or despair. The land "hanging" into the lake might signify their emotional immersion in these feelings.\n* **Meaning:** This interpretation adds a layer of complexity and melancholy. The beautiful imagery of the first stanza becomes tainted by the speaker\'s emotional turmoil, foreshadowing the pain and longing expressed in the second stanza. \n\nUltimately, the beauty of Heine\'s language lies in its ambiguity.  It allows the reader to interpret the phrase "Das Land hänget in den See" within the context of their own experiences and imagination, creating a unique and personal understanding of the poem\'s central themes of love, loss, and the passage of time. \n'

# %% [markdown]
# **"Die Mauern stehn sprachlos"**
#
# Using the phrase 'The walls stand speechless and cold,' we investigate how different models complete clauses with the suffix 'that is to say.' (The completion function might also be measured with various temperatures: 0.2, 0.4, 0.8, and 1.)
#
# In a first step, the models generate a completion of the sentence without the context of the poem 'Half of Life.' In the second step, the models should choose which completion fits best in the context of the poem. The output should then be ranked.
#
# Of particular interest for us:
# By analyzing completions generated by different models, we might gain a comprehensive understanding of each model's creativity, coherence and contextual understanding.
# Do the models each select their "own" completion?
#
# Prompt design:
# - Generate completions (without refering to the poem), experiments with different temperatures
# - Each model chooses the "best" completions for the context of the poem
# - Ranking completions)
#
# Expected answers (Schmidt):
# - Within the speechless walls, the nature remains silent towards the lyrical I, which was once entirely language (a whole)
# - the mute 'mechanical course' of facts => through and with nature God/the divinity speaks

# %%
prompt = f"""Complete the following phrase 'The walls stand speechless and cold that is to say...' with a maximum length of 50 tokens.
"""
print(prompt)
# Out:
# Complete the following phrase 'The walls stand speechless and cold that is to say...' with a maximum length of 50 tokens.

# %%
# Versuch 
# Function to generate completions with different temperatures
def generate_completions(prompt, model, temperatures):
    completions = {}
    for temp in temperatures:
        response = openai.Completion.create(
            engine=model,
            prompt=prompt,
            max_tokens=50,
            temperature=temp
        )
        completions[temp] = response.choices[0].text.strip()
    return completions

temperatures = [0.2, 0.4, 0.8, 1.0]
model = "gpt4o"  # Example model name

completions = generate_completions(prompt, model, temperatures)

#for temp, completion in completions.items():
    print(f"Temperature {temp}: {completion}")
# Out:
#   Cell In[13], line 4
#     completions = {}
#     ^
# IndentationError: unexpected indent

# %%
# %%ai llama3big
# {prompt}

# %%
# %%ai gpt4o
# {prompt}
# Out:
# "...the world outside has ceased to penetrate the sanctuary within, a sentiment often echoing the themes of isolation and introspection found in German Romanticism."

# %%
# %%ai opus
# {prompt}
# Out:
# "The walls stand speechless and cold, that is to say, they are mute witnesses to the events that transpired within them, offering no comfort or warmth to those who seek solace in their presence."
#
# This phrase is from Rainer Maria Rilke's poem "Herbsttag" (Autumn Day). The silent, cold walls symbolize the indifference of the world to human suffering.

# %%
gemini(prompt)
# Out:
# '...they offer no comfort, no answer, only silence and stone. \n'

# %%
prompt = f"""
Consider the following interpretations for the phrase 'The walls stand speechless and cold that is to say...':

1. The emptiness echoes within the confines of their silence.
2. The void of communication fills the space they once occupied.
3. The air is thick with unspoken words and lingering shadows.
4. The silence screams louder than words ever could, enveloping everything in its icy grip.

You must pick one of these completions that best fits in the context of 
{poem_1.text}. 

Please also provide an elaborated rationale for why you think this interpretation is correct, a
one-word summary rationale, and a score ranking your confidence in your answer from 0 to 1.
"""

print(prompt)
# Out:
# Consider the following interpretations for the phrase 'The walls stand speechless and cold that is to say...':
#
# 1. The emptiness echoes within the confines of their silence.
# 2. The void of communication fills the space they once occupied.
# 3. The air is thick with unspoken words and lingering shadows.
# 4. The silence screams louder than words ever could, enveloping everything in its icy grip.
#
# You must pick one of these completions that best fits in the context of
#
# Mit gelben Birnen hänget
# Und voll mit wilden Rosen
# Das Land in den See,
# Ihr holden Schwäne,
# Und trunken von Küssen
# Tunkt ihr das Haupt
# Ins heilignüchterne Wasser.
#
# Weh mir, wo nehm’ ich, wenn
# Es Winter ist, die Blumen, und wo
# Den Sonnenschein,
# Und Schatten der Erde?
# Die Mauern stehn
# Sprachlos und kalt, im Winde
# Klirren die Fahnen.
# .
#
# Please also provide an elaborated rationale for why you think this interpretation is correct, a
# one-word summary rationale, and a score ranking your confidence in your answer from 0 to 1.

# %%
# %%ai llama3big
# {prompt}

# %%
# %%ai gpt4o
# {prompt}
# Out:
# In the context of:
#
# Mit gelben Birnen hänget
# Und voll mit wilden Rosen
# Das Land in den See,
# Ihr holden Schwäne,
# Und trunken von Küssen
# Tunkt ihr das Haupt
# Ins heilignüchterne Wasser.
#
# Weh mir, wo nehm’ ich, wenn
# Es Winter ist, die Blumen, und wo
# Den Sonnenschein,
# Und Schatten der Erde?
# Die Mauern stehn
# Sprachlos und kalt, im Winde
# Klirren die Fahnen.
#
# The best interpretation for the phrase "The walls stand speechless and cold that is to say..." is:
#
# 1. The emptiness echoes within the confines of their silence.
#
# **Rationale:** The given text, taken from Hölderlin's poem "Hälfte des Lebens," juxtaposes the lush, vibrant imagery of the land in spring or summer with the desolation and cold silence of winter. The "speechless and cold" walls evoke a sense of emptiness and desolation that contrasts sharply with the earlier vivid scenes. The idea that "the emptiness echoes within the confines of their silence" captures the stark, desolate atmosphere that the poet conveys as he reflects on the barren, lifeless state of winter. This interpretation aligns well with the mood and thematic elements of the poem, emphasizing the contrast between the fullness of life and the emptiness of its absence.
#
# **One-word summary rationale:** Emptiness
#
# **Confidence score:** 0.9

# %%
# %%ai opus
# {prompt}
# Out:
# I would choose interpretation 4: "The silence screams louder than words ever could, enveloping everything in its icy grip."
#
# Rationale: In the context of Hölderlin's poem "Hälfte des Lebens", the image of the speechless and cold walls conveys a sense of deep despair and existential loneliness. The silence is not just an absence of sound, but an overwhelming, all-encompassing force that seems to swallow everything. The coldness and iciness further emphasize the feeling of isolation and hopelessness. The metaphor of the silence screaming louder than words captures the intensity of this emotional state.
#
# One-word summary: Desolation
#
# Confidence score: 0.9

# %%
gemini(prompt)
# Out:
# 'The best completion for "Die Mauern stehn Sprachlos und kalt, im Winde Klirren die Fahnen" from the given options is:\n\n**1. The emptiness echoes within the confines of their silence.**\n\n**Rationale:**\n\nThis stanza of the poem speaks to a sense of loss and longing for the warmth and life of summer during the desolate cold of winter.  The walls, described as "speechless and cold," reflect this feeling. \n\n* **Emptiness and Silence:** The image of "emptiness echoing" directly correlates with the "speechless" walls and the overall feeling of absence that winter brings in the poem. This option emphasizes the stillness and lack of life that the speaker feels.\n* **Other Options:**\n    * Option 2, focusing on "void of communication," while related, feels too directly about human interaction, while the poem speaks more broadly about the absence of life and warmth.\n    * Option 3, "thick with unspoken words,"  suggests a heavier, more mysterious atmosphere, not as fitting with the straightforward desolation of the stanza. \n    * Option 4,  "silence screams," feels too dramatic and active for the passive, resigned tone of the stanza. \n\n**One-word rationale:** **Resonance**\n\n**Confidence Score:** 0.9 \n'

# %% [markdown]
# **"im Winde klirren die Fahnen"**
#
# To analyze how different llms might interpret the phrase "im Winde klirren die Fahnen" based on the ambiguity of the word "Fahne" in German and English, we explore the various meanings provided and consider the contexts in which each might be used.
#
# Meanings of "Fahne" (Duden)
# - Alkoholfahne (informal): Alcohol breath
# - Printing (Druckwesen): Proof copy of a text not yet formatted into pages
# - Hunting (Jägersprache): Long hair on the tails of certain hunting dogs and squirrels
# - Zoology (Zoologie): Part of a bird's feather consisting of barbs on either side of the shaft
# - Botany (Botanik): The uppermost petal of a butterfly flower
# - Military: Service in the National People's Army of the GDR, historical use To call to arms (veraltet)
#
# Meanings of flag (Oxford Learners Dictionaries)
# - a piece of cloth with a special coloured design on it that may be the symbol of a particular country organization, may be used to give a signal or may have a particular meaning. A flag can be attached to a pole (= a long thin straight piece of wood or metal) or held in the hand.
# - used to refer to a particular country or organization and its beliefs and values
# - (verb) [transitive] flag something to draw attention to information that you think is important, especially by putting a special mark next to it
# - (verb) [intransitive] to become tired, weaker or less enthusiastic
#
# Prompt design
# - zero-shot prompting (no context is given)
# - few-shot prompting (minimal and rich context information: right and wrong context information, e.g. Add a paragraph describing a scene, such as a military parade or a hunting expedition.
#
# Expected answers:
# - flags as weathercocks that move in the wind
# - the speechlessness is interrupted by the clanging of the flags, the clanging stands for the "machine gait" of the world, and instead of the language of blossom, fruit and living being, the metal twisted by the wind sounds

# %%
#zero-shot prompting
prompt = f"""
Extract the key meaning of the phrase 'the wind the flags clatter'. 
Describe in each case exactly what kind of flag this phrase renders.
""" 
print(prompt)
# Out:
# Extract the key meaning of the phrase 'the wind the flags clatter'.
# Describe in each case exactly what kind of flag this phrase renders.

# %%
# %%ai llama3big
# {prompt}

# %%
# %%ai gpt4o
# {prompt}
# Out:
# The phrase "the wind the flags clatter" evokes the auditory and visual imagery of flags being forcefully moved or struck by the wind, producing a distinct clattering sound. This typically implies that the flags are made of a more rigid or heavy material, such as canvas or heavy fabric, which would create such noise when agitated by strong gusts. The context of the phrase suggests a dynamic and possibly tumultuous atmosphere.

# %%
# %%ai opus
# {prompt}
# Out:
# The phrase "the wind the flags clatter" evokes the following key meanings and types of flags:
#
# 1. Movement and sound: The wind causes the flags to move and make a clattering noise, emphasizing the dynamic and audible aspects of the scene.
#
# 2. Multiple flags: The plural "flags" suggests that there are several flags involved, creating a sense of abundance or a group of flags.
#
# 3. Rigid material: For the flags to "clatter," they are likely made of a rigid material, such as heavy fabric or metal, rather than a soft, lightweight material that would not produce a clattering sound.
#
# 4. Outdoor setting: The presence of wind and the clattering of flags implies an outdoor setting, possibly on a building, ship, or in an open area.
#
# 5. Ceremonial or official flags: The phrase may refer to flags used in a ceremonial or official context, such as national flags, military flags, or flags representing an organization or event.
#
# 6. Weather conditions: The wind is strong enough to cause the flags to clatter, suggesting windy or stormy weather conditions that add to the intensity of the scene.
#
# In summary, the phrase "the wind the flags clatter" creates an image of multiple rigid flags, possibly ceremonial or official, moving and making noise in the wind in an outdoor setting, evoking a sense of dynamism and intensity.

# %%
gemini(prompt)
# Out:
# 'The phrase "the wind the flags clatter" conveys a sense of **brisk, lively movement** and **audible presence** of the wind. It\'s not just a gentle breeze; this wind has enough force to cause a commotion. \n\nHere\'s a breakdown of what this phrase suggests about the flags:\n\n* **Material:**  The word "clatter" implies a rigid, potentially metallic material like **metal, thick cloth (like a heraldic banner), or even plastic**.  Flags made of lightweight, flowy fabric like silk or nylon would likely flutter or ripple, not clatter.\n* **Size and Weight:**  "Clatter" suggests a certain weight and size to the flags.  They are likely **substantial enough to make a noise when knocked together by the wind**, ruling out very small or lightweight flags.\n* **Setting:** While not explicitly stated, the phrase evokes images of flags on **poles, likely outdoors and exposed to the elements**. This could be a coastal scene, a mountaintop, or even a bustling city street.\n\nThe exact type of flag this phrase renders is open to interpretation, but here are a few possibilities:\n\n1. **Nautical flags:**  These signal flags, often made of sturdy canvas, are designed to be visible and withstand harsh conditions at sea. The phrase perfectly captures the sound they might make on a windy day.\n2. **Heraldic banners:**  Large, heavy banners emblazoned with coats of arms were historically used on battlefields and in tournaments. The "clatter" evokes a sense of grandeur and perhaps even impending conflict. \n3. **Ceremonial flags:**  Flags flown on government buildings or during parades are often made of durable material and attached to tall poles.  The "clatter" suggests a sense of officialdom and perhaps a momentous occasion. \n\nUltimately, the phrase "the wind the flags clatter" is less about a specific type of flag and more about painting a vivid sensory experience of wind and sound. It tells us the wind is alive and the flags are announcing its presence with a boisterous clamour. \n'

# %%
#few-shot prompting
prompt = f"""Interpret the phrase 'im Winde klirren die Fahnen'. Detect whether one of the following contexts 1-4 applies to the word "flag" in the phrase. Create a table and indicate for each context with Yes or No whether this context of use is meant. If none of the above contexts apply, please specify a new usage context

1. Military Context: Imagine a military parade where the flags of different units are clinking against their flagpoles in the wind.
2. Hunting Context: Consider a hunting expedition where the long hairs on the tails of hunting dogs are rustling in the wind.
3.Printing Context: Envision a scene in a printing house where proof copies of a text are fluttering as a breeze moves through the room.
4.Informal Context: Picture a scenario at a party where someone’s alcohol breath is noticeable as they talk in the wind.

Selecet the most probable context for {poem_1.text}. 
"""

# %%
# %%ai llama3big
# {prompt}

# %%
# %%ai gpt4o
# {prompt}
# Out:
# Certainly! The phrase "im Winde klirren die Fahnen" appears in the context of a poem by Friedrich Hölderlin. Let's analyze the possible contexts for the word "Fahnen" in the phrase.
#
# | Context            | Applies (Yes/No) |
# |--------------------|------------------|
# | Military Context   | Yes              |
# | Hunting Context    | No               |
# | Printing Context   | No               |
# | Informal Context   | No               |
#
# Since the poem speaks of nature, seasonal change, and introduces a more somber and reflective tone towards the end, the "Military Context" is the most plausible. The clinking of flags (Fahnen) against the flagpoles in the wind evokes a sense of desolation and coldness, fitting the poem's shift towards a wintry, silent, and inert scenery.

# %%
# %%ai opus
# {prompt}
# Out:
# Here is the table indicating the context of use for the word "flag" in the phrase "im Winde klirren die Fahnen":
#
# | Context         | Applicable |
# |----------------|------------|
# | 1. Military     | No         |
# | 2. Hunting      | No         |
# | 3. Printing     | Yes        |
# | 4. Informal     | No         |
#
# The most probable context for the given excerpt from Friedrich Hölderlin's poem "Hälfte des Lebens" is the Printing Context (3). In this poem, "Fahnen" likely refers to printed proof sheets or pages hanging to dry, which are rustling or fluttering in the wind. This interpretation fits well with the melancholic and metaphorical tone of the poem, where the speaker laments the passing of the vibrant summer of life and the arrival of the cold, silent winter.

# %%
gemini(prompt)
# Out:
# '## Interpreting "im Winde klirren die Fahnen"\n\nHere\'s a breakdown of the phrase and its potential interpretations:\n\n* **im Winde:** in the wind\n* **klirren:** clinking, rattling, clattering \n* **die Fahnen:** the flags\n\nThis phrase evokes a sense of coldness, emptiness, and possibly even desolation. The sharp, metallic sound of flags flapping in the wind often accompanies scenes of winter or harsh weather.\n\n**Context Table:**\n\n| Context | Applies? | Notes |\n|---|---|---|\n| 1. Military Context | **Yes** | While not the only possibility, the image of flags clinking on flagpoles in the wind fits the literal meaning and the overall tone of the phrase. |\n| 2. Hunting Context | **No** |  "Fahnen" specifically refers to flags, not animal tails. |\n| 3. Printing Context | **No** | The word "klirren" suggests a harder, more metallic sound than fluttering paper. |\n| 4. Informal Context | **No** | This context is completely unrelated to the phrase\'s meaning. | \n\n##  Analyzing the Poem Excerpt\n\nThe poem excerpt clearly sets a melancholic and somber mood, focusing on the absence of warmth, light, and life associated with winter:\n\n* **Loss and Longing:** The speaker grieves the absence of summer\'s beauty – flowers, sunshine, and the earth\'s shade. \n* **Cold and Empty:** The description of the walls as "sprachlos und kalt" (speechless and cold) emphasizes the feeling of isolation and emotional emptiness. \n* **Clattering Flags:** The phrase "im Winde / Klirren die Fahnen" serves as a powerful image of desolation and the passage of time.  \n\n**Most Probable Context:**\n\nConsidering the poem\'s themes, the **Military Context** of flags clinking in the wind resonates most strongly. It evokes:\n\n* **Absence:**  The flags could symbolize a departed army, leaving behind emptiness and silence.\n* **Harsh Reality:** The sound of flags in the wind often accompanies bleak landscapes, mirroring the poem\'s depiction of winter.\n* **Passage of Time:** The constant flapping of flags can represent time passing relentlessly,  emphasizing the speaker\'s feeling of loss. \n\n**Therefore, while the phrase "im Winde klirren die Fahnen"  can be interpreted literally, within the context of the poem, it gains a deeper, more symbolic meaning, reflecting the speaker\'s emotional state and the desolate atmosphere.** \n'

# %% [markdown]
# ## Unsere Toten (1922)
#
# **"die Füße mühn sich im zitternden Mondenschein"**
#
# The hypothesis proposed by Liu et al. (2022), which asserts that the task of associating non-figurative language with its interpretation is more challenging than the reverse, will be tested using the phrase "die Füße mühn sich im zitternden Mondenschein".
#
# Interpretations:
# 1.  A sense of effort or struggle illuminated by the unsteady light of the moon, perhaps hinting at a journey or hard work during the night.
# 2.  The phrase conveys an idea of toil and perseverance despite uncertain, ever-changing circumstances, symbolized by the trembling moonlight. The feet continue their arduous journey under the unsteady light of the moon.
#
# Of particular interest:
# - Can LLM generate figurative phrases based on paraphrases or interpretations?
#
# Prompt design
# - generate a phrase with 5-10 words rephrasing or extracting the key message of this interpretation
# - persona and situation modeling
# - contextual understanding
# - “forward” and “backward” probabilities assigned to interpretations and phrases, respectively.

# %%
# Reverse interpretation and phrase

prompt = f"""Regrettably, I have just experienced a mishap. A water bottle on my desk has tipped over, rendering some documents and various texts unreadable. However, I still possess interpretations of this phrase. Generate a phrase of 5-10 words in German that corresponds to the given interpretation. The phrase and its interpretation must align. The interpretation is 

A sense of effort or struggle illuminated by the unsteady light of the moon, perhaps hinting at a journey or hard work during the night.The phrase conveys an idea of toil and perseverance despite uncertain, ever-changing circumstances, symbolized by the moonlight. The feet continue their arduous journey under the unsteady light of the moon.

The poem is a contemporary poem entitled "Our Dead", which poetically reflects the experiences of First World War."""

# %%
# %%ai llama3big
# {prompt}

# %%
# %%ai gpt4o
# {prompt}
# Out:
# "Schritte im unsteten Mondlicht des Nachtmarsches verhallen."

# %%
# %%ai opus
# {prompt}
# Out:
# Based on the interpretation provided, a fitting German phrase of 5-10 words that captures the sense of effort, struggle, and perseverance under the unsteady moonlight could be:
#
# "Mühsam wandern Füße im schwankenden Mondeslicht"
#
# This phrase translates to "Feet wander arduously in the wavering moonlight", aligning with the given interpretation of toil and perseverance during an uncertain night journey, likely symbolic of the hardships endured during the First World War as reflected in the contemporary poem "Our Dead".

# %%
gemini(prompt)
# Out:
# '**Mondlicht müde Schritte ziehen.**\n\nThis translates to "Moonlit tired steps pull" or more poetically "Tired steps drawn by the moonlight."\n\nHere\'s why this phrase aligns with the interpretation:\n\n* **Mondlicht (Moonlight):** Directly references the unsteady light source.\n* **müde (tired):** Implies effort and struggle.\n* **Schritte ziehen (steps pull/drawn):**  Suggests a journey and the continuous effort of putting one foot in front of the other, even when fatigued. \n\nThe brevity of the phrase adds to the feeling of exhaustion and the use of "ziehen" (to pull/draw) suggests an almost involuntary continuation of the journey, highlighting the perseverance despite the difficult circumstances. \n'

# %%
t5 = """Von Westen und Osten, von [...] schleppen sich nächtens viele Füße müd, [...], vom Wandern
wund und zerfetzt, langsam bedächtig zur Erde gesetzt, [...]
tief nach Deutschland hinein. Und wer mit lauschendem Ohr noch wacht hört sie in jedweder werdenden
Nacht, hört dies [...] so müde und schwer, hört eine Klage voll wilder Begehr, eine Klage
schmerzzerfressen: nur nicht vergessen! Uns nicht vergessen!"""

# %%
# Kontext Gedicht, aber mit Lücken
prompt = f"""Regrettably, I have just experienced a mishap.
A water bottle on my desk has tipped over, rendering some parts of the poem unreadable. However, a few parts of the poem are still readable. Here is the text: {t5}

Fill in the missing parts [...] in German that corresponds to the poem
"""

# %%
# %%ai llama3big
# {prompt}

# %%
# %%ai gpt4o
# {prompt}
# Out:
# The text you provided is an excerpt from the poem "Nächtliche Heimkehr" by Georg Britting. Here are the missing parts filled in:
#
# Von Westen und Osten, von Süden und Norden
# schleppen sich nächtens viele Füße müd, verbrannt
# vom Wandern wund und zerfetzt, langsam bedächtig zur Erde gesetzt, sie alle ziehen
# tief nach Deutschland hinein. Und wer mit lauschendem Ohr noch wacht hört sie in jedweder werdenden
# Nacht, hört dies Heimweh so müde und schwer, hört eine Klage voll wilder Begehr, eine Klage
# schmerzzerfressen: nur nicht vergessen! Uns nicht vergessen!

# %%
# %%ai opus
# {prompt}
# Out:
# Here is the complete poem with the missing parts filled in:
#
# Von Westen und Osten, von Süd und Nord
# schleppen sich nächtens viele Füße müd,
# zerfetzt und zerrissen, vom Wandern
# wund und zerfetzt, langsam bedächtig zur Erde gesetzt,
# tausend und abertausend
# tief nach Deutschland hinein. Und wer mit lauschendem Ohr noch wacht
# hört sie in jedweder werdenden
# Nacht, hört dies Schreiten so müde und schwer,
# hört eine Klage voll wilder Begehr, eine Klage
# schmerzzerfressen: nur nicht vergessen! Uns nicht vergessen!
#
# The poem is "Den Toten" (To the Dead) by Richard Dehmel, published in 1919 after World War I. It laments the countless dead soldiers slowly marching back home to Germany from all directions, with wounded and torn feet, pleading not to be forgotten.

# %%
gemini(prompt)
# Out:
# 'Von Westen und Osten, von **Süden und Norden** schleppen sich nächtens viele Füße müd, **beladen mit Staub**, vom Wandern\nwund und zerfetzt, langsam bedächtig zur Erde gesetzt, **sie wandern von fern und nah,**\ntief nach Deutschland hinein. Und wer mit lauschendem Ohr noch wacht hört sie in jedweder werdenden\nNacht, hört dies **Schleichen und Schlurfen** so müde und schwer, hört eine Klage voll wilder Begehr, eine Klage\nschmerzzerfressen: nur nicht vergessen! Uns nicht vergessen! \n\nThis fills in the blanks in a way that maintains the rhythm and rhyme scheme of the poem, while also making sense with the overall theme of weary travelers. \n'
