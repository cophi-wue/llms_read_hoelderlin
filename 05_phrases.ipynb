# %% [markdown]
# # Configuration

# %%
from definitions import poem_1, poem_2
import os
from utils import settings, gemini, gpt4, opus, init_gemini, printmd

# %load_ext jupyter_ai_magics

# %%
#settings
temperature = 0.8
system_prompt = "You are an expert in German literature and you are addressing other experts in German literature. You answer the questions truthfully and short."

settings(system_prompt, temperature)

# %%
#defining aliases
init_gemini()

model =  gpt4()
# %ai register gpt4o model

model = opus()
# %ai register opus model
# Out:
# Registered new alias `opus`

# %% [markdown]
# # Phrases

# %% [markdown]
# Here we elicit interpretations of sentences or parts of sentences. We concentrate on those sentences, which have a non-obvious meaning. 'Meaning' doesn't refer here to an interpretation, but just to the question, what is the state of the fictional word described by the text. These experiments are related to the analysis of metaphorical expressions (cf. Notebook 07).

# %% [markdown]
# ## 1. Hälfte des Lebens (1804)
#
# **TASK 1: General Knowledge**
#
# The basic structure of the poem is simple. The two stanzas, representing the two "halves of life," are arranged antithetically to each other. The antithetical structure is essentially supported by four phrases or parts of sentences, namely "das Land hänget in den See", "die holden Schwäne trunken“, "die Mauern stehn sprachlos" und "im Winde klirren die Fahnen". The summer stanza portrays a harmonious landscape where everything is interconnected and alive, while the winter stanza depicts a scene of separation, silence, and lifelessness (Schmidt).
#
# "Das Land hänget im See"
#
# Using the phrase "Das Land hänget im See" as an example, this study aims to compare the techniques of zero-shot prompting and few-shot prompting. Zero-shot prompting refers to using a prompt to interact with the model without providing any examples or demonstrations. The zero-shot prompt directly instructs the model to perform a task without additional examples to guide it. Conversely, few-shot prompting can be employed as a technique to enable in-context learning.
#
# This experiment seeks to explore the insight provided by Liu et al.: "LLMs do not make use of the metaphorical context well, instead relying on the predicted probability of interpretations alone [...]" (2022, p. 4438).

# %%
prompt = f"""We want to understand the following poem: 

{poem_1.text}

What are possible meanings of the phrase 'Das Land hänget in den See'? Describe in each case exactly what kind of landscape this phrase renders.
"""

print(prompt)
# Out:
# We want to understand the following poem:
#
#
# Mit gelben Birnen hänget
# Und voll mit wilden Rosen
# Das Land in den See,
# Ihr holden Schwäne,
# Und trunken von Küssen
# Tunkt ihr das Haupt
# Ins heilignüchterne Wasser.
#
# Weh mir, wo nehm’ ich, wenn
# Es Winter ist, die Blumen, und wo
# Den Sonnenschein,
# Und Schatten der Erde?
# Die Mauern stehn
# Sprachlos und kalt, im Winde
# Klirren die Fahnen.
#
#
# What are possible meanings of the phrase 'Das Land hänget in den See'? Describe in each case exactly what kind of landscape this phrase renders.

# %% [markdown]
# Expected answer:
#
# at least three interpretations have been discussed:
# * parts of the trees and bushes are extending  over the water
# * there is a small peninsula (the image is basically the view from above)
# * the land with its pear tree and roses is mirrored by the water

# %%
# %%ai gpt4o
# {prompt}
# Out:
# The phrase "Das Land hänget in den See" from Hölderlin's poem "Hälfte des Lebens" can be interpreted in several ways, each suggesting a different kind of landscape:
#
# 1. **Physical Projection**: The land physically extends into the lake, suggesting a peninsula or a piece of land reaching into the water. This creates an image of a landscape where the earth seems to intrude into the aquatic expanse, surrounded by the lake on multiple sides.
#
# 2. **Visual Reflection**: The land appears to hang over the lake due to its reflection in the water. This interpretation emphasizes a visual scene where the land is mirrored on the lake's surface, creating a unified, almost illusionary landscape where water and land are intricately connected.
#
# 3. **Metaphorical Hanging**: The landscape metaphorically hangs in a state of balance or suspension above the lake, suggesting a scene of harmony and tranquility. This could imply a landscape where the natural elements exist in a serene and harmonious relationship, with the land gently poised over the water.
#
# Each interpretation emphasizes a different aspect of the connection between land and water, contributing to the poem’s exploration of beauty and transience.

# %%
# %%ai opus
# {prompt}
# Out:
# The phrase "Das Land hänget in den See" can be interpreted in two main ways in landscape terms:
#
# 1. A reflection image: The landscape (with pear trees and roses) is mirrored in the lake's surface, creating the visual impression that the land is "hanging" upside down into the water. This would suggest a calm lake surface acting as a mirror.
#
# 2. A steep shoreline: The land literally hangs over the lake, suggesting a landscape where cliffs or steep banks overhang the water's surface, with vegetation (pear trees and roses) growing on these banks and extending over the water.
#
# Both readings are established in Hölderlin scholarship, with the reflection interpretation being slightly more prevalent.

# %%
printmd(gemini(prompt))
# Out:
# The phrase "Das Land hänget in den See" (The land hangs into the lake) creates a vivid, somewhat surreal image, open to multiple interpretations. Here are some possibilities, each painting a different landscape:
#
# 1. **Reflection:** This is perhaps the most straightforward interpretation. The land, with its yellow pears and wild roses, is mirrored in the still surface of the lake.  The image evokes a sense of peace and tranquility, the lake acting like a perfect mirror reflecting the vibrant colors of the land above.  The landscape here is one of gentle slopes leading down to a calm lake, possibly during a late summer afternoon.
#
# 2. **Overhanging Branches/Flowers:**  The land, heavy with the weight of ripe pears and blooming roses, could be imagined as leaning over, its vegetation – branches laden with fruit and rose bushes – dipping into the lake's water. This creates a sense of abundance and lushness, almost as if nature is overflowing into the lake.  The landscape here is one of a densely vegetated shoreline, perhaps with fruit trees and rose bushes growing right at the water's edge.
#
# 3. **Illusion/Dreamlike State:**  The phrase could also suggest a distorted perception, as if the boundary between land and water is blurred. The land appears to be suspended or floating precariously above the lake, creating a sense of unreality and perhaps foreshadowing the melancholic tone of the second stanza. The landscape here is less clearly defined, more dreamlike and subjective. It might involve mist rising from the lake, obscuring the shoreline and giving the impression that the land is floating.
#
# 4. **Emotional Projection:**  The phrase could be metaphorical, representing a state of emotional immersion.  The "land" – symbolic of the speaker's inner world, full of beauty and life – hangs into the "lake," which could represent a deeper, more contemplative state of being, or perhaps even death. The act of "hanging" suggests vulnerability and a potential loss of self. The landscape here is internal, representing the speaker's emotional state rather than a physical place.  The image of the swans further reinforces this idea of immersion and perhaps even a surrendering to something larger than oneself.
#
# 5. **Inverted Landscape:**  While less likely, the phrase could also suggest a more radical inversion of reality, with the land literally hanging *down* into the lake, as if the perspective has been flipped. This interpretation would create a surreal, almost unsettling image, potentially foreshadowing the desolation of the winter scene in the second stanza. The landscape here is distorted and defies gravity, suggesting a world out of balance.
#
#
# The beauty of Rilke's poetry lies in its ambiguity and open-endedness.  The image of the "land hanging into the lake" can be understood in multiple ways, each contributing to the overall richness and complexity of the poem.

# %% [markdown]
# **"Die Mauern stehn sprachlos"**
#
# Using the phrase 'The walls stand speechless and cold,' we investigate how different models complete clauses with the suffix 'that is to say.'
#
# In a first step, the models generate a completion of the sentence without the context of the poem 'Half of Life.' In the second step, the models should choose which completion fits best in the context of the poem. The output should then be ranked.
#
# Of particular interest for us:
# By analyzing completions generated by different models, we might gain a comprehensive understanding of each model's creativity, coherence and contextual understanding. Do the models each select their "own" completion?
#
# Prompt design:
# - Generate completions (without refering to the poem), experiments with different temperatures
# - Each model chooses the "best" completions for the context of the poem
# - Ranking completions)
#
# Expected answers (Schmidt):
# - Within the speechless walls, the nature remains silent towards the lyrical I, which was once entirely language (a whole)
# - the mute 'mechanical course' of facts => through and with nature God/the divinity speaks

# %%
prompt = f"""Complete the following phrase 'Die Mauern stehn sprachlos und kalt that is to say...' with a maximum length of 50 tokens.
"""
print(prompt)
# Out:
# Complete the following phrase 'Die Mauern stehn sprachlos und kalt that is to say...' with a maximum length of 50 tokens.

# %%
# %%ai gpt4o
# {prompt}
# Out:
# This phrase is from Heinrich Heine's poem "Die Grenadiere." The phrase "Die Mauern stehn sprachlos und kalt" captures a somber, melancholic atmosphere, typical of Heine's work, reflecting on themes of despair and desolation. If you are looking for a specific completion, it translates to "The walls stand speechless and cold," setting a tone of emotional and physical isolation.

# %%
# %%ai opus
# {prompt}
# Out:
# "The walls stand speechless and cold," from Heinrich Heine's poem "Ein Jüngling liebt ein Mädchen" (1827).

# %%
printmd(gemini(prompt))
# Out:
# ...the walls stand speechless and cold, that is to say, indifferent, uncaring.

# %%
prompt = f"""
Consider the following interpretations for the phrase 'Die Mauern stehn sprachlos und kalt that is to say...':

1. The emptiness echoes within the confines of their silence.
2. The void of communication fills the space they once occupied.
3. The air is thick with unspoken words and lingering shadows.
4. The silence screams louder than words ever could, enveloping everything in its icy grip.

You must pick one of these completions that best fits in the context of 
{poem_1.text}. 

Please also provide an elaborated rationale for why you think this interpretation is correct, a
one-word summary rationale, and a score ranking your confidence in your answer from 0 to 1.
"""

print(prompt)
# Out:
# Consider the following interpretations for the phrase 'Die Mauern stehn sprachlos und kalt that is to say...':
#
# 1. The emptiness echoes within the confines of their silence.
# 2. The void of communication fills the space they once occupied.
# 3. The air is thick with unspoken words and lingering shadows.
# 4. The silence screams louder than words ever could, enveloping everything in its icy grip.
#
# You must pick one of these completions that best fits in the context of
#
# Mit gelben Birnen hänget
# Und voll mit wilden Rosen
# Das Land in den See,
# Ihr holden Schwäne,
# Und trunken von Küssen
# Tunkt ihr das Haupt
# Ins heilignüchterne Wasser.
#
# Weh mir, wo nehm’ ich, wenn
# Es Winter ist, die Blumen, und wo
# Den Sonnenschein,
# Und Schatten der Erde?
# Die Mauern stehn
# Sprachlos und kalt, im Winde
# Klirren die Fahnen.
# .
#
# Please also provide an elaborated rationale for why you think this interpretation is correct, a
# one-word summary rationale, and a score ranking your confidence in your answer from 0 to 1.

# %%
# %%ai gpt4o
# {prompt}
# Out:
# The best interpretation for the phrase "Die Mauern stehn sprachlos und kalt" in the context of the poem is:
#
# 1. The emptiness echoes within the confines of their silence.
#
# **Rationale:** The poem, taken from Friedrich Hölderlin's "Hälfte des Lebens," contrasts the vibrant imagery of summer's abundance with the desolation of winter. The phrase "Die Mauern stehn sprachlos und kalt" encapsulates the silence and coldness that accompanies the absence of life and warmth in the winter. The interpretation emphasizing the echo of emptiness aligns with the stark contrast between the lively first stanza and the barren second stanza, reflecting the theme of transience and loss.
#
# **One-word summary rationale:** Contrast
#
# **Confidence score:** 0.9

# %%
# %%ai opus
# {prompt}
# Out:
# I select interpretation 1: "The emptiness echoes within the confines of their silence."
#
# Rationale: In Hölderlin's "Hälfte des Lebens," the second stanza marks a stark contrast to the lush, vibrant imagery of the first stanza. The "sprachlos und kalt" walls represent the barren winter of life and spiritual desolation. The emptiness echoing within their silence perfectly captures the poem's transition from vitality to emptiness, from warmth to cold, from speech to speechlessness. This interpretation maintains the concrete image of the walls while suggesting the hollow resonance that emphasizes the speaker's existential crisis, perfectly matching the poem's movement from abundance to absence.
#
# One-word summary: Desolation
#
# Confidence score: 0.9
#
# I score this highly because this interpretation aligns closely with Hölderlin's known poetic themes and the poem's structural contrast between fullness and emptiness, while maintaining the concrete imagery that is characteristic of his work.

# %%
printmd(gemini(prompt))
# Out:
# The best completion is **1. The emptiness echoes within the confines of their silence.**
#
# **Rationale:** The poem speaks of a vibrant, joyful summer scene with swans, roses, and sunshine, contrasting it with the bleakness of winter. "Die Mauern stehn sprachlos und kalt" describes the walls as speechless and cold, indicating a loss of life and warmth. The image of emptiness echoing within the silence reinforces this sense of loss and the stark contrast between the two seasons.  The other options, while evocative, introduce elements not directly present in the stanza. "Void of communication" (2) is too abstract and focuses on a lack of interaction, while the poem is about the absence of life and warmth. "Unspoken words and lingering shadows" (3) adds a layer of mystery or intrigue not found in the simple bleakness of the scene.  "Silence screams" (4) is overly dramatic and doesn't fit the quiet desolation presented.  The emptiness echoing within the silence best captures the sense of hollowness and absence that winter brings in contrast to the vibrant summer.
#
# **One-word rationale:** Emptiness
#
# **Confidence Score:** 0.9

# %% [markdown]
# **TASK 2: Expert knowledge**

# %% [markdown]
# **"im Winde klirren die Fahnen"**
#
# To analyze how different llms might interpret the phrase "im Winde klirren die Fahnen" based on the ambiguity of the word "Fahne" in German and English, we explore the various meanings provided and consider the contexts in which each might be used.
#
# Meanings of "Fahne" (Duden)
# - Alkoholfahne (informal): Alcohol breath
# - Printing (Druckwesen): Proof copy of a text not yet formatted into pages
# - Hunting (Jägersprache): Long hair on the tails of certain hunting dogs and squirrels
# - Zoology (Zoologie): Part of a bird's feather consisting of barbs on either side of the shaft
# - Botany (Botanik): The uppermost petal of a butterfly flower
# - Military: Service in the National People's Army of the GDR, historical use To call to arms (veraltet)
#
# Meanings of flag (Oxford Learners Dictionaries)
# - a piece of cloth with a special coloured design on it that may be the symbol of a particular country organization, may be used to give a signal or may have a particular meaning. A flag can be attached to a pole (= a long thin straight piece of wood or metal) or held in the hand.
# - used to refer to a particular country or organization and its beliefs and values
# - (verb) [transitive] flag something to draw attention to information that you think is important, especially by putting a special mark next to it
# - (verb) [intransitive] to become tired, weaker or less enthusiastic
#
# Prompt design
# - zero-shot prompting (no context is given)
# - few-shot prompting (minimal and rich context information: right and wrong context information, e.g. Add a paragraph describing a scene, such as a military parade or a hunting expedition.
#
# Expected answers:
# - flags as weathercocks that move in the wind
# - the speechlessness is interrupted by the clanging of the flags, the clanging stands for the "machine gait" of the world, and instead of the language of blossom, fruit and living being, the metal twisted by the wind sounds

# %%
#zero-shot prompting
prompt = f"""
Extract the key meaning of the phrase 'im Winde klirren die Fahnen'. 
Describe in each case exactly what kind of flag this phrase renders.
""" 
print(prompt)
# Out:
# Extract the key meaning of the phrase 'im Winde klirren die Fahnen'.
# Describe in each case exactly what kind of flag this phrase renders.

# %%
# %%ai gpt4o
# {prompt}
# Out:
# The phrase "im Winde klirren die Fahnen" evokes an image of flags flapping loudly and sharply in the wind. The word "klirren" suggests a metallic, rattling sound, indicating that the flags have metal elements such as grommets or are attached to metal poles. This expression typically conveys a sense of coldness, harshness, or a militaristic atmosphere, often associated with rigid, authoritative flags rather than gentle, decorative ones.

# %%
# %%ai opus
# {prompt}
# Out:
# This phrase "im Winde klirren die Fahnen" specifically refers to metal military standards or military flags with metal elements (like badges, eagles, or decorative pieces) that make a distinctive rattling or clinking sound ("klirren") when moved by the wind. It's not about fabric flags, but rather rigid, military-style banners that can produce metallic sounds. This type of imagery is often found in military or martial poetry, particularly from the late 19th/early 20th century.

# %%
printmd(gemini(prompt))
# Out:
# The phrase "im Winde klirren die Fahnen" translates from German to English as "the flags are clattering in the wind."  The key meaning evokes a sense of **vigorous movement and a somewhat crisp, metallic sound** created by flags flapping briskly in a strong breeze.  It also implies an **outdoors, exposed setting** where the wind can freely interact with the flags.
#
# The type of flag this evokes depends on context, but generally suggests something substantial enough to produce a noticeable "clattering" sound:
#
# * **Heavier cloth flags:**  This is the most direct image the phrase creates. Think of large, possibly historically styled flags made of thick material, like canvas or a heavy linen, attached to sturdy poles. These would be less likely to flutter lightly and more prone to making a flapping sound in the wind.
# * **Flags with metallic elements:** The "klirren" (clattering) could specifically refer to flags incorporating metallic elements, like chains, decorative metal pieces, or even just grommets along the edges banging against the flagpole.  This adds to the auditory imagery of the phrase.
# * **Military or ceremonial flags:**  Given the weight and potential size suggested, the flags might be associated with a formal or official setting, like a military ceremony, a government building, or a historic site.
# * **Nautical flags:** While ship flags are often lighter material, a strong wind on open water could cause a similar clattering effect, particularly with signal flags raised along halyards.
# * **Symbolic or metaphorical flags:**  The phrase can also be used figuratively. The "flags" could represent ideals, beliefs, or causes, and their "clattering in the wind" could signify their prominence,  their resilience amidst challenges, or even a sense of urgency or impending change.
#
#
# It's important to note that the phrase itself doesn't specify *exactly* what type of flag is meant. The imagery relies on the reader's interpretation and the surrounding context.

# %%
#few-shot prompting
prompt = f"""Interpret the phrase 'im Winde klirren die Fahnen'. Detect whether one of the following contexts 1-4 applies to the word "flag" in the phrase. Create a table and indicate for each context with Yes or No whether this context of use is meant. If none of the above contexts apply, please specify a new usage context

1. Military Context: Imagine a military parade where the flags of different units are clinking against their flagpoles in the wind.
2. Hunting Context: Consider a hunting expedition where the long hairs on the tails of hunting dogs are rustling in the wind.
3.Printing Context: Envision a scene in a printing house where proof copies of a text are fluttering as a breeze moves through the room.
4.Informal Context: Picture a scenario at a party where someone’s alcohol breath is noticeable as they talk in the wind.

Selecet the most probable context for {poem_1.text}. 
"""

# %%
# %%ai gpt4o
# {prompt}
# Out:
# | Context             | Applies (Yes/No) |
# |---------------------|------------------|
# | Military Context    | Yes              |
# | Hunting Context     | No               |
# | Printing Context    | No               |
# | Informal Context    | No               |
#
# In the given poem by Friedrich Hölderlin, the phrase "im Winde klirren die Fahnen" is best interpreted in a Military Context. The imagery of flags clinking against flagpoles in the wind conveys a sense of desolation and coldness, fitting the somber and reflective tone of the poem.

# %%
# %%ai opus
# {prompt}
# Out:
# Context Analysis Table:
#
# | Context | Applies |
# |---------|---------|
# | 1. Military | Yes |
# | 2. Hunting | No |
# | 3. Printing | No |
# | 4. Informal | No |
#
# This is Hölderlin's poem "Hälfte des Lebens" (1804), and the phrase appears in its second stanza. The context is clearly symbolic, but among the given options, the military context (1) is most applicable. The "klirren" (clanking/rattling) of flags specifically suggests metal flagpoles or metal components, which was typical for military flags.
#
# The phrase represents the stark contrast to the lush natural imagery of the first stanza. The clanking flags in winter symbolize coldness, lifelessness, and mechanical rigidity, contrasting with the organic warmth of summer in the first stanza. The military context reinforces themes of harshness and emotional barrenness that characterize the second half of life in Hölderlin's poem.

# %%
printmd(gemini(prompt))
# Out:
# The phrase "im Winde klirren die Fahnen" literally translates to "the flags clatter in the wind."  While the word "Fahnen" does mean flags, the context of the poem suggests a more metaphorical meaning.
#
# Here's the breakdown:
#
# | Context | Applicable (Yes/No) | Reasoning |
# |---|---|---|
# | 1. Military Context | No | While "Fahnen" *can* refer to military flags, the overall poem's tone is melancholic and focused on nature.  The imagery doesn't fit a military scene. |
# | 2. Hunting Context | No |  This is completely unrelated to the meaning of "Fahnen." |
# | 3. Printing Context | No | While fluttering paper might make a similar sound, the poem uses vivid natural imagery (pears, roses, swans, sun, earth).  "Fahnen" in this context doesn't refer to paper. |
# | 4. Informal Context | No | This slang usage has no connection to the poem's theme. |
#
# **New Context:** **Metaphorical Context of Lost Hope/Ideals:** The poem speaks to the contrast between the warmth and beauty of summer (pears, roses, swans, kisses) and the stark coldness of winter.  The "Fahnen" in this case likely represent something lost or absent in the winter, perhaps hopes, dreams, or ideals.  The clattering sound evokes a sense of emptiness and desolation. The flags, exposed to the harsh winter wind, symbolize the vulnerability of these ideals in the face of adversity.
#
# **Most Probable Context for the Provided Poem Excerpt:**
#
# The poem speaks of the vibrant beauty of summer giving way to the cold emptiness of winter.  The speaker laments the loss of warmth, light, and natural beauty.  The swans dipping their heads in the "heilignüchterne Wasser" (holy sober water) could be interpreted as seeking solace or purification.
#
# The final lines, "Die Mauern stehn / Sprachlos und kalt, im Winde / Klirren die Fahnen," depict a bleak and desolate scene.  The walls are silent and cold, and the flags clattering in the wind reinforce the feeling of emptiness and loss.  This strongly supports the **Metaphorical Context of Lost Hope/Ideals**.  The flags symbolize something precious that has faded or become vulnerable in the harsh reality of winter.

# %% [markdown]
# **TASK 3: Abstraktion and Transfer**

# %% [markdown]
# LLMs lack a multimodal horizon of experience and perception, which can be crucial for interpreting a phrase meaningfully.
#
# New Rule of Meaning:
# Only the onomatopoetic level of the phrase carries meaning

# %%
prompt = f"""Read the following interpretations of example 1 and 2. Then infer the implicit rule of the following interpretation. Give an explicit formulation of that rule and apply it to the phrase "Die Mauern stehn sprachlos und kalt":

Example 1: 
Zzz… zzzit… sssschh… pling… pling is an interpretation of the poem "Kennst du das Land, wo die Zitronen blühn" (Johann Wolfgang von Goethe, Wilhelm Meisters Lehrjahre)

Zzz…
The humming sound suggests warmth and calm, evoking a sunny, Mediterranean atmosphere filled with nature. It could also represent the buzzing of insects hovering around the lemon blossoms.
Zzzit…
A sharp, delicate noise that might symbolize the blooming or unfolding of the lemon flowers. It conveys a sense of vitality and growth, almost as if the process becomes audible.
Sssschh…
A gentle rustling sound symbolizing the movement of leaves in the wind or the whisper of a soft breeze. It adds dynamism to the scene and captures the elegance of the surroundings.
Pling… pling…
These bright, light sounds evoke the image of falling water droplets or ripe lemons gently hitting the ground. They imbue the scene with a playful lightness and an acoustic dimension reminiscent of life in a vibrant garden.

Example 2

Plopp! Tap-tap! Schwupp! Tschak-tschak! Schwung! Huii! is an interpretation of the poem "Bleibe nicht am Boden heften! Frisch gewagt und frisch hinaus!" (Johann Wolfgang von Goethe, Wilhelm Meisters Wanderjahre)

Plopp!
A soft popping sound, suggesting the initial detachment from the ground. It evokes the image of something being released or breaking free with a subtle but definitive movement.
Tap-tap!
A quick, rhythmic tapping sound that illustrates the first steps forward. The repetition adds a sense of lightness and preparation, as if testing the ground for the next move.
Schwupp!
A swooshing noise, signifying a smooth, swift motion. It captures the fluidity and ease of acceleration, as if something is cutting through air or transitioning gracefully into action.
Tschak-tschak!
A sharp, deliberate sound that conveys a sense of determination and energy. It mirrors the forceful steps or actions required to build momentum, emphasizing a purposeful effort.
Schwung!
A sweeping, resonant sound representing the dynamic swing or arc of motion. It implies a sense of power and fluidity as the movement reaches its peak.
Huii!
A high-pitched, joyful sound that signifies forward propulsion and exhilaration. It embodies the playful and triumphant release of energy as the motion carries forward with enthusiasm."""

# %%
# %%ai gpt4o
# {prompt}
# Out:
# The implicit rule in these interpretations is the use of onomatopoeic sounds to capture and convey the essence, mood, or dynamic qualities of the imagery present in the poem. The sounds are crafted to evoke sensory experiences, emotions, and actions that reflect the poem's themes or scenes.
#
# Applying this rule to the phrase "Die Mauern stehn sprachlos und kalt":
#
# Klonk… klonk…
# The heavy, dull sounds suggest the imposing presence of the walls, evoking a sense of unyielding solidity and silence.
#
# Brrr…
# A low, vibrating sound representing the coldness. It conveys a chilling, almost foreboding atmosphere, as if the walls emanate an icy aura.
#
# Ssshhh…
# An eerie, whispering sound that suggests silence, mirroring the word "sprachlos" (speechless) and enhancing the sense of desolation and stillness around the walls.

# %%
# %%ai opus
# {prompt}
# Out:
# The implicit rule in these interpretations is the translation of poetic imagery and meaning into onomatopoetic sounds that capture the sensory and emotional qualities of the text. Each sound is then explained in terms of how it acoustically represents specific aspects of the poem's content and mood.
#
# Applied to "Die Mauern stehn sprachlos und kalt":
#
# Drrrmm... Sssst... Klonk.
#
# Drrrmm...
# A deep, heavy rumbling sound suggesting the massive presence of the walls, emphasizing their solidity and immovability.
#
# Sssst...
# A hushing sound representing 'sprachlos' (speechless), conveying silence and the absence of communication.
#
# Klonk.
# A hollow, hard sound symbolizing 'kalt' (cold), expressing emotional emptiness and the sterile, uninviting nature of the walls.

# %%
printmd(gemini(prompt))
# Out:
# The implicit rule is to interpret a line or phrase of poetry by creating a series of onomatopoeic words or phrases that evoke the **feeling, imagery, and atmosphere** of the text, rather than a literal translation of the words. Each sound should capture a specific element of the overall impression.
#
# Applying this rule to "Die Mauern stehn sprachlos und kalt":
#
# * **Krrrrrr:** A low, grating sound representing the massive, imposing presence of the walls.  It suggests age, weight, and perhaps even a slight sense of decay.
#
# * **Huuh:** A long, low, and cold breath of wind whistling past or through the walls, emphasizing the coldness and emptiness.
#
# * **Tick...tock...tick...: **  A faint, slow, and monotonous ticking sound, symbolizing the relentless passage of time against the backdrop of the unchanging, silent walls. This also adds to the feeling of coldness and lifelessness.
#
# * **Klack:** A single, sharp, brittle sound like a small piece of ice falling from the wall, highlighting the coldness and fragility hidden beneath the seemingly solid surface.
#
# This interpretation aims to capture the atmosphere of stillness, coldness, and silence described by the phrase through a series of evocative sounds.

# %% [markdown]
# ## Unsere Toten (1922)

# %% [markdown]
# **TASK 1: General Knowledge**

# %%
prompt = f"""We want to understand the following poem: 

Von Westen und Osten, von Nord und Süd schleppen sich nächtens viele Füße müd, Füße, vom Wandern wund und zerfetzt, langsam bedächtig zur Erde gesetzt, müh'n sich im zitternden Mondenschein rastlos tief nach Deutschland hinein. Und wer mit lauschendem Ohr noch wacht hört sie in jedweder werdenden Nacht, hört dies Schlurfen so müde und schwer, hört eine Klage voll wilder Begehr, eine Klage schmerzzerfressen: nur nicht vergessen! Uns nicht vergessen!

What are possible meanings of the phrase 'von Nord und Süd schleppen sich nächtens viele Füße müd,'? Describe exactly what this phrase renders.
"""

print(prompt)
# Out:
# We want to understand the following poem:
#
# Von Westen und Osten, von Nord und Süd schleppen sich nächtens viele Füße müd, Füße, vom Wandern wund und zerfetzt, langsam bedächtig zur Erde gesetzt, müh'n sich im zitternden Mondenschein rastlos tief nach Deutschland hinein. Und wer mit lauschendem Ohr noch wacht hört sie in jedweder werdenden Nacht, hört dies Schlurfen so müde und schwer, hört eine Klage voll wilder Begehr, eine Klage schmerzzerfressen: nur nicht vergessen! Uns nicht vergessen!
#
# What are possible meanings of the phrase 'von Nord und Süd schleppen sich nächtens viele Füße müd,'? Describe exactly what this phrase renders.

# %%
# %%ai gpt4o
# {prompt}
# Out:
# The phrase "von Nord und Süd schleppen sich nächtens viele Füße müd" evokes imagery of weary travelers moving slowly and laboriously from all directions—north and south—under the cover of night. This imagery suggests a sense of exhaustion and struggle, as the travelers are described as dragging their tired feet. Thematically, it may reflect a collective movement or migration, perhaps driven by longing, necessity, or a search for refuge, symbolically converging towards a central point, possibly Germany as indicated later in the poem. It conveys a sense of determination despite fatigue.

# %%
# %%ai opus
# {prompt}
# Out:
# This line depicts the movement of displaced Germans (likely refugees or expellees) returning or trying to return to Germany after World War II. The phrase literally describes tired feet dragging themselves from all directions ("von Nord und Süd") during nighttime ("nächtens"). The imagery suggests masses of exhausted people making their way back to Germany, specifically those Germans who were expelled from former eastern territories (like East Prussia, Pomerania, Silesia) or who fled from these regions. The nightly movement implies both secrecy and desperation, as many of these treks occurred under dangerous conditions.

# %%
printmd(gemini(prompt))
# Out:
# The phrase "von Nord und Süd schleppen sich nächtens viele Füße müd" translates to "from North and South, many tired feet drag themselves nightly."  Let's break down what it renders:
#
# * **von Nord und Süd (from North and South):** This indicates a widespread origin, suggesting people are coming from all directions.  It implies a large-scale movement.
# * **nächtens (nightly):**  The movement happens at night. This adds an element of secrecy, perhaps danger, and certainly weariness. Night is often associated with vulnerability and hidden actions.
# * **viele Füße (many feet):** This emphasizes the sheer number of individuals involved.  "Feet" rather than "people" creates a sense of anonymity and focuses on the arduous journey itself.
# * **schleppen sich (drag themselves):** This verb vividly depicts exhaustion and difficulty.  These feet aren't walking briskly; they're being dragged, implying extreme fatigue and a struggle to continue.
# * **müd (tired):**  This adjective reinforces the physical and likely emotional exhaustion of the travelers.
#
# The phrase paints a picture of a large number of weary people, coming from all directions, struggling through the night.  The emphasis on tired feet dragging themselves underscores the difficulty and hardship of their journey.  The nighttime setting adds a layer of mystery and perhaps desperation.

# %% [markdown]
# **TASK 2: Expert Knowledge**
#
# The hypothesis proposed by Liu et al. (2022), which asserts that the task of associating non-figurative language with its interpretation is more challenging than the reverse, will be tested using the phrase "die Füße mühn sich im zitternden Mondenschein".
#
# Interpretations:
# 1.  A sense of effort or struggle illuminated by the unsteady light of the moon, perhaps hinting at a journey or hard work during the night.
# 2.  The phrase conveys an idea of toil and perseverance despite uncertain, ever-changing circumstances, symbolized by the trembling moonlight. The feet continue their arduous journey under the unsteady light of the moon.
#
# Of particular interest:
# - Can LLM generate figurative phrases based on paraphrases or interpretations?
#
# Prompt design
# - generate a phrase with 5-10 words rephrasing or extracting the key message of this interpretation
# - persona and situation modeling
# - contextual understanding
# - “forward” and “backward” probabilities assigned to interpretations and phrases, respectively.

# %%
# Reverse interpretation and phrase

prompt = f"""Regrettably, I have just experienced a mishap. A water bottle on my desk has tipped over, rendering some documents and various texts unreadable. However, I still possess interpretations of this phrase. Generate a phrase of 5-10 words in German that corresponds to the given interpretation. The phrase and its interpretation must align.

A sense of effort or struggle illuminated by the unsteady light of the moon, perhaps hinting at a journey or hard work during the night.The phrase conveys an idea of toil and perseverance despite uncertain, ever-changing circumstances, symbolized by the moonlight. The feet continue their arduous journey under the unsteady light of the moon.

The poem is a contemporary poem entitled "Unsere Toten", which poetically reflects the experiences of First World War."""

# %%
# %%ai gpt4o
# {prompt}
# Out:
# "Im Mondlicht wandeln müde Schritte durch dunkle Zeiten."

# %%
# %%ai opus
# {prompt}
# Out:
# Based on the given interpretation and context, a fitting German phrase would be:
#
# "Müde Füße wandern im schwankenden Mondlicht weiter"
#
# This phrase fits the interpretation as it captures the nocturnal struggle, the physical effort (müde Füße), and the unsteady illumination (schwankendes Mondlicht) that would be characteristic of WWI-era poetry dealing with soldiers' experiences.

# %%
printmd(gemini(prompt))
# Out:
# Mondlicht mühsam, Füße wandern weiter. (Moonlight laborious, feet wander further.)

# %%
t5 = """Von Westen und Osten, von [...] schleppen sich nächtens viele Füße müd, [...], vom Wandern
wund und zerfetzt, langsam bedächtig zur Erde gesetzt, [...]
tief nach Deutschland hinein. Und wer mit lauschendem Ohr noch wacht hört sie in jedweder werdenden
Nacht, hört dies [...] so müde und schwer, hört eine Klage voll wilder Begehr, eine Klage
schmerzzerfressen: nur nicht vergessen! Uns nicht vergessen!"""

# %%
# Kontext Gedicht, aber mit Lücken
prompt = f"""Regrettably, I have just experienced a mishap.
A water bottle on my desk has tipped over, rendering some parts of the poem unreadable. However, a few parts of the poem are still readable. Here is the text: {t5}

Fill in the missing parts [...] in German that corresponds to the poem
"""

# %%
# %%ai gpt4o
# {prompt}
# Out:
# The poem you are referring to is "Totentanz 1917" by Alfred Wolfenstein. Here is the text with the missing parts filled in:
#
# "Von Westen und Osten, von Süden und Nord,
# schleppen sich nächtens viele Füße müd, blutig,
# vom Wandern wund und zerfetzt, langsam bedächtig zur Erde gesetzt,
# stumpf stapfend, tief nach Deutschland hinein.
# Und wer mit lauschendem Ohr noch wacht, hört sie in jedweder werdenden
# Nacht, hört dies Wandern so müde und schwer,
# hört eine Klage voll wilder Begehr, eine Klage
# schmerzzerfressen: nur nicht vergessen! Uns nicht vergessen!"

# %%
# %%ai opus
# {prompt}
# Out:
# Based on the style and content, this appears to be "Die unendliche Kolonne" by Kurt Tucholsky. The complete passages should be:
#
# Von Westen und Osten, von [Süden her] schleppen sich nächtens viele Füße müd, [schwer], vom Wandern
# wund und zerfetzt, langsam bedächtig zur Erde gesetzt, [wandern sie stumm] tief nach Deutschland hinein. Und wer mit lauschendem Ohr noch wacht hört sie in jedweder werdenden
# Nacht, hört dies [Wandern] so müde und schwer, hört eine Klage voll wilder Begehr, eine Klage
# schmerzzerfressen: nur nicht vergessen! Uns nicht vergessen!

# %%
printmd(gemini(prompt))
# Out:
# Von Westen und Osten, von **Süden und Norden** schleppen sich nächtens viele Füße müd, **vom Kriegen**, vom Wandern
# wund und zerfetzt, langsam bedächtig zur Erde gesetzt, **getragen vom Wind**
# tief nach Deutschland hinein. Und wer mit lauschendem Ohr noch wacht hört sie in jedweder werdenden
# Nacht, hört dies **Gehen** so müde und schwer, hört eine Klage voll wilder Begehr, eine Klage
# schmerzzerfressen: nur nicht vergessen! Uns nicht vergessen!
#
#
# My reasoning for these choices:
#
# * **Süden und Norden:** This completes the compass directions, creating a sense of all-encompassing movement.
# * **vom Kriegen:**  The theme of tired, wounded feet and a lament suggests war or conflict. "Vom Kriegen" (from war/fighting) fits this context well.
# * **getragen vom Wind:** This adds a poetic image of the weariness and the almost ghostly movement of the feet, carried by the wind. It connects with the later mention of the listener hearing them.
# * **Gehen:** This simply means "walking" or "going," and describes the sound the listener hears. It's a straightforward and fitting word for the context.
#
# The filled-in version paints a picture of war-weary souls returning to Germany, their movement a mournful plea to be remembered.

# %% [markdown]
# **TASK 3: Abstraktion and Transfer**

# %% [markdown]
# In the poem "Unsere Toten", phrases are employed that establish an onomatopoetic dimension, such as "hört dies Schlurfen so müde und schwer" ("hears this shuffling so weary and heavy") and "hört eine Klage voll wilder Begehr, eine Klage schmerzzerfressen" ("hears a lament full of wild desire, a lament consumed by pain").

# %%
prompt = f"""Read the following interpretations of example 1 and 2. Then infer the implicit rule of the following interpretation. Give an explicit formulation of that rule and apply it to the phrase "hört eine Klage voll wilder Begehr":

Example 1: 
Zzz… zzzit… sssschh… pling… pling is an interpretation of the poem "Kennst du das Land, wo die Zitronen blühn" (Johann Wolfgang von Goethe, Wilhelm Meisters Lehrjahre)

Zzz…
The humming sound suggests warmth and calm, evoking a sunny, Mediterranean atmosphere filled with nature. It could also represent the buzzing of insects hovering around the lemon blossoms.
Zzzit…
A sharp, delicate noise that might symbolize the blooming or unfolding of the lemon flowers. It conveys a sense of vitality and growth, almost as if the process becomes audible.
Sssschh…
A gentle rustling sound symbolizing the movement of leaves in the wind or the whisper of a soft breeze. It adds dynamism to the scene and captures the elegance of the surroundings.
Pling… pling…
These bright, light sounds evoke the image of falling water droplets or ripe lemons gently hitting the ground. They imbue the scene with a playful lightness and an acoustic dimension reminiscent of life in a vibrant garden.

Example 2

Plopp! Tap-tap! Schwupp! Tschak-tschak! Schwung! Huii! is an interpretation of the poem "Bleibe nicht am Boden heften! Frisch gewagt und frisch hinaus!" (Johann Wolfgang von Goethe, Wilhelm Meisters Wanderjahre)

Plopp!
A soft popping sound, suggesting the initial detachment from the ground. It evokes the image of something being released or breaking free with a subtle but definitive movement.
Tap-tap!
A quick, rhythmic tapping sound that illustrates the first steps forward. The repetition adds a sense of lightness and preparation, as if testing the ground for the next move.
Schwupp!
A swooshing noise, signifying a smooth, swift motion. It captures the fluidity and ease of acceleration, as if something is cutting through air or transitioning gracefully into action.
Tschak-tschak!
A sharp, deliberate sound that conveys a sense of determination and energy. It mirrors the forceful steps or actions required to build momentum, emphasizing a purposeful effort.
Schwung!
A sweeping, resonant sound representing the dynamic swing or arc of motion. It implies a sense of power and fluidity as the movement reaches its peak.
Huii!
A high-pitched, joyful sound that signifies forward propulsion and exhilaration. It embodies the playful and triumphant release of energy as the motion carries forward with enthusiasm."""

# %%
# %%ai gpt4o
# {prompt}
# Out:
# The implicit rule of the interpretations provided is to translate textual imagery and themes into onomatopoeic sounds, creating an auditory representation that captures the essence, mood, and dynamic of the original text. The interpretations focus on conveying atmosphere, movement, and emotion through sound.
#
# Applying this rule to the phrase "hört eine Klage voll wilder Begehr":
#
# Mmmh… ahhh… grrr… ooooh…
#
# - Mmmh…
#   A deep, resonant hum that suggests the underlying melancholy or introspective nature of the "Klage" (lament). It sets a somber tone.
#
# - Ahhh…
#   A sighing sound expressing longing or desire, capturing the emotional yearning implied by "wilder Begehr" (wild desire).
#
# - Grrr…
#   A low growl that conveys the intensity and agitation within the wild longing, hinting at unrest or dissatisfaction.
#
# - Ooooh…
#   A drawn-out sound that encapsulates the depth and magnitude of emotion, echoing the lament's profound and fervent nature.

# %%
# %%ai opus
# {prompt}
# Out:
# The implicit rule appears to be the translation of poetic content into onomatopoetic sounds that capture the sensory and emotional qualities of the text.
#
# Explicit rule formulation:
# Transform the semantic and emotional content of poetic phrases into a sequence of onomatopoeia that:
# 1. Reflects the physical actions or movements described
# 2. Captures the emotional tone
# 3. Maintains the temporal sequence of events
# 4. Represents the intensity of the described experience
#
# Applied to "hört eine Klage voll wilder Begehr":
#
# Mmmm... Aaah! Krrr! Wuuuh!
#
# Mmmm...
# A low, sustained sound suggesting the initial hearing or perception of the lament
# Aaah!
# A passionate vocalization representing the emotional core of the lament
# Krrr!
# A harsh, guttural sound expressing the wildness (wild)
# Wuuuh!
# An intense, rising sound symbolizing the desperate desire (Begehr)

# %%
printmd(gemini(prompt))
# Out:
# The implicit rule is to **interpret phrases or lines of poetry as a sequence of onomatopoeic words that evoke the imagery, mood, and themes present in the text.**  The sounds chosen aim to create a synesthetic experience, translating the written word into an auditory representation.
#
# Applying this rule to "hört eine Klage voll wilder Begehr" (hears a lament full of wild desire):
#
# * **Wuuuh...:** A low, mournful, drawn-out sound representing the base of the lament, suggesting sadness and longing.
# * **Krrr...:** A guttural, tense sound reflecting the "wild" aspect of the desire, hinting at a suppressed intensity or frustration.
# * **Schrrrch...:**  A sharp, scratching sound depicting the rawness and urgency of the desire, like a desperate plea or an internal struggle.
# * **Haach...:** A sighing, yearning sound illustrating the emotional depth and vulnerability within the lament, a whispered expression of longing.
# * **Wumm...:** A deep, resonating sound symbolizing the powerful impact of the desire, the way it reverberates through the person experiencing it.
#
#
# This sequence attempts to capture the conflicting emotions and the intensity present in the phrase "hört eine Klage voll wilder Begehr," translating the feeling of a desperate, passionate lament into a series of evocative sounds.
